# %%
print("hello world")
# Out:
# hello world

# %%
## This script get all information needed about IXPs in PeeringDB using its API.
## IXP Name, Localization, URL website, Graph ?, URL graphs stats, List of Peers (social networks at IX?)
from datetime import datetime
import json, requests, sys, time
from pprint import pprint
import os


## This function requests the output of any API endpoint.
def fetch_api_url(url):
    r = requests.get(url)
    #time.sleep(0.5) ## necessary to make sure that the output is fully fetched
    content_url = r.content
    # Put content_url in json variable and return it
    json_val = {}
    try:
        json_val = json.loads(content_url)
    except:
        pass
    return json_val


print('Step 1: Getting all IDs of IXPs in the Peering database')
query = "https://api.ixpdb.net/v1/provider/list"
query2= "https://api.ixpdb.net"

# If you want to fetch them all
list_IXPs = fetch_api_url(query)
# Out:
# Step 1: Getting all IDs of IXPs in the Peering database

# %%
list_IXPs
# Out:
# [{'id': 748,
#   'pdb_id': 2239,
#   'name': '(BHNIX) Bosnia and Herzegovina Neutral Internet Exchange',
#   'city': 'Sarajevo',
#   'country': 'BA',
#   'organization_id': 10664,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:06:06Z',
#   'manrs': False},
#  {'id': 123,
#   'pdb_id': 1183,
#   'name': '6NGIX (IPv6 Next Generation Internet eXchange)',
#   'city': 'Seoul',
#   'country': 'KR',
#   'organization_id': 186,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T00:17:51Z',
#   'manrs': False},
#  {'id': 699,
#   'pdb_id': 1816,
#   'name': 'A.IX (Advanced Internet eXchange)',
#   'city': 'Beirut',
#   'country': 'LB',
#   'organization_id': 690,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:48:19Z',
#   'manrs': False},
#  {'id': 276,
#   'pdb_id': 377,
#   'name': 'AAIX (Alpes Adria Internet Exchange)',
#   'city': 'Klagenfurt',
#   'country': 'AT',
#   'organization_id': 324,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 10,
#   'location_count': 0,
#   'updated': '2019-06-19T00:55:28Z',
#   'manrs': False},
#  {'id': 323,
#   'pdb_id': 976,
#   'name': 'ACT-IX',
#   'city': 'Canberra',
#   'country': 'AU',
#   'organization_id': 359,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://ix.asn.au/participants.json', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-07-10T06:01:05Z',
#   'manrs': False},
#  {'id': 212,
#   'pdb_id': 1201,
#   'name': 'AIXP (Arusha Internet eXchange)',
#   'city': 'Arusha',
#   'country': 'TZ',
#   'organization_id': 265,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 5,
#   'location_count': 0,
#   'updated': '2019-06-17T22:59:29Z',
#   'manrs': False},
#  {'id': 586,
#   'pdb_id': 977,
#   'name': 'AKL-IX (Auckland Internet Exchange)',
#   'city': 'Auckland',
#   'country': 'NZ',
#   'organization_id': 558,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T12:16:33Z',
#   'manrs': False},
#  {'id': 443,
#   'pdb_id': 168,
#   'name': 'AMPATH (AMPATH - Florida International University/CIARA)',
#   'city': 'Miami',
#   'country': 'US',
#   'organization_id': 447,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:13:59Z',
#   'manrs': False},
#  {'id': 737,
#   'pdb_id': 1812,
#   'name': 'ams (Asteroid Amsterdam Internet Exchange)',
#   'city': 'Amsterdam',
#   'country': 'NL',
#   'organization_id': 720,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://sputnik.asteroidhq.com/export/euroix/1/participants.json',
#    'traffic': ''},
#   'participant_count': 31,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 2,
#   'pdb_id': 26,
#   'name': 'AMS-IX',
#   'city': 'Amsterdam',
#   'country': 'NL',
#   'organization_id': 9,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 843,
#   'location_count': 14,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 61,
#   'pdb_id': 366,
#   'name': 'AMS-IX Caribbean',
#   'city': 'Willemstad, Curacao',
#   'country': 'AN',
#   'organization_id': 91,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 12,
#   'location_count': 1,
#   'updated': '2019-07-10T21:00:17Z',
#   'manrs': False},
#  {'id': 356,
#   'pdb_id': 577,
#   'name': 'AMS-IX Hong Kong',
#   'city': 'Hong Kong',
#   'country': 'CN',
#   'organization_id': 92,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 52,
#   'location_count': 1,
#   'updated': '2019-07-10T21:01:08Z',
#   'manrs': False},
#  {'id': 619,
#   'pdb_id': 1623,
#   'name': 'AMS-IX India',
#   'city': 'Mumbai',
#   'country': 'IN',
#   'organization_id': 587,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 39,
#   'location_count': 2,
#   'updated': '2019-07-10T21:01:06Z',
#   'manrs': False},
#  {'id': 532,
#   'pdb_id': 935,
#   'name': 'AMS-IX USA Bay Area',
#   'city': 'San Francisco',
#   'country': 'US',
#   'organization_id': 510,
#   'association': 'North America',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 27,
#   'location_count': 3,
#   'updated': '2019-07-10T21:01:12Z',
#   'manrs': False},
#  {'id': 533,
#   'pdb_id': 944,
#   'name': 'AMS-IX USA Chicago',
#   'city': 'Chicago',
#   'country': 'US',
#   'organization_id': 511,
#   'association': 'North America',
#   'apis': {'ixfexport': 'https://stats.ams-ix.net/exports/members.json',
#    'traffic': ''},
#   'participant_count': 29,
#   'location_count': 3,
#   'updated': '2019-07-10T21:01:10Z',
#   'manrs': False},
#  {'id': 412,
#   'pdb_id': 806,
#   'name': 'AMS-IX USA New York',
#   'city': 'New York',
#   'country': 'US',
#   'organization_id': 93,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T23:45:39Z',
#   'manrs': False},
#  {'id': 202,
#   'pdb_id': 421,
#   'name': 'Angola IXP',
#   'city': 'Luanda',
#   'country': 'AO',
#   'organization_id': 257,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T21:07:55Z',
#   'manrs': False},
#  {'id': 531,
#   'pdb_id': 1007,
#   'name': 'angonix',
#   'city': 'Luanda',
#   'country': 'AO',
#   'organization_id': 509,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 15,
#   'location_count': 0,
#   'updated': '2019-06-19T21:08:40Z',
#   'manrs': False},
#  {'id': 746,
#   'pdb_id': 2004,
#   'name': 'ANIX (Albanian Neutral Internet eXchange)',
#   'city': '',
#   'country': 'AL',
#   'organization_id': 10622,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://anix.al/export.json', 'traffic': ''},
#   'participant_count': 7,
#   'location_count': 1,
#   'updated': '2019-02-20T10:06:14Z',
#   'manrs': False},
#  {'id': 238,
#   'pdb_id': 333,
#   'name': 'Any2 (CoreSite) Boston (Any2 (CoreSite) Boston)',
#   'city': 'Boston',
#   'country': 'US',
#   'organization_id': 290,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 2,
#   'location_count': 0,
#   'updated': '2019-06-18T08:47:58Z',
#   'manrs': False},
#  {'id': 239,
#   'pdb_id': 226,
#   'name': 'Any2 (CoreSite) Chicago (Any2 (CoreSite) Chicago)',
#   'city': 'Chicago',
#   'country': 'US',
#   'organization_id': 291,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 7,
#   'location_count': 0,
#   'updated': '2019-06-10T11:16:50Z',
#   'manrs': False},
#  {'id': 240,
#   'pdb_id': 205,
#   'name': 'Any2 (CoreSite) Miami (Any2 (CoreSite) Miami)',
#   'city': 'Miami',
#   'country': 'US',
#   'organization_id': 292,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 1,
#   'location_count': 0,
#   'updated': '2019-06-10T11:17:27Z',
#   'manrs': False},
#  {'id': 242,
#   'pdb_id': 332,
#   'name': 'Any2 (CoreSite) New York (Any2 (CoreSite) New York)',
#   'city': 'New York',
#   'country': 'US',
#   'organization_id': 294,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 2,
#   'location_count': 0,
#   'updated': '2019-06-10T11:21:36Z',
#   'manrs': False},
#  {'id': 243,
#   'pdb_id': 204,
#   'name': 'Any2 (CoreSite) NorthEast',
#   'city': 'Reston',
#   'country': 'US',
#   'organization_id': 295,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 9,
#   'location_count': 0,
#   'updated': '2019-06-10T11:24:04Z',
#   'manrs': False},
#  {'id': 241,
#   'pdb_id': 338,
#   'name': 'Any2 (CoreSite) Silicon Valley',
#   'city': 'Milpitas',
#   'country': 'US',
#   'organization_id': 293,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 3,
#   'location_count': 0,
#   'updated': '2019-06-10T11:20:36Z',
#   'manrs': False},
#  {'id': 126,
#   'pdb_id': 97,
#   'name': 'APE - Auckland (Auckland Peering Exchange)',
#   'city': 'Auckland',
#   'country': 'NZ',
#   'organization_id': 189,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 72,
#   'location_count': 0,
#   'updated': '2019-06-18T08:39:12Z',
#   'manrs': False},
#  {'id': 721,
#   'pdb_id': 1919,
#   'name': 'APLIX.PL (APLIX)',
#   'city': 'Gdynia',
#   'country': 'PL',
#   'organization_id': 708,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T21:39:56Z',
#   'manrs': False},
#  {'id': 631,
#   'pdb_id': 1684,
#   'name': 'Aracaju (SE) (IX.br - Aracaju)',
#   'city': 'Aracaju',
#   'country': 'BR',
#   'organization_id': 600,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:44:24Z',
#   'manrs': False},
#  {'id': 372,
#   'pdb_id': 851,
#   'name': 'ARMIX (Armenian Internet Traffic Exchange)',
#   'city': 'Yerevan',
#   'country': 'AM',
#   'organization_id': 394,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 10,
#   'location_count': 0,
#   'updated': '2019-06-18T02:16:57Z',
#   'manrs': False},
#  {'id': 695,
#   'pdb_id': 1468,
#   'name': 'Asia Smart IX (Asia Smart IX [BBIX Asia])',
#   'city': 'Tokyo',
#   'country': 'JP',
#   'organization_id': 684,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:40:16Z',
#   'manrs': False},
#  {'id': 564,
#   'pdb_id': 1019,
#   'name': 'AuvernIX (AuvernIX)',
#   'city': 'Clermont Ferrand',
#   'country': 'FR',
#   'organization_id': 130,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 8,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:16Z',
#   'manrs': True},
#  {'id': 287,
#   'pdb_id': 476,
#   'name': 'AZIX (Arizona Internet Exchange)',
#   'city': 'Phoenix',
#   'country': 'US',
#   'organization_id': 332,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 2,
#   'location_count': 0,
#   'updated': '2019-06-18T11:59:09Z',
#   'manrs': False},
#  {'id': 291,
#   'pdb_id': 372,
#   'name': 'Balcan-IX (Balcan-IX)',
#   'city': 'Bucharest',
#   'country': 'RO',
#   'organization_id': 335,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 17,
#   'location_count': 0,
#   'updated': '2019-06-19T21:10:23Z',
#   'manrs': False},
#  {'id': 197,
#   'pdb_id': 326,
#   'name': 'Balkan-IX (Balkan Internet Exchange)',
#   'city': 'Sofia',
#   'country': 'BG',
#   'organization_id': 252,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 14,
#   'location_count': 0,
#   'updated': '2019-06-17T22:54:14Z',
#   'manrs': False},
#  {'id': 741,
#   'pdb_id': 2005,
#   'name': 'BALT-IX (Baltic Internet Exchange)',
#   'city': '',
#   'country': 'LT',
#   'organization_id': 723,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://stats.balt-ix.net/members/0.7/participants.json',
#    'traffic': 'http://stats.balt-ix.net/graph.day'},
#   'participant_count': 45,
#   'location_count': 9,
#   'updated': '2019-06-17T10:01:41Z',
#   'manrs': False},
#  {'id': 766,
#   'pdb_id': 2186,
#   'name': 'Baltimore IX',
#   'city': 'Baltimore',
#   'country': 'US',
#   'organization_id': 13978,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-03-27T18:40:04Z',
#   'manrs': False},
#  {'id': 587,
#   'pdb_id': 1025,
#   'name': 'Bangkok Neutral Internet Exchange (BKNIX)',
#   'city': '',
#   'country': 'TH',
#   'organization_id': 122,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://bknix.co.th/data/public/members.json',
#    'traffic': 'https://ixpmanager.bknix.co.th/grapher/infrastructure?id=1&type=log&period=day'},
#   'participant_count': 25,
#   'location_count': 2,
#   'updated': '2019-07-11T02:05:16Z',
#   'manrs': True},
#  {'id': 590,
#   'pdb_id': 1449,
#   'name': 'BBIX - Hong Kong',
#   'city': 'Hong Kong',
#   'country': 'HK',
#   'organization_id': 562,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:26:28Z',
#   'manrs': False},
#  {'id': 366,
#   'pdb_id': 786,
#   'name': 'BBIX - Osaka (Broadband Internet eXchange - Osaka)',
#   'city': 'Osaka',
#   'country': 'JP',
#   'organization_id': 391,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:02:56Z',
#   'manrs': False},
#  {'id': 601,
#   'pdb_id': 909,
#   'name': 'BBIX - Singapore (BBIX - Singapore)',
#   'city': 'Singapore',
#   'country': 'SG',
#   'organization_id': 573,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:39:26Z',
#   'manrs': False},
#  {'id': 51,
#   'pdb_id': 126,
#   'name': 'BBIX - Tokyo (BroadBand Internet eXchange - Tokyo)',
#   'city': 'Tokyo',
#   'country': 'JP',
#   'organization_id': 140,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 8,
#   'location_count': 0,
#   'updated': '2019-06-17T06:43:04Z',
#   'manrs': False},
#  {'id': 802,
#   'pdb_id': 2467,
#   'name': 'BBIX Thailand',
#   'city': '',
#   'country': '',
#   'organization_id': 16265,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:32:22Z',
#   'manrs': False},
#  {'id': 21,
#   'pdb_id': 87,
#   'name': 'BCIX (BCIX Management GmbH)',
#   'city': '',
#   'country': 'DE',
#   'organization_id': 29,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.bcix.de/ixp/api/v4/member-export/ixf/0.7',
#    'traffic': 'https://www.bcix.de/ixp/grapher/infrastructure?id=1&type=log&period=day'},
#   'participant_count': 101,
#   'location_count': 8,
#   'updated': '2019-06-27T09:02:09Z',
#   'manrs': False},
#  {'id': 109,
#   'pdb_id': 2516,
#   'name': 'BDIX - Dhaka (Bangladesh Internet Exchange)',
#   'city': 'Dhaka',
#   'country': 'BD',
#   'organization_id': 172,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-05-28T18:12:48Z',
#   'manrs': False},
#  {'id': 147,
#   'pdb_id': 1354,
#   'name': 'Beirut-IX (Beirut Internet Exchange)',
#   'city': 'Beirut',
#   'country': 'LB',
#   'organization_id': 210,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 25,
#   'location_count': 0,
#   'updated': '2019-06-17T20:15:06Z',
#   'manrs': False},
#  {'id': 378,
#   'pdb_id': 711,
#   'name': 'Belém (BEL) (IX.br Belém (BEL))',
#   'city': 'Belém',
#   'country': 'BR',
#   'organization_id': 400,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 15,
#   'location_count': 0,
#   'updated': '2019-06-17T20:28:40Z',
#   'manrs': False},
#  {'id': 154,
#   'pdb_id': 176,
#   'name': 'Belo Horizonte (MG) (IX.br - Belo Horizonte (MG))',
#   'city': 'Belo Horizonte',
#   'country': 'BR',
#   'organization_id': 218,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 29,
#   'location_count': 0,
#   'updated': '2019-06-17T06:54:32Z',
#   'manrs': False},
#  {'id': 545,
#   'pdb_id': 1017,
#   'name': 'Benin-IX (Benin Internet eXchange)',
#   'city': 'Cotonou',
#   'country': 'BJ',
#   'organization_id': 527,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:30:52Z',
#   'manrs': False},
#  {'id': 556,
#   'pdb_id': 1314,
#   'name': 'BFiX Burkina Faso (Burkina Faso)',
#   'city': 'Ouagadougou',
#   'country': 'BF',
#   'organization_id': 537,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:33:24Z',
#   'manrs': False},
#  {'id': 246,
#   'pdb_id': 151,
#   'name': 'Big APE (The big apple peering Exchange)',
#   'city': 'New York',
#   'country': 'US',
#   'organization_id': 298,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 27,
#   'location_count': 0,
#   'updated': '2019-06-10T11:26:20Z',
#   'manrs': False},
#  {'id': 203,
#   'pdb_id': 1409,
#   'name': 'BINX (Botswana Internet Exchange)',
#   'city': 'Gaborone',
#   'country': 'BW',
#   'organization_id': 258,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T22:57:24Z',
#   'manrs': False},
#  {'id': 358,
#   'pdb_id': 452,
#   'name': 'BIX - Jakarta (Biznet Internet eXchange)',
#   'city': 'Jakarta',
#   'country': 'ID',
#   'organization_id': 383,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 25,
#   'location_count': 0,
#   'updated': '2019-06-17T08:49:04Z',
#   'manrs': False},
#  {'id': 12,
#   'pdb_id': 55,
#   'name': 'BiX (Budapest Internet eXchange)',
#   'city': 'Budapest',
#   'country': 'HU',
#   'organization_id': 19,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://admin.bix.hu/ixfexport.php', 'traffic': ''},
#   'participant_count': 49,
#   'location_count': 0,
#   'updated': '2019-05-27T22:14:04Z',
#   'manrs': False},
#  {'id': 55,
#   'pdb_id': 55,
#   'name': 'BIX (Budapest Internet Exchange)',
#   'city': '',
#   'country': 'HU',
#   'organization_id': 59,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://admin.bix.hu/ixfexport.php', 'traffic': ''},
#   'participant_count': 66,
#   'location_count': 3,
#   'updated': '2019-06-16T23:26:47Z',
#   'manrs': False},
#  {'id': 192,
#   'pdb_id': 582,
#   'name': 'BIX Bergen (Bergen Internet Exchange)',
#   'city': 'Bergen',
#   'country': 'NO',
#   'organization_id': 247,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 4,
#   'location_count': 0,
#   'updated': '2019-06-18T08:42:57Z',
#   'manrs': False},
#  {'id': 40,
#   'pdb_id': 331,
#   'name': 'BIX.BG (Bulgarian Internet eXchange)',
#   'city': 'Sofia',
#   'country': 'BG',
#   'organization_id': 47,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 81,
#   'location_count': 0,
#   'updated': '2019-06-16T23:14:37Z',
#   'manrs': False},
#  {'id': 286,
#   'pdb_id': 496,
#   'name': 'BNIIX (Buffalo Niagara International Internet Exchange)',
#   'city': 'Buffalo',
#   'country': 'US',
#   'organization_id': 331,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:57:12Z',
#   'manrs': False},
#  {'id': 4,
#   'pdb_id': 59,
#   'name': 'BNIX (Belgian National Internet Exchange)',
#   'city': 'Brussels',
#   'country': 'BE',
#   'organization_id': 11,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 45,
#   'location_count': 0,
#   'updated': '2019-05-27T12:53:59Z',
#   'manrs': False},
#  {'id': 273,
#   'pdb_id': 1412,
#   'name': 'BOR-IX (Boras Internet Exchange)',
#   'city': 'Boras',
#   'country': 'SE',
#   'organization_id': 320,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 8,
#   'location_count': 0,
#   'updated': '2019-06-17T23:11:55Z',
#   'manrs': False},
#  {'id': 407,
#   'pdb_id': 565,
#   'name': 'BostonIX (Markley Boston Internet Exchange)',
#   'city': 'Boston',
#   'country': 'US',
#   'organization_id': 422,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 24,
#   'location_count': 0,
#   'updated': '2019-06-13T21:44:37Z',
#   'manrs': False},
#  {'id': 588,
#   'pdb_id': 864,
#   'name': 'BR-IX (Brno Internet Exchange Point)',
#   'city': 'Brno',
#   'country': 'CZ',
#   'organization_id': 560,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T09:07:08Z',
#   'manrs': False},
#  {'id': 155,
#   'pdb_id': 178,
#   'name': 'Brasília (DF) (IX.br -  Brasília (DF))',
#   'city': 'Brasilia',
#   'country': 'BR',
#   'organization_id': 219,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 32,
#   'location_count': 0,
#   'updated': '2019-06-17T14:14:51Z',
#   'manrs': False},
#  {'id': 672,
#   'pdb_id': 1670,
#   'name': 'Breizh-IX (Breizh-IX)',
#   'city': 'Rennes',
#   'country': 'FR',
#   'organization_id': 654,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T01:29:53Z',
#   'manrs': False},
#  {'id': 404,
#   'pdb_id': 796,
#   'name': 'BREM-IX (Bremen Internet Exchange)',
#   'city': 'Bremen',
#   'country': 'DE',
#   'organization_id': 420,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-13T21:41:58Z',
#   'manrs': False},
#  {'id': 620,
#   'pdb_id': 1421,
#   'name': 'BW-IX Karlsruhe (Baden-Württemberg Internet Exchange Karlsruhe)',
#   'city': 'Karlsruhe',
#   'country': 'DE',
#   'organization_id': 589,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T20:12:30Z',
#   'manrs': False},
#  {'id': 139,
#   'pdb_id': 212,
#   'name': 'BW-IX Stuttgart (Baden-Württemberg Internet Exchange Stuttgart)',
#   'city': 'Stuttgart',
#   'country': 'DE',
#   'organization_id': 201,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 10,
#   'location_count': 0,
#   'updated': '2019-06-17T20:11:26Z',
#   'manrs': False},
#  {'id': 279,
#   'pdb_id': 275,
#   'name': 'BYIX (Belarus National Internet Exchange Point)',
#   'city': 'Minsk',
#   'country': 'BY',
#   'organization_id': 327,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T14:55:45Z',
#   'manrs': False},
#  {'id': 797,
#   'pdb_id': 1068,
#   'name': 'CABASE-DLC - IX Argentina (Santa Teresita)',
#   'city': '',
#   'country': '',
#   'organization_id': 16259,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:48:53Z',
#   'manrs': False},
#  {'id': 795,
#   'pdb_id': 1484,
#   'name': 'CABASE-NGB - IX Argentina (Pilar)',
#   'city': '',
#   'country': '',
#   'organization_id': 16257,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:43:06Z',
#   'manrs': False},
#  {'id': 794,
#   'pdb_id': 2039,
#   'name': 'CABASE-OGB - IX Argentina (Moreno)',
#   'city': '',
#   'country': '',
#   'organization_id': 16256,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:40:46Z',
#   'manrs': False},
#  {'id': 796,
#   'pdb_id': 1486,
#   'name': 'CABASE-SLT - IX Argentina (Salta)',
#   'city': '',
#   'country': '',
#   'organization_id': 16258,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:45:32Z',
#   'manrs': False},
#  {'id': 206,
#   'pdb_id': 274,
#   'name': 'CAIX (Cairo Internet Exchange)',
#   'city': 'Cairo',
#   'country': 'EG',
#   'organization_id': 262,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T08:44:14Z',
#   'manrs': False},
#  {'id': 798,
#   'pdb_id': 2541,
#   'name': 'CAMIX Douala',
#   'city': '',
#   'country': '',
#   'organization_id': 16260,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:23:36Z',
#   'manrs': False},
#  {'id': 528,
#   'pdb_id': 2554,
#   'name': 'CAMIX Yaounde',
#   'city': 'Yaoundé',
#   'country': 'CM',
#   'organization_id': 506,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:23:05Z',
#   'manrs': False},
#  {'id': 283,
#   'pdb_id': 603,
#   'name': 'Campina Grande (CPV) (IX.br - Campina Grande (CPV))',
#   'city': 'Campina Grande',
#   'country': 'BR',
#   'organization_id': 329,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 10,
#   'location_count': 0,
#   'updated': '2019-06-17T20:26:20Z',
#   'manrs': False},
#  {'id': 262,
#   'pdb_id': 415,
#   'name': 'Campinas (CAS) (IX.br - Campinas (CAS))',
#   'city': 'Campinas',
#   'country': 'BR',
#   'organization_id': 312,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 36,
#   'location_count': 0,
#   'updated': '2019-06-17T20:25:16Z',
#   'manrs': False},
#  {'id': 11,
#   'pdb_id': 62,
#   'name': 'CATNIX (Catalunya Neutral Internet eXchange)',
#   'city': '',
#   'country': 'ES',
#   'organization_id': 18,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://www.catnix.net/participants.json',
#    'traffic': ''},
#   'participant_count': 40,
#   'location_count': 1,
#   'updated': '2019-07-11T02:05:16Z',
#   'manrs': True},
#  {'id': 376,
#   'pdb_id': 558,
#   'name': 'Caxias do Sul (CXJ) (IX.br - Caxias do Sul (CXJ))',
#   'city': 'Caxias do Sul',
#   'country': 'BR',
#   'organization_id': 398,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 5,
#   'location_count': 0,
#   'updated': '2019-06-17T15:03:38Z',
#   'manrs': False},
#  {'id': 697,
#   'pdb_id': 1228,
#   'name': 'CDIX (Cyber Data Internet Xchange)',
#   'city': 'Jakarta',
#   'country': 'ID',
#   'organization_id': 688,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:00:50Z',
#   'manrs': False},
#  {'id': 127,
#   'pdb_id': 349,
#   'name': 'CHIX - Christchurch (Christchurch Internet Exchange)',
#   'city': 'Christchurch',
#   'country': 'NZ',
#   'organization_id': 190,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 11,
#   'location_count': 0,
#   'updated': '2019-06-17T06:50:42Z',
#   'manrs': False},
#  {'id': 149,
#   'pdb_id': 239,
#   'name': 'ChIX (Chicago Internet eXchange)',
#   'city': 'Chicago',
#   'country': 'US',
#   'organization_id': 212,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 20,
#   'location_count': 0,
#   'updated': '2019-06-17T20:17:14Z',
#   'manrs': False},
#  {'id': 582,
#   'pdb_id': 1172,
#   'name': 'CHN-IX Beijing',
#   'city': 'Beijing',
#   'country': 'CN',
#   'organization_id': 555,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:28:25Z',
#   'manrs': False},
#  {'id': 585,
#   'pdb_id': 1284,
#   'name': 'CHN-IX Guangzhou',
#   'city': 'Guangzhou',
#   'country': 'CN',
#   'organization_id': 556,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:33:09Z',
#   'manrs': False},
#  {'id': 209,
#   'pdb_id': 344,
#   'name': 'CINX - Cape Town (Cape Town Internet Exchange)',
#   'city': 'Cape Town',
#   'country': 'ZA',
#   'organization_id': 264,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 11,
#   'location_count': 0,
#   'updated': '2019-06-17T14:36:24Z',
#   'manrs': False},
#  {'id': 205,
#   'pdb_id': 810,
#   'name': 'CIVIX (Cote d’Ivoire Internet eXchange Point)',
#   'city': 'Abidjan',
#   'country': 'CI',
#   'organization_id': 261,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 4,
#   'location_count': 0,
#   'updated': '2019-06-19T00:25:49Z',
#   'manrs': False},
#  {'id': 28,
#   'pdb_id': 303,
#   'name': 'CIX (Croatian Internet eXchange)',
#   'city': 'Zagreb',
#   'country': 'HR',
#   'organization_id': 37,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 35,
#   'location_count': 0,
#   'updated': '2019-05-28T06:00:44Z',
#   'manrs': False},
#  {'id': 496,
#   'pdb_id': 778,
#   'name': 'CIX KR (CIX - Cracow Internet Exchange)',
#   'city': 'Krakow',
#   'country': 'PL',
#   'organization_id': 481,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-14T14:17:44Z',
#   'manrs': False},
#  {'id': 684,
#   'pdb_id': 1668,
#   'name': 'CIX-ATL',
#   'city': 'Atlanta',
#   'country': 'US',
#   'organization_id': 675,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T17:37:34Z',
#   'manrs': False},
#  {'id': 7,
#   'pdb_id': 33,
#   'name': 'CIXP (CERN Internet Exchange Point)',
#   'city': '',
#   'country': 'CH',
#   'organization_id': 134,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://cixp.net/participants.json', 'traffic': ''},
#   'participant_count': 40,
#   'location_count': 3,
#   'updated': '2019-06-07T15:00:42Z',
#   'manrs': False},
#  {'id': 457,
#   'pdb_id': 237,
#   'name': 'CNC Beijing NAP (CNC Beijing NAP)',
#   'city': 'Beijing',
#   'country': 'CN',
#   'organization_id': 450,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T14:34:22Z',
#   'manrs': False},
#  {'id': 604,
#   'pdb_id': 1303,
#   'name': 'CNIX (China Internet Exchange)',
#   'city': 'Beijing',
#   'country': 'CN',
#   'organization_id': 576,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:38:48Z',
#   'manrs': False},
#  {'id': 432,
#   'pdb_id': 1209,
#   'name': 'CNX (Cambodian Network Exchange)',
#   'city': 'Phnom Penh',
#   'country': 'KH',
#   'organization_id': 87,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 18,
#   'location_count': 0,
#   'updated': '2019-06-17T08:53:39Z',
#   'manrs': False},
#  {'id': 696,
#   'pdb_id': 1229,
#   'name': 'COD-IX (COD-IX)',
#   'city': 'St. Petersburg',
#   'country': 'RU',
#   'organization_id': 686,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:00:21Z',
#   'manrs': False},
#  {'id': 477,
#   'pdb_id': 514,
#   'name': 'COIX (Central Oregon Internet eXchange)',
#   'city': 'Bend Oregon',
#   'country': 'US',
#   'organization_id': 464,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T09:02:15Z',
#   'manrs': False},
#  {'id': 747,
#   'pdb_id': 1329,
#   'name': 'Community-IX DE',
#   'city': '',
#   'country': '',
#   'organization_id': 10646,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:04:16Z',
#   'manrs': False},
#  {'id': 257,
#   'pdb_id': 254,
#   'name': 'CoreSite - Any2 Denver / RMIX Denver (CoreSite - Any2 Denver / RMIX Denver)',
#   'city': 'Denver',
#   'country': 'US',
#   'organization_id': 307,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 6,
#   'location_count': 0,
#   'updated': '2019-06-17T23:04:09Z',
#   'manrs': False},
#  {'id': 52,
#   'pdb_id': 142,
#   'name': 'CoreSite - Any2 Los Angeles (CoreSite - Any2 Los Angeles)',
#   'city': 'Los Angeles',
#   'country': 'US',
#   'organization_id': 55,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 147,
#   'location_count': 0,
#   'updated': '2019-06-17T13:59:48Z',
#   'manrs': False},
#  {'id': 186,
#   'pdb_id': 287,
#   'name': 'Crimea-IX (Crimea-IX)',
#   'city': 'Crimea Republic, Simferopol',
#   'country': 'RU',
#   'organization_id': 78,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 16,
#   'location_count': 0,
#   'updated': '2019-06-17T21:13:41Z',
#   'manrs': False},
#  {'id': 541,
#   'pdb_id': 1023,
#   'name': 'CRIX (NIC Costa Rica - Academia Nacional de Ciencias)',
#   'city': '',
#   'country': 'CR',
#   'organization_id': 522,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': 'https://portal.crix.cr/api/v4/member-export/ixf/0.7',
#    'traffic': 'https://portal.crix.cr/grapher/infrastructure?id=1&type=log&period=day'},
#   'participant_count': 30,
#   'location_count': 1,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 500,
#   'pdb_id': 859,
#   'name': 'Cuiabá (CGB) (IX.br - Cuiabá (CGB))',
#   'city': 'Cuiabá',
#   'country': 'BR',
#   'organization_id': 485,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 8,
#   'location_count': 0,
#   'updated': '2019-06-16T17:40:45Z',
#   'manrs': False},
#  {'id': 156,
#   'pdb_id': 174,
#   'name': 'Curitiba (PR) (IX.br - Curitiba (PR))',
#   'city': 'Curitiba',
#   'country': 'BR',
#   'organization_id': 220,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 66,
#   'location_count': 0,
#   'updated': '2019-06-17T20:20:19Z',
#   'manrs': False},
#  {'id': 73,
#   'pdb_id': 487,
#   'name': 'CyIX (Cyprus Internet Exchange)',
#   'city': 'Nicosia',
#   'country': 'CY',
#   'organization_id': 149,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 6,
#   'location_count': 0,
#   'updated': '2019-06-17T09:30:37Z',
#   'manrs': False},
#  {'id': 640,
#   'pdb_id': 674,
#   'name': 'CyrusOne IX Austin (CyrusOne IX Austin)',
#   'city': 'Austin',
#   'country': 'US',
#   'organization_id': 607,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:52:34Z',
#   'manrs': False},
#  {'id': 643,
#   'pdb_id': 1142,
#   'name': 'CyrusOne IX Chicago (CyrusOne IX Chicago)',
#   'city': 'Chicago',
#   'country': 'US',
#   'organization_id': 610,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T19:42:42Z',
#   'manrs': False},
#  {'id': 353,
#   'pdb_id': 672,
#   'name': 'CyrusOne IX Dallas (CyrusOne IX Dallas)',
#   'city': 'Carrollton',
#   'country': 'US',
#   'organization_id': 380,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T19:44:12Z',
#   'manrs': False},
#  {'id': 639,
#   'pdb_id': 673,
#   'name': 'CyrusOne IX Houston (CyrusOne IX Houston)',
#   'city': 'Houston',
#   'country': 'US',
#   'organization_id': 606,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:51:59Z',
#   'manrs': False},
#  {'id': 642,
#   'pdb_id': 760,
#   'name': 'CyrusOne IX Phoenix (CyrusOne IX Phoenix)',
#   'city': 'Phoenix',
#   'country': 'US',
#   'organization_id': 609,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T19:43:08Z',
#   'manrs': False},
#  {'id': 641,
#   'pdb_id': 675,
#   'name': 'CyrusOne IX San Antonio (CyrusOne IX San Antonio)',
#   'city': 'San Antonio',
#   'country': 'US',
#   'organization_id': 608,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:08:19Z',
#   'manrs': False},
#  {'id': 644,
#   'pdb_id': 1117,
#   'name': 'CyrusOne IX Sterling (CyrusOne IX Sterling)',
#   'city': 'Sterling',
#   'country': 'US',
#   'organization_id': 611,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T19:42:11Z',
#   'manrs': False},
#  {'id': 522,
#   'pdb_id': 358,
#   'name': 'DataIX - Moscow (DataIX - Moscow)',
#   'city': 'Moscow',
#   'country': 'RU',
#   'organization_id': 500,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T12:14:01Z',
#   'manrs': False},
#  {'id': 524,
#   'pdb_id': 358,
#   'name': 'DataIX - Novosibirsk (DataIX - Novosibirsk)',
#   'city': 'Novosibirsk',
#   'country': 'RU',
#   'organization_id': 502,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:22:49Z',
#   'manrs': False},
#  {'id': 403,
#   'pdb_id': 358,
#   'name': 'DataIX - St Petersburg (DataIX - St Petersburg)',
#   'city': 'St Petersburg',
#   'country': 'RU',
#   'organization_id': 419,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-13T21:37:10Z',
#   'manrs': False},
#  {'id': 523,
#   'pdb_id': 358,
#   'name': 'DataIX - Ufa (DataIX - Ufa)',
#   'city': 'Ufa',
#   'country': 'RU',
#   'organization_id': 501,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T09:05:16Z',
#   'manrs': False},
#  {'id': 567,
#   'pdb_id': 1387,
#   'name': 'DataLine-IX (DataLine-IX)',
#   'city': 'Moscow',
#   'country': 'RU',
#   'organization_id': 544,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T17:51:47Z',
#   'manrs': False},
#  {'id': 580,
#   'pdb_id': 1249,
#   'name': 'DE-CIX Dallas (DE-CIX Dallas)',
#   'city': 'Dallas',
#   'country': 'US',
#   'organization_id': 117,
#   'association': 'North America',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_dfw',
#    'traffic': ''},
#   'participant_count': 37,
#   'location_count': 0,
#   'updated': '2019-06-16T18:04:22Z',
#   'manrs': False},
#  {'id': 688,
#   'pdb_id': 2587,
#   'name': 'DE-CIX Delhi',
#   'city': 'Delhi',
#   'country': 'IN',
#   'organization_id': 679,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T01:14:35Z',
#   'manrs': False},
#  {'id': 565,
#   'pdb_id': 1214,
#   'name': 'DE-CIX DUS (DE-CIX Dusseldorf)',
#   'city': 'Dusseldorf',
#   'country': 'DE',
#   'organization_id': 114,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_dus',
#    'traffic': ''},
#   'participant_count': 107,
#   'location_count': 0,
#   'updated': '2019-07-10T16:01:38Z',
#   'manrs': False},
#  {'id': 9,
#   'pdb_id': 31,
#   'name': 'DE-CIX FRA (DE-CIX Frankfurt)',
#   'city': 'Frankfurt am Main',
#   'country': 'DE',
#   'organization_id': 16,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_fra',
#    'traffic': ''},
#   'participant_count': 868,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 47,
#   'pdb_id': 74,
#   'name': 'DE-CIX HAM (DE-CIX Hamburg)',
#   'city': 'Hamburg',
#   'country': 'DE',
#   'organization_id': 51,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_ham',
#    'traffic': ''},
#   'participant_count': 120,
#   'location_count': 0,
#   'updated': '2019-07-10T16:02:26Z',
#   'manrs': False},
#  {'id': 560,
#   'pdb_id': 1150,
#   'name': 'DE-CIX Istanbul (DE-CIX Istanbul)',
#   'city': 'Istanbul',
#   'country': 'TR',
#   'organization_id': 113,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_ist',
#    'traffic': ''},
#   'participant_count': 25,
#   'location_count': 0,
#   'updated': '2019-06-16T17:46:06Z',
#   'manrs': False},
#  {'id': 689,
#   'pdb_id': 2589,
#   'name': 'DE-CIX Kolkata',
#   'city': 'Kolkata',
#   'country': 'IN',
#   'organization_id': 680,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-19T00:43:43Z',
#   'manrs': False},
#  {'id': 765,
#   'pdb_id': 2531,
#   'name': 'DE-CIX LIS (DE-CIX Lisbon)',
#   'city': 'Lisbon',
#   'country': 'PT',
#   'organization_id': 13792,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_lis',
#    'traffic': ''},
#   'participant_count': 10,
#   'location_count': 0,
#   'updated': '2019-07-10T16:03:02Z',
#   'manrs': False},
#  {'id': 470,
#   'pdb_id': 1277,
#   'name': 'DE-CIX MAD (DE-CIX Madrid)',
#   'city': 'Madrid',
#   'country': 'ES',
#   'organization_id': 458,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_mad',
#    'traffic': ''},
#   'participant_count': 139,
#   'location_count': 0,
#   'updated': '2019-07-10T16:02:32Z',
#   'manrs': False},
#  {'id': 559,
#   'pdb_id': 1149,
#   'name': 'DE-CIX Marseille (DE-CIX Marseille)',
#   'city': 'Marseilles',
#   'country': 'FR',
#   'organization_id': 111,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_mrs',
#    'traffic': ''},
#   'participant_count': 49,
#   'location_count': 0,
#   'updated': '2019-06-16T23:23:48Z',
#   'manrs': False},
#  {'id': 54,
#   'pdb_id': 248,
#   'name': 'DE-CIX MUC (DE-CIX Munich)',
#   'city': 'Munich',
#   'country': 'DE',
#   'organization_id': 57,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_muc',
#    'traffic': ''},
#   'participant_count': 117,
#   'location_count': 0,
#   'updated': '2019-07-10T16:02:39Z',
#   'manrs': False},
#  {'id': 425,
#   'pdb_id': 804,
#   'name': 'DE-CIX NYC (DE-CIX New York)',
#   'city': 'New York',
#   'country': 'US',
#   'organization_id': 88,
#   'association': 'North America',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_nyc',
#    'traffic': ''},
#   'participant_count': 218,
#   'location_count': 0,
#   'updated': '2019-07-10T16:02:45Z',
#   'manrs': False},
#  {'id': 558,
#   'pdb_id': 1131,
#   'name': 'DE-CIX PMO (DE-CIX Palermo)',
#   'city': 'Palermo',
#   'country': 'IT',
#   'organization_id': 110,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://portal.de-cix.net/customer_pmo',
#    'traffic': ''},
#   'participant_count': 11,
#   'location_count': 0,
#   'updated': '2019-07-10T16:02:57Z',
#   'manrs': False},
#  {'id': 662,
#   'pdb_id': 1006,
#   'name': 'DET-IX (Detroit Internet Exchange)',
#   'city': 'Detroit',
#   'country': 'US',
#   'organization_id': 636,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:42:29Z',
#   'manrs': False},
#  {'id': 56,
#   'pdb_id': 22,
#   'name': 'Digital Realty - Atlanta (Digital Realty Exchange - Atlanta)',
#   'city': 'Atlanta',
#   'country': 'US',
#   'organization_id': 142,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 94,
#   'location_count': 0,
#   'updated': '2019-06-16T23:30:00Z',
#   'manrs': False},
#  {'id': 229,
#   'pdb_id': 322,
#   'name': 'Digital Realty - Dallas (Digital Realty  Dallas)',
#   'city': 'Dallas',
#   'country': 'US',
#   'organization_id': 281,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 6,
#   'location_count': 0,
#   'updated': '2019-06-16T23:31:35Z',
#   'manrs': False},
#  {'id': 230,
#   'pdb_id': 325,
#   'name': 'Digital Realty - New York (Digital Realty New York)',
#   'city': 'New York',
#   'country': 'US',
#   'organization_id': 282,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 24,
#   'location_count': 0,
#   'updated': '2019-06-16T23:32:05Z',
#   'manrs': False},
#  {'id': 231,
#   'pdb_id': 256,
#   'name': 'Digital Realty - Phoenix (Digital Realty Phoenix)',
#   'city': 'Phoenix',
#   'country': 'US',
#   'organization_id': 283,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 15,
#   'location_count': 0,
#   'updated': '2019-06-16T23:32:39Z',
#   'manrs': False},
#  {'id': 253,
#   'pdb_id': 2572,
#   'name': 'Digital Realty Ashburn',
#   'city': 'Vienna',
#   'country': 'US',
#   'organization_id': 304,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 11,
#   'location_count': 0,
#   'updated': '2019-06-16T23:35:28Z',
#   'manrs': False},
#  {'id': 29,
#   'pdb_id': 78,
#   'name': 'DIX',
#   'city': 'Lyngby',
#   'country': 'DK',
#   'organization_id': 89,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 44,
#   'location_count': 0,
#   'updated': '2019-06-19T21:27:13Z',
#   'manrs': False},
#  {'id': 441,
#   'pdb_id': 92,
#   'name': 'DIX-IE (Distributed IX in EDO)',
#   'city': 'Tokyo',
#   'country': 'JP',
#   'organization_id': 445,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:09:54Z',
#   'manrs': False},
#  {'id': 549,
#   'pdb_id': 967,
#   'name': 'DjIX (Djibouti IX)',
#   'city': '',
#   'country': 'DJ',
#   'organization_id': 533,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T12:15:46Z',
#   'manrs': False},
#  {'id': 322,
#   'pdb_id': 766,
#   'name': 'DN-IX (Donetsk Internet Exchange)',
#   'city': 'Donetsk',
#   'country': 'UA',
#   'organization_id': 358,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-10T23:06:30Z',
#   'manrs': False},
#  {'id': 463,
#   'pdb_id': 762,
#   'name': 'DO-IX (DOrtmund Internet Exchange)',
#   'city': 'Dortmund',
#   'country': 'DE',
#   'organization_id': 454,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T22:17:32Z',
#   'manrs': False},
#  {'id': 270,
#   'pdb_id': 267,
#   'name': 'DRF IX (DRFortress Exchange)',
#   'city': 'Honolulu',
#   'country': 'US',
#   'organization_id': 317,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 2,
#   'location_count': 0,
#   'updated': '2019-06-18T08:49:00Z',
#   'manrs': False},
#  {'id': 198,
#   'pdb_id': 327,
#   'name': 'DTEL-IX (Digital Telecom Internet Exchange)',
#   'city': 'Kiev',
#   'country': 'UA',
#   'organization_id': 253,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 95,
#   'location_count': 0,
#   'updated': '2019-06-19T00:24:06Z',
#   'manrs': False},
#  {'id': 487,
#   'pdb_id': 610,
#   'name': 'Durban Internet Exchange Point (INX)',
#   'city': 'Durban',
#   'country': 'ZA',
#   'organization_id': 472,
#   'association': 'AFIX',
#   'apis': {'ixfexport': 'https://portal.inx.net.za/api/v4/member-export/ixf/0.7',
#    'traffic': ''},
#   'participant_count': 54,
#   'location_count': 2,
#   'updated': '2019-07-09T18:01:50Z',
#   'manrs': False},
#  {'id': 485,
#   'pdb_id': 602,
#   'name': 'Echigo-IX (Echigo Internet Exchange)',
#   'city': 'Niigata',
#   'country': 'JP',
#   'organization_id': 471,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-13T22:35:51Z',
#   'manrs': False},
#  {'id': 30,
#   'pdb_id': 209,
#   'name': 'ECIX-BER',
#   'city': '',
#   'country': 'DE',
#   'organization_id': 66,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.ecix.net/content/member-lists/memberlist_BER.json',
#    'traffic': ''},
#   'participant_count': 61,
#   'location_count': 0,
#   'updated': '2019-06-16T23:58:28Z',
#   'manrs': False},
#  {'id': 340,
#   'pdb_id': 91,
#   'name': 'ECIX-DUS',
#   'city': '',
#   'country': 'DE',
#   'organization_id': 97,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.ecix.net/content/member-lists/memberlist_DUS.json',
#    'traffic': ''},
#   'participant_count': 112,
#   'location_count': 0,
#   'updated': '2019-06-16T23:59:22Z',
#   'manrs': False},
#  {'id': 431,
#   'pdb_id': 676,
#   'name': 'ECIX-FRA',
#   'city': '',
#   'country': 'DE',
# ...
#   'city': 'Tahoe',
#   'country': 'US',
#   'organization_id': 603,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T18:46:44Z',
#   'manrs': False},
#  {'id': 424,
#   'pdb_id': 363,
#   'name': 'tdc-ops-sw1 (SUPRnet)',
#   'city': '',
#   'country': 'US',
#   'organization_id': 436,
#   'association': 'North America',
#   'apis': {'ixfexport': 'https://portal.suprnet.net/api/v4/member-export/ixf/0.7',
#    'traffic': ''},
#   'participant_count': 22,
#   'location_count': 1,
#   'updated': '2019-06-21T20:00:26Z',
#   'manrs': False},
#  {'id': 346,
#   'pdb_id': 481,
#   'name': 'Thinx (Thinx)',
#   'city': 'Warsaw',
#   'country': 'PL',
#   'organization_id': 86,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 160,
#   'location_count': 0,
#   'updated': '2019-06-17T14:27:00Z',
#   'manrs': False},
#  {'id': 663,
#   'pdb_id': 1009,
#   'name': 'Tirol-IX (Tirol-IX)',
#   'city': 'Hall in Tirol',
#   'country': 'AT',
#   'organization_id': 638,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:43:05Z',
#   'manrs': False},
#  {'id': 50,
#   'pdb_id': 361,
#   'name': 'TIX - Tanzania (Tanzania Internet eXchange)',
#   'city': 'Dar es Salaam',
#   'country': 'TZ',
#   'organization_id': 53,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 38,
#   'location_count': 0,
#   'updated': '2019-06-18T08:34:57Z',
#   'manrs': False},
#  {'id': 76,
#   'pdb_id': 187,
#   'name': 'TIX Tallinn (Tallinn Internet eXchange)',
#   'city': 'Tallinn',
#   'country': 'EE',
#   'organization_id': 150,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 13,
#   'location_count': 0,
#   'updated': '2019-06-17T14:02:21Z',
#   'manrs': False},
#  {'id': 675,
#   'pdb_id': 1574,
#   'name': 'TIX Tanzania - Mwanza IXP (TIX Tanzania - Mwanza IXP)',
#   'city': 'Mwanza',
#   'country': 'TZ',
#   'organization_id': 660,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:35:48Z',
#   'manrs': False},
#  {'id': 199,
#   'pdb_id': 1418,
#   'name': 'TIX Tromsø (Tromsø Internet Exchange)',
#   'city': 'Tromsø',
#   'country': 'NO',
#   'organization_id': 254,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T08:43:42Z',
#   'manrs': False},
#  {'id': 26,
#   'pdb_id': 273,
#   'name': 'TIX Tuscany (Tuscany Internet eXchange)',
#   'city': 'Florence',
#   'country': 'IT',
#   'organization_id': 135,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 20,
#   'location_count': 0,
#   'updated': '2019-05-27T22:20:39Z',
#   'manrs': False},
#  {'id': 98,
#   'pdb_id': 190,
#   'name': 'TLLIX (Tallinn Internet Exchange)',
#   'city': 'Tallinn',
#   'country': 'EE',
#   'organization_id': 163,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 16,
#   'location_count': 0,
#   'updated': '2019-05-28T06:23:02Z',
#   'manrs': False},
#  {'id': 14,
#   'pdb_id': 115,
#   'name': 'TOP-IX (Torino Piemonte Exchange Point)',
#   'city': '',
#   'country': 'IT',
#   'organization_id': 22,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.top-ix.org/members.json', 'traffic': ''},
#   'participant_count': 121,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 163,
#   'pdb_id': 24,
#   'name': 'TorIX (Toronto Internet Exchange)',
#   'city': 'Toronto',
#   'country': 'CA',
#   'organization_id': 77,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 224,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 274,
#   'pdb_id': 336,
#   'name': 'TOUIX (Toulouse Internet eXchange)',
#   'city': 'Toulouse',
#   'country': 'FR',
#   'organization_id': 322,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T23:12:40Z',
#   'manrs': False},
#  {'id': 495,
#   'pdb_id': 624,
#   'name': 'TP-IX (Twin Ports IX)',
#   'city': 'Duluth',
#   'country': 'US',
#   'organization_id': 480,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-14T14:16:54Z',
#   'manrs': False},
#  {'id': 656,
#   'pdb_id': 833,
#   'name': 'TPA-IX (Tampa Internet Exchange)',
#   'city': 'Tampa',
#   'country': 'US',
#   'organization_id': 625,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-16T20:23:03Z',
#   'manrs': False},
#  {'id': 185,
#   'pdb_id': 823,
#   'name': 'TPIX - Taipei (Taipei Internet Exchange)',
#   'city': 'Taipei',
#   'country': 'TW',
#   'organization_id': 244,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 24,
#   'location_count': 0,
#   'updated': '2019-06-10T11:06:57Z',
#   'manrs': False},
#  {'id': 401,
#   'pdb_id': 482,
#   'name': 'TPIX (Orange Polska Internet Exchange)',
#   'city': 'Warsaw',
#   'country': 'PL',
#   'organization_id': 81,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 203,
#   'location_count': 0,
#   'updated': '2019-06-13T21:05:54Z',
#   'manrs': False},
#  {'id': 330,
#   'pdb_id': 269,
#   'name': 'TransACT IX (TransACT IX)',
#   'city': 'Canberra',
#   'country': 'AU',
#   'organization_id': 366,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-12T21:16:32Z',
#   'manrs': False},
#  {'id': 193,
#   'pdb_id': 1420,
#   'name': 'TRDIX (Trondheim Internet Exchange)',
#   'city': 'Trondheim',
#   'country': 'NO',
#   'organization_id': 248,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 5,
#   'location_count': 0,
#   'updated': '2019-06-17T08:16:16Z',
#   'manrs': False},
#  {'id': 46,
#   'pdb_id': 328,
#   'name': 'TREX (TREX Regional Exchanges Oy)',
#   'city': '',
#   'country': 'FI',
#   'organization_id': 50,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://www.trex.fi/memberlist.json', 'traffic': ''},
#   'participant_count': 20,
#   'location_count': 1,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 536,
#   'pdb_id': 940,
#   'name': 'TTIX',
#   'city': 'Barataria',
#   'country': 'TT',
#   'organization_id': 101,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 8,
#   'location_count': 0,
#   'updated': '2019-06-18T23:28:30Z',
#   'manrs': False},
#  {'id': 799,
#   'pdb_id': 2272,
#   'name': 'TTIX2',
#   'city': '',
#   'country': '',
#   'organization_id': 16261,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:30:13Z',
#   'manrs': False},
#  {'id': 757,
#   'pdb_id': 2355,
#   'name': 'TTPL LAN (Bhutan Internet Exchange)',
#   'city': '',
#   'country': 'BT',
#   'organization_id': 11780,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://www.btix.bt/ixp/api/v4/member-export/ixf/0.7',
#    'traffic': ''},
#   'participant_count': 12,
#   'location_count': 1,
#   'updated': '2019-06-13T09:00:41Z',
#   'manrs': False},
#  {'id': 370,
#   'pdb_id': 1105,
#   'name': 'TunIXP (Tunisian Internet eXchange)',
#   'city': 'Tunis',
#   'country': 'TN',
#   'organization_id': 393,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 9,
#   'location_count': 0,
#   'updated': '2019-06-18T02:16:22Z',
#   'manrs': False},
#  {'id': 767,
#   'pdb_id': 2527,
#   'name': 'Turk-IX',
#   'city': 'Istanbul',
#   'country': 'TR',
#   'organization_id': 14019,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-03-28T16:02:05Z',
#   'manrs': False},
#  {'id': 113,
#   'pdb_id': 43,
#   'name': 'TWIX - Taipei (Taiwan Internet Exchange)',
#   'city': 'Taipei',
#   'country': 'TW',
#   'organization_id': 176,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 26,
#   'location_count': 0,
#   'updated': '2019-05-28T18:16:03Z',
#   'manrs': False},
#  {'id': 48,
#   'pdb_id': 184,
#   'name': 'UA-IX (Ukrainian Internet Exchange)',
#   'city': 'Kiev',
#   'country': 'UA',
#   'organization_id': 52,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 102,
#   'location_count': 0,
#   'updated': '2019-06-16T23:25:57Z',
#   'manrs': False},
#  {'id': 373,
#   'pdb_id': 587,
#   'name': 'UAE-IX (United Arab Emirates Internet Exchange)',
#   'city': 'Dubai',
#   'country': 'AE',
#   'organization_id': 395,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 61,
#   'location_count': 0,
#   'updated': '2019-06-19T01:19:37Z',
#   'manrs': False},
#  {'id': 187,
#   'pdb_id': 340,
#   'name': 'ULN-IX (Ulyanovsk Internet Exchange)',
#   'city': '',
#   'country': 'RU',
#   'organization_id': 90,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'http://www.uln-ix.ru/participants.json',
#    'traffic': ''},
#   'participant_count': 15,
#   'location_count': 1,
#   'updated': '2019-06-17T21:18:34Z',
#   'manrs': False},
#  {'id': 598,
#   'pdb_id': 1469,
#   'name': 'UNIFI-IX (UNIFI-IX)',
#   'city': 'Coventry',
#   'country': 'GB',
#   'organization_id': 571,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T15:28:10Z',
#   'manrs': False},
#  {'id': 535,
#   'pdb_id': 863,
#   'name': 'VANIX (Vancouver Internet eXchange)',
#   'city': 'Vancouver',
#   'country': 'CA',
#   'organization_id': 513,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:25:04Z',
#   'manrs': False},
#  {'id': 393,
#   'pdb_id': 513,
#   'name': 'VIC-IX',
#   'city': 'Melbourne',
#   'country': 'AU',
#   'organization_id': 414,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://ix.asn.au/participants.json', 'traffic': ''},
#   'participant_count': 98,
#   'location_count': 0,
#   'updated': '2019-07-10T06:01:14Z',
#   'manrs': False},
#  {'id': 377,
#   'pdb_id': 706,
#   'name': 'Vitória (VIX) (IX.br -  Vitória (VIX))',
#   'city': 'Vitória',
#   'country': 'BR',
#   'organization_id': 399,
#   'association': 'LAC-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 22,
#   'location_count': 0,
#   'updated': '2019-06-17T20:28:15Z',
#   'manrs': False},
#  {'id': 3,
#   'pdb_id': 50,
#   'name': 'VIX (Vienna Internet Exchange)',
#   'city': '',
#   'country': 'AT',
#   'organization_id': 10,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.vix.at/participants.json', 'traffic': ''},
#   'participant_count': 143,
#   'location_count': 0,
#   'updated': '2019-06-11T08:00:36Z',
#   'manrs': False},
#  {'id': 170,
#   'pdb_id': 378,
#   'name': 'vlv-ix (VLV-IX public peering VLAN)',
#   'city': 'Vladivostok',
#   'country': 'RU',
#   'organization_id': 231,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://www.msk-ix.ru/data/json/ixp-member-list-ixf/participants.json',
#    'traffic': ''},
#   'participant_count': 17,
#   'location_count': 0,
#   'updated': '2019-07-10T10:01:31Z',
#   'manrs': False},
#  {'id': 134,
#   'pdb_id': 1772,
#   'name': 'VNIX - Hanoi (Vietnam National Internet eXchange - Hanoi)',
#   'city': 'Hanoi',
#   'country': 'VN',
#   'organization_id': 195,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 19,
#   'location_count': 0,
#   'updated': '2019-06-17T20:10:11Z',
#   'manrs': False},
#  {'id': 135,
#   'pdb_id': 1771,
#   'name': 'VNIX - Ho Chi Minh (Vietnam National Internet eXchange - Ho Chi Minh)',
#   'city': 'Ho Chi Minh City',
#   'country': 'VN',
#   'organization_id': 196,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 9,
#   'location_count': 0,
#   'updated': '2019-06-19T00:22:06Z',
#   'manrs': False},
#  {'id': 38,
#   'pdb_id': 311,
#   'name': 'VSIX (VSIX Nap del Nord Est)',
#   'city': '',
#   'country': 'IT',
#   'organization_id': 45,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': 'https://www.vsix.it/participants.json',
#    'traffic': ''},
#   'participant_count': 49,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:16Z',
#   'manrs': True},
#  {'id': 494,
#   'pdb_id': 971,
#   'name': 'VUIX (Vanuatu Internet Exchange)',
#   'city': 'Port Vila',
#   'country': 'VU',
#   'organization_id': 479,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-14T14:16:23Z',
#   'manrs': False},
#  {'id': 678,
#   'pdb_id': 1242,
#   'name': 'W-IX (W-IX)',
#   'city': 'Moscow',
#   'country': 'RU',
#   'organization_id': 664,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:49:17Z',
#   'manrs': False},
#  {'id': 108,
#   'pdb_id': 21,
#   'name': 'WA-IX',
#   'city': 'Perth',
#   'country': 'AU',
#   'organization_id': 83,
#   'association': 'APIX',
#   'apis': {'ixfexport': 'https://ix.asn.au/participants.json', 'traffic': ''},
#   'participant_count': 106,
#   'location_count': 0,
#   'updated': '2019-07-10T06:01:16Z',
#   'manrs': False},
#  {'id': 85,
#   'pdb_id': 96,
#   'name': 'WIX - Poland (Warsaw Internet eXchange)',
#   'city': 'Warsaw',
#   'country': 'PL',
#   'organization_id': 156,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 13,
#   'location_count': 0,
#   'updated': '2019-06-17T06:49:00Z',
#   'manrs': False},
#  {'id': 132,
#   'pdb_id': 348,
#   'name': 'WIX - Wellington (Wellington Internet Exchange)',
#   'city': 'Wellington',
#   'country': 'NZ',
#   'organization_id': 192,
#   'association': 'APIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 87,
#   'location_count': 0,
#   'updated': '2019-06-17T20:08:52Z',
#   'manrs': False},
#  {'id': 386,
#   'pdb_id': 776,
#   'name': 'WPG-IX (Winnipeg Internet Exchange)',
#   'city': 'Winnipeg',
#   'country': 'CA',
#   'organization_id': 407,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-12T21:21:22Z',
#   'manrs': False},
#  {'id': 493,
#   'pdb_id': 683,
#   'name': 'YAR-IX (Yaroslavl Internet Exchange)',
#   'city': 'Yaroslavl',
#   'country': 'RU',
#   'organization_id': 478,
#   'association': 'Euro-IX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-14T14:12:01Z',
#   'manrs': False},
#  {'id': 669,
#   'pdb_id': 1169,
#   'name': 'YEGIX (YEGIX)',
#   'city': 'Edmonton',
#   'country': 'CA',
#   'organization_id': 649,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-18T23:44:25Z',
#   'manrs': False},
#  {'id': 219,
#   'pdb_id': 199,
#   'name': 'YRIX (Yellowstone Regional Internet Exchange)',
#   'city': 'Billings',
#   'country': 'US',
#   'organization_id': 272,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 7,
#   'location_count': 0,
#   'updated': '2019-06-17T14:37:31Z',
#   'manrs': False},
#  {'id': 398,
#   'pdb_id': 639,
#   'name': 'YYCIX (Calgary Internet Exchange)',
#   'city': 'Calgary',
#   'country': 'CA',
#   'organization_id': 79,
#   'association': 'North America',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 29,
#   'location_count': 0,
#   'updated': '2019-07-11T02:05:17Z',
#   'manrs': True},
#  {'id': 213,
#   'pdb_id': 1293,
#   'name': 'ZINX (Zimbabwe Internet Exchange)',
#   'city': 'Harare',
#   'country': 'ZW',
#   'organization_id': 266,
#   'association': 'AFIX',
#   'apis': {'ixfexport': '', 'traffic': ''},
#   'participant_count': 0,
#   'location_count': 0,
#   'updated': '2019-06-17T23:00:12Z',
#   'manrs': False}]

# %%
print ('Num IXPs in IXPDB = ', len(list_IXPs))
# Out:
# Num IXPs in IXPDB =  553

# %%
[r['traffic'] for r in  [d['apis']  for d in list_IXPs] if r['traffic']is not '']
# Out:
# ['http://stats.balt-ix.net/graph.day',
#  'https://ixpmanager.bknix.co.th/grapher/infrastructure?id=1&type=log&period=day',
#  'https://www.bcix.de/ixp/grapher/infrastructure?id=1&type=log&period=day',
#  'https://portal.crix.cr/grapher/infrastructure?id=1&type=log&period=day',
#  'https://stats-ficix.basen.com/#/page?name=Ficix1Total&source=wiki',
#  'https://stats-ficix.basen.com/#/page?name=Ficix2Total&source=wiki',
#  'https://stats-ficix.basen.com/#/page?name=Ficix3Total&source=wiki',
#  'https://portal.gr-ix.gr/grapher/infrastructure?id=1&type=log&period=day',
#  'https://portal.gr-ix.gr/grapher/infrastructure?id=3&type=log&period=day',
#  'https://portal.hix.org.zw/grapher/infrastructure?id=1&type=log&period=day',
#  'https://www.inex.ie/ixp/grapher/infrastructure?id=3&type=log&period=day',
#  'https://www.inex.ie/ixp/grapher/infrastructure?id=1&type=log&period=day',
#  'https://www.inex.ie/ixp/grapher/infrastructure?id=2&type=log&period=day',
#  'https://portal.ixp.ht/grapher/ixp?id=1&type=json',
#  'https://ixpmanager.swissix.ch/grapher/infrastructure?id=1&type=log&period=day',
#  'https://portal.uixp.co.ug/grapher/infrastructure?id=1&type=log&period=day',
#  'https://manager.minap.it/grapher/ixp?id=1&type=log&period=day',
#  'https://my.namex.it/grapher/ixp?id=1&type=log&period=day',
#  'http://ix.nap.africa/grapher/infrastructure?id=2&type=log&period=day',
#  'http://ix.nap.africa/grapher/infrastructure?id=3&type=log&period=day',
#  'https://ix.nap.africa/grapher/infrastructure?id=1&type=log&period=day',
#  'https://www.nix.cz/euroixstats.php',
#  'https://www.nix.sk/euroixstats-sk.php',
#  'https://nms2.npix.net.np/grapher/infrastructure?id=1&type=log&period=day',
#  'https://www.six.sk/stats/aggregated.log',
#  'https://portal.sthix.net/grapher/infrastructure?id=1&type=log&period=day']

# %%
#[r['name'] for r in  list_IXPs]

# %%
DB1=[]
for i in range(len(list_IXPs)):
    DB1.append({'pdb_id':list_IXPs[i]['pdb_id'],'id':list_IXPs[i]['id'],'Country':list_IXPs[i]['country'],'IXP_id':list_IXPs[i]['name'],'URL(website)':[],'Location':list_IXPs[i]['city'],'URL(Graph stats)':[]})

# %%
DB1
# Out:
# [{'pdb_id': 2239,
#   'id': 748,
#   'Country': 'BA',
#   'IXP_id': '(BHNIX) Bosnia and Herzegovina Neutral Internet Exchange',
#   'URL(website)': [],
#   'Location': 'Sarajevo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1183,
#   'id': 123,
#   'Country': 'KR',
#   'IXP_id': '6NGIX (IPv6 Next Generation Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Seoul',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1816,
#   'id': 699,
#   'Country': 'LB',
#   'IXP_id': 'A.IX (Advanced Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Beirut',
#   'URL(Graph stats)': []},
#  {'pdb_id': 377,
#   'id': 276,
#   'Country': 'AT',
#   'IXP_id': 'AAIX (Alpes Adria Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Klagenfurt',
#   'URL(Graph stats)': []},
#  {'pdb_id': 976,
#   'id': 323,
#   'Country': 'AU',
#   'IXP_id': 'ACT-IX',
#   'URL(website)': [],
#   'Location': 'Canberra',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1201,
#   'id': 212,
#   'Country': 'TZ',
#   'IXP_id': 'AIXP (Arusha Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Arusha',
#   'URL(Graph stats)': []},
#  {'pdb_id': 977,
#   'id': 586,
#   'Country': 'NZ',
#   'IXP_id': 'AKL-IX (Auckland Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Auckland',
#   'URL(Graph stats)': []},
#  {'pdb_id': 168,
#   'id': 443,
#   'Country': 'US',
#   'IXP_id': 'AMPATH (AMPATH - Florida International University/CIARA)',
#   'URL(website)': [],
#   'Location': 'Miami',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1812,
#   'id': 737,
#   'Country': 'NL',
#   'IXP_id': 'ams (Asteroid Amsterdam Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Amsterdam',
#   'URL(Graph stats)': []},
#  {'pdb_id': 26,
#   'id': 2,
#   'Country': 'NL',
#   'IXP_id': 'AMS-IX',
#   'URL(website)': [],
#   'Location': 'Amsterdam',
#   'URL(Graph stats)': []},
#  {'pdb_id': 366,
#   'id': 61,
#   'Country': 'AN',
#   'IXP_id': 'AMS-IX Caribbean',
#   'URL(website)': [],
#   'Location': 'Willemstad, Curacao',
#   'URL(Graph stats)': []},
#  {'pdb_id': 577,
#   'id': 356,
#   'Country': 'CN',
#   'IXP_id': 'AMS-IX Hong Kong',
#   'URL(website)': [],
#   'Location': 'Hong Kong',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1623,
#   'id': 619,
#   'Country': 'IN',
#   'IXP_id': 'AMS-IX India',
#   'URL(website)': [],
#   'Location': 'Mumbai',
#   'URL(Graph stats)': []},
#  {'pdb_id': 935,
#   'id': 532,
#   'Country': 'US',
#   'IXP_id': 'AMS-IX USA Bay Area',
#   'URL(website)': [],
#   'Location': 'San Francisco',
#   'URL(Graph stats)': []},
#  {'pdb_id': 944,
#   'id': 533,
#   'Country': 'US',
#   'IXP_id': 'AMS-IX USA Chicago',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 806,
#   'id': 412,
#   'Country': 'US',
#   'IXP_id': 'AMS-IX USA New York',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 421,
#   'id': 202,
#   'Country': 'AO',
#   'IXP_id': 'Angola IXP',
#   'URL(website)': [],
#   'Location': 'Luanda',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1007,
#   'id': 531,
#   'Country': 'AO',
#   'IXP_id': 'angonix',
#   'URL(website)': [],
#   'Location': 'Luanda',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2004,
#   'id': 746,
#   'Country': 'AL',
#   'IXP_id': 'ANIX (Albanian Neutral Internet eXchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 333,
#   'id': 238,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) Boston (Any2 (CoreSite) Boston)',
#   'URL(website)': [],
#   'Location': 'Boston',
#   'URL(Graph stats)': []},
#  {'pdb_id': 226,
#   'id': 239,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) Chicago (Any2 (CoreSite) Chicago)',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 205,
#   'id': 240,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) Miami (Any2 (CoreSite) Miami)',
#   'URL(website)': [],
#   'Location': 'Miami',
#   'URL(Graph stats)': []},
#  {'pdb_id': 332,
#   'id': 242,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) New York (Any2 (CoreSite) New York)',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 204,
#   'id': 243,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) NorthEast',
#   'URL(website)': [],
#   'Location': 'Reston',
#   'URL(Graph stats)': []},
#  {'pdb_id': 338,
#   'id': 241,
#   'Country': 'US',
#   'IXP_id': 'Any2 (CoreSite) Silicon Valley',
#   'URL(website)': [],
#   'Location': 'Milpitas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 97,
#   'id': 126,
#   'Country': 'NZ',
#   'IXP_id': 'APE - Auckland (Auckland Peering Exchange)',
#   'URL(website)': [],
#   'Location': 'Auckland',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1919,
#   'id': 721,
#   'Country': 'PL',
#   'IXP_id': 'APLIX.PL (APLIX)',
#   'URL(website)': [],
#   'Location': 'Gdynia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1684,
#   'id': 631,
#   'Country': 'BR',
#   'IXP_id': 'Aracaju (SE) (IX.br - Aracaju)',
#   'URL(website)': [],
#   'Location': 'Aracaju',
#   'URL(Graph stats)': []},
#  {'pdb_id': 851,
#   'id': 372,
#   'Country': 'AM',
#   'IXP_id': 'ARMIX (Armenian Internet Traffic Exchange)',
#   'URL(website)': [],
#   'Location': 'Yerevan',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1468,
#   'id': 695,
#   'Country': 'JP',
#   'IXP_id': 'Asia Smart IX (Asia Smart IX [BBIX Asia])',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1019,
#   'id': 564,
#   'Country': 'FR',
#   'IXP_id': 'AuvernIX (AuvernIX)',
#   'URL(website)': [],
#   'Location': 'Clermont Ferrand',
#   'URL(Graph stats)': []},
#  {'pdb_id': 476,
#   'id': 287,
#   'Country': 'US',
#   'IXP_id': 'AZIX (Arizona Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Phoenix',
#   'URL(Graph stats)': []},
#  {'pdb_id': 372,
#   'id': 291,
#   'Country': 'RO',
#   'IXP_id': 'Balcan-IX (Balcan-IX)',
#   'URL(website)': [],
#   'Location': 'Bucharest',
#   'URL(Graph stats)': []},
#  {'pdb_id': 326,
#   'id': 197,
#   'Country': 'BG',
#   'IXP_id': 'Balkan-IX (Balkan Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Sofia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2005,
#   'id': 741,
#   'Country': 'LT',
#   'IXP_id': 'BALT-IX (Baltic Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2186,
#   'id': 766,
#   'Country': 'US',
#   'IXP_id': 'Baltimore IX',
#   'URL(website)': [],
#   'Location': 'Baltimore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1025,
#   'id': 587,
#   'Country': 'TH',
#   'IXP_id': 'Bangkok Neutral Internet Exchange (BKNIX)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1449,
#   'id': 590,
#   'Country': 'HK',
#   'IXP_id': 'BBIX - Hong Kong',
#   'URL(website)': [],
#   'Location': 'Hong Kong',
#   'URL(Graph stats)': []},
#  {'pdb_id': 786,
#   'id': 366,
#   'Country': 'JP',
#   'IXP_id': 'BBIX - Osaka (Broadband Internet eXchange - Osaka)',
#   'URL(website)': [],
#   'Location': 'Osaka',
#   'URL(Graph stats)': []},
#  {'pdb_id': 909,
#   'id': 601,
#   'Country': 'SG',
#   'IXP_id': 'BBIX - Singapore (BBIX - Singapore)',
#   'URL(website)': [],
#   'Location': 'Singapore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 126,
#   'id': 51,
#   'Country': 'JP',
#   'IXP_id': 'BBIX - Tokyo (BroadBand Internet eXchange - Tokyo)',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2467,
#   'id': 802,
#   'Country': '',
#   'IXP_id': 'BBIX Thailand',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 87,
#   'id': 21,
#   'Country': 'DE',
#   'IXP_id': 'BCIX (BCIX Management GmbH)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2516,
#   'id': 109,
#   'Country': 'BD',
#   'IXP_id': 'BDIX - Dhaka (Bangladesh Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Dhaka',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1354,
#   'id': 147,
#   'Country': 'LB',
#   'IXP_id': 'Beirut-IX (Beirut Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Beirut',
#   'URL(Graph stats)': []},
#  {'pdb_id': 711,
#   'id': 378,
#   'Country': 'BR',
#   'IXP_id': 'Belém (BEL) (IX.br Belém (BEL))',
#   'URL(website)': [],
#   'Location': 'Belém',
#   'URL(Graph stats)': []},
#  {'pdb_id': 176,
#   'id': 154,
#   'Country': 'BR',
#   'IXP_id': 'Belo Horizonte (MG) (IX.br - Belo Horizonte (MG))',
#   'URL(website)': [],
#   'Location': 'Belo Horizonte',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1017,
#   'id': 545,
#   'Country': 'BJ',
#   'IXP_id': 'Benin-IX (Benin Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Cotonou',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1314,
#   'id': 556,
#   'Country': 'BF',
#   'IXP_id': 'BFiX Burkina Faso (Burkina Faso)',
#   'URL(website)': [],
#   'Location': 'Ouagadougou',
#   'URL(Graph stats)': []},
#  {'pdb_id': 151,
#   'id': 246,
#   'Country': 'US',
#   'IXP_id': 'Big APE (The big apple peering Exchange)',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1409,
#   'id': 203,
#   'Country': 'BW',
#   'IXP_id': 'BINX (Botswana Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Gaborone',
#   'URL(Graph stats)': []},
#  {'pdb_id': 452,
#   'id': 358,
#   'Country': 'ID',
#   'IXP_id': 'BIX - Jakarta (Biznet Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Jakarta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 55,
#   'id': 12,
#   'Country': 'HU',
#   'IXP_id': 'BiX (Budapest Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Budapest',
#   'URL(Graph stats)': []},
#  {'pdb_id': 55,
#   'id': 55,
#   'Country': 'HU',
#   'IXP_id': 'BIX (Budapest Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 582,
#   'id': 192,
#   'Country': 'NO',
#   'IXP_id': 'BIX Bergen (Bergen Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Bergen',
#   'URL(Graph stats)': []},
#  {'pdb_id': 331,
#   'id': 40,
#   'Country': 'BG',
#   'IXP_id': 'BIX.BG (Bulgarian Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Sofia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 496,
#   'id': 286,
#   'Country': 'US',
#   'IXP_id': 'BNIIX (Buffalo Niagara International Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Buffalo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 59,
#   'id': 4,
#   'Country': 'BE',
#   'IXP_id': 'BNIX (Belgian National Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Brussels',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1412,
#   'id': 273,
#   'Country': 'SE',
#   'IXP_id': 'BOR-IX (Boras Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Boras',
#   'URL(Graph stats)': []},
#  {'pdb_id': 565,
#   'id': 407,
#   'Country': 'US',
#   'IXP_id': 'BostonIX (Markley Boston Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Boston',
#   'URL(Graph stats)': []},
#  {'pdb_id': 864,
#   'id': 588,
#   'Country': 'CZ',
#   'IXP_id': 'BR-IX (Brno Internet Exchange Point)',
#   'URL(website)': [],
#   'Location': 'Brno',
#   'URL(Graph stats)': []},
#  {'pdb_id': 178,
#   'id': 155,
#   'Country': 'BR',
#   'IXP_id': 'Brasília (DF) (IX.br -  Brasília (DF))',
#   'URL(website)': [],
#   'Location': 'Brasilia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1670,
#   'id': 672,
#   'Country': 'FR',
#   'IXP_id': 'Breizh-IX (Breizh-IX)',
#   'URL(website)': [],
#   'Location': 'Rennes',
#   'URL(Graph stats)': []},
#  {'pdb_id': 796,
#   'id': 404,
#   'Country': 'DE',
#   'IXP_id': 'BREM-IX (Bremen Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Bremen',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1421,
#   'id': 620,
#   'Country': 'DE',
#   'IXP_id': 'BW-IX Karlsruhe (Baden-Württemberg Internet Exchange Karlsruhe)',
#   'URL(website)': [],
#   'Location': 'Karlsruhe',
#   'URL(Graph stats)': []},
#  {'pdb_id': 212,
#   'id': 139,
#   'Country': 'DE',
#   'IXP_id': 'BW-IX Stuttgart (Baden-Württemberg Internet Exchange Stuttgart)',
#   'URL(website)': [],
#   'Location': 'Stuttgart',
#   'URL(Graph stats)': []},
#  {'pdb_id': 275,
#   'id': 279,
#   'Country': 'BY',
#   'IXP_id': 'BYIX (Belarus National Internet Exchange Point)',
#   'URL(website)': [],
#   'Location': 'Minsk',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1068,
#   'id': 797,
#   'Country': '',
#   'IXP_id': 'CABASE-DLC - IX Argentina (Santa Teresita)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1484,
#   'id': 795,
#   'Country': '',
#   'IXP_id': 'CABASE-NGB - IX Argentina (Pilar)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2039,
#   'id': 794,
#   'Country': '',
#   'IXP_id': 'CABASE-OGB - IX Argentina (Moreno)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1486,
#   'id': 796,
#   'Country': '',
#   'IXP_id': 'CABASE-SLT - IX Argentina (Salta)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 274,
#   'id': 206,
#   'Country': 'EG',
#   'IXP_id': 'CAIX (Cairo Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Cairo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2541,
#   'id': 798,
#   'Country': '',
#   'IXP_id': 'CAMIX Douala',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2554,
#   'id': 528,
#   'Country': 'CM',
#   'IXP_id': 'CAMIX Yaounde',
#   'URL(website)': [],
#   'Location': 'Yaoundé',
#   'URL(Graph stats)': []},
#  {'pdb_id': 603,
#   'id': 283,
#   'Country': 'BR',
#   'IXP_id': 'Campina Grande (CPV) (IX.br - Campina Grande (CPV))',
#   'URL(website)': [],
#   'Location': 'Campina Grande',
#   'URL(Graph stats)': []},
#  {'pdb_id': 415,
#   'id': 262,
#   'Country': 'BR',
#   'IXP_id': 'Campinas (CAS) (IX.br - Campinas (CAS))',
#   'URL(website)': [],
#   'Location': 'Campinas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 62,
#   'id': 11,
#   'Country': 'ES',
#   'IXP_id': 'CATNIX (Catalunya Neutral Internet eXchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 558,
#   'id': 376,
#   'Country': 'BR',
#   'IXP_id': 'Caxias do Sul (CXJ) (IX.br - Caxias do Sul (CXJ))',
#   'URL(website)': [],
#   'Location': 'Caxias do Sul',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1228,
#   'id': 697,
#   'Country': 'ID',
#   'IXP_id': 'CDIX (Cyber Data Internet Xchange)',
#   'URL(website)': [],
#   'Location': 'Jakarta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 349,
#   'id': 127,
#   'Country': 'NZ',
#   'IXP_id': 'CHIX - Christchurch (Christchurch Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Christchurch',
#   'URL(Graph stats)': []},
#  {'pdb_id': 239,
#   'id': 149,
#   'Country': 'US',
#   'IXP_id': 'ChIX (Chicago Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1172,
#   'id': 582,
#   'Country': 'CN',
#   'IXP_id': 'CHN-IX Beijing',
#   'URL(website)': [],
#   'Location': 'Beijing',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1284,
#   'id': 585,
#   'Country': 'CN',
#   'IXP_id': 'CHN-IX Guangzhou',
#   'URL(website)': [],
#   'Location': 'Guangzhou',
#   'URL(Graph stats)': []},
#  {'pdb_id': 344,
#   'id': 209,
#   'Country': 'ZA',
#   'IXP_id': 'CINX - Cape Town (Cape Town Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Cape Town',
#   'URL(Graph stats)': []},
#  {'pdb_id': 810,
#   'id': 205,
#   'Country': 'CI',
#   'IXP_id': 'CIVIX (Cote d’Ivoire Internet eXchange Point)',
#   'URL(website)': [],
#   'Location': 'Abidjan',
#   'URL(Graph stats)': []},
#  {'pdb_id': 303,
#   'id': 28,
#   'Country': 'HR',
#   'IXP_id': 'CIX (Croatian Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Zagreb',
#   'URL(Graph stats)': []},
#  {'pdb_id': 778,
#   'id': 496,
#   'Country': 'PL',
#   'IXP_id': 'CIX KR (CIX - Cracow Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Krakow',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1668,
#   'id': 684,
#   'Country': 'US',
#   'IXP_id': 'CIX-ATL',
#   'URL(website)': [],
#   'Location': 'Atlanta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 33,
#   'id': 7,
#   'Country': 'CH',
#   'IXP_id': 'CIXP (CERN Internet Exchange Point)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 237,
#   'id': 457,
#   'Country': 'CN',
#   'IXP_id': 'CNC Beijing NAP (CNC Beijing NAP)',
#   'URL(website)': [],
#   'Location': 'Beijing',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1303,
#   'id': 604,
#   'Country': 'CN',
#   'IXP_id': 'CNIX (China Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Beijing',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1209,
#   'id': 432,
#   'Country': 'KH',
#   'IXP_id': 'CNX (Cambodian Network Exchange)',
#   'URL(website)': [],
#   'Location': 'Phnom Penh',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1229,
#   'id': 696,
#   'Country': 'RU',
#   'IXP_id': 'COD-IX (COD-IX)',
#   'URL(website)': [],
#   'Location': 'St. Petersburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 514,
#   'id': 477,
#   'Country': 'US',
#   'IXP_id': 'COIX (Central Oregon Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Bend Oregon',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1329,
#   'id': 747,
#   'Country': '',
#   'IXP_id': 'Community-IX DE',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 254,
#   'id': 257,
#   'Country': 'US',
#   'IXP_id': 'CoreSite - Any2 Denver / RMIX Denver (CoreSite - Any2 Denver / RMIX Denver)',
#   'URL(website)': [],
#   'Location': 'Denver',
#   'URL(Graph stats)': []},
#  {'pdb_id': 142,
#   'id': 52,
#   'Country': 'US',
#   'IXP_id': 'CoreSite - Any2 Los Angeles (CoreSite - Any2 Los Angeles)',
#   'URL(website)': [],
#   'Location': 'Los Angeles',
#   'URL(Graph stats)': []},
#  {'pdb_id': 287,
#   'id': 186,
#   'Country': 'RU',
#   'IXP_id': 'Crimea-IX (Crimea-IX)',
#   'URL(website)': [],
#   'Location': 'Crimea Republic, Simferopol',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1023,
#   'id': 541,
#   'Country': 'CR',
#   'IXP_id': 'CRIX (NIC Costa Rica - Academia Nacional de Ciencias)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 859,
#   'id': 500,
#   'Country': 'BR',
#   'IXP_id': 'Cuiabá (CGB) (IX.br - Cuiabá (CGB))',
#   'URL(website)': [],
#   'Location': 'Cuiabá',
#   'URL(Graph stats)': []},
#  {'pdb_id': 174,
#   'id': 156,
#   'Country': 'BR',
#   'IXP_id': 'Curitiba (PR) (IX.br - Curitiba (PR))',
#   'URL(website)': [],
#   'Location': 'Curitiba',
#   'URL(Graph stats)': []},
#  {'pdb_id': 487,
#   'id': 73,
#   'Country': 'CY',
#   'IXP_id': 'CyIX (Cyprus Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Nicosia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 674,
#   'id': 640,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Austin (CyrusOne IX Austin)',
#   'URL(website)': [],
#   'Location': 'Austin',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1142,
#   'id': 643,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Chicago (CyrusOne IX Chicago)',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 672,
#   'id': 353,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Dallas (CyrusOne IX Dallas)',
#   'URL(website)': [],
#   'Location': 'Carrollton',
#   'URL(Graph stats)': []},
#  {'pdb_id': 673,
#   'id': 639,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Houston (CyrusOne IX Houston)',
#   'URL(website)': [],
#   'Location': 'Houston',
#   'URL(Graph stats)': []},
#  {'pdb_id': 760,
#   'id': 642,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Phoenix (CyrusOne IX Phoenix)',
#   'URL(website)': [],
#   'Location': 'Phoenix',
#   'URL(Graph stats)': []},
#  {'pdb_id': 675,
#   'id': 641,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX San Antonio (CyrusOne IX San Antonio)',
#   'URL(website)': [],
#   'Location': 'San Antonio',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1117,
#   'id': 644,
#   'Country': 'US',
#   'IXP_id': 'CyrusOne IX Sterling (CyrusOne IX Sterling)',
#   'URL(website)': [],
#   'Location': 'Sterling',
#   'URL(Graph stats)': []},
#  {'pdb_id': 358,
#   'id': 522,
#   'Country': 'RU',
#   'IXP_id': 'DataIX - Moscow (DataIX - Moscow)',
#   'URL(website)': [],
#   'Location': 'Moscow',
#   'URL(Graph stats)': []},
#  {'pdb_id': 358,
#   'id': 524,
#   'Country': 'RU',
#   'IXP_id': 'DataIX - Novosibirsk (DataIX - Novosibirsk)',
#   'URL(website)': [],
#   'Location': 'Novosibirsk',
#   'URL(Graph stats)': []},
#  {'pdb_id': 358,
#   'id': 403,
#   'Country': 'RU',
#   'IXP_id': 'DataIX - St Petersburg (DataIX - St Petersburg)',
#   'URL(website)': [],
#   'Location': 'St Petersburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 358,
#   'id': 523,
#   'Country': 'RU',
#   'IXP_id': 'DataIX - Ufa (DataIX - Ufa)',
#   'URL(website)': [],
#   'Location': 'Ufa',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1387,
#   'id': 567,
#   'Country': 'RU',
#   'IXP_id': 'DataLine-IX (DataLine-IX)',
#   'URL(website)': [],
#   'Location': 'Moscow',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1249,
#   'id': 580,
#   'Country': 'US',
#   'IXP_id': 'DE-CIX Dallas (DE-CIX Dallas)',
#   'URL(website)': [],
#   'Location': 'Dallas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2587,
#   'id': 688,
#   'Country': 'IN',
#   'IXP_id': 'DE-CIX Delhi',
#   'URL(website)': [],
#   'Location': 'Delhi',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1214,
#   'id': 565,
#   'Country': 'DE',
#   'IXP_id': 'DE-CIX DUS (DE-CIX Dusseldorf)',
#   'URL(website)': [],
#   'Location': 'Dusseldorf',
#   'URL(Graph stats)': []},
#  {'pdb_id': 31,
#   'id': 9,
#   'Country': 'DE',
#   'IXP_id': 'DE-CIX FRA (DE-CIX Frankfurt)',
#   'URL(website)': [],
#   'Location': 'Frankfurt am Main',
#   'URL(Graph stats)': []},
#  {'pdb_id': 74,
#   'id': 47,
#   'Country': 'DE',
#   'IXP_id': 'DE-CIX HAM (DE-CIX Hamburg)',
#   'URL(website)': [],
#   'Location': 'Hamburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1150,
#   'id': 560,
#   'Country': 'TR',
#   'IXP_id': 'DE-CIX Istanbul (DE-CIX Istanbul)',
#   'URL(website)': [],
#   'Location': 'Istanbul',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2589,
#   'id': 689,
#   'Country': 'IN',
#   'IXP_id': 'DE-CIX Kolkata',
#   'URL(website)': [],
#   'Location': 'Kolkata',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2531,
#   'id': 765,
#   'Country': 'PT',
#   'IXP_id': 'DE-CIX LIS (DE-CIX Lisbon)',
#   'URL(website)': [],
#   'Location': 'Lisbon',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1277,
#   'id': 470,
#   'Country': 'ES',
#   'IXP_id': 'DE-CIX MAD (DE-CIX Madrid)',
#   'URL(website)': [],
#   'Location': 'Madrid',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1149,
#   'id': 559,
#   'Country': 'FR',
#   'IXP_id': 'DE-CIX Marseille (DE-CIX Marseille)',
#   'URL(website)': [],
#   'Location': 'Marseilles',
#   'URL(Graph stats)': []},
#  {'pdb_id': 248,
#   'id': 54,
#   'Country': 'DE',
#   'IXP_id': 'DE-CIX MUC (DE-CIX Munich)',
#   'URL(website)': [],
#   'Location': 'Munich',
#   'URL(Graph stats)': []},
#  {'pdb_id': 804,
#   'id': 425,
#   'Country': 'US',
#   'IXP_id': 'DE-CIX NYC (DE-CIX New York)',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1131,
#   'id': 558,
#   'Country': 'IT',
#   'IXP_id': 'DE-CIX PMO (DE-CIX Palermo)',
#   'URL(website)': [],
#   'Location': 'Palermo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1006,
#   'id': 662,
#   'Country': 'US',
#   'IXP_id': 'DET-IX (Detroit Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Detroit',
#   'URL(Graph stats)': []},
#  {'pdb_id': 22,
#   'id': 56,
#   'Country': 'US',
#   'IXP_id': 'Digital Realty - Atlanta (Digital Realty Exchange - Atlanta)',
#   'URL(website)': [],
#   'Location': 'Atlanta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 322,
#   'id': 229,
#   'Country': 'US',
#   'IXP_id': 'Digital Realty - Dallas (Digital Realty  Dallas)',
#   'URL(website)': [],
#   'Location': 'Dallas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 325,
#   'id': 230,
#   'Country': 'US',
#   'IXP_id': 'Digital Realty - New York (Digital Realty New York)',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 256,
#   'id': 231,
#   'Country': 'US',
#   'IXP_id': 'Digital Realty - Phoenix (Digital Realty Phoenix)',
#   'URL(website)': [],
#   'Location': 'Phoenix',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2572,
#   'id': 253,
#   'Country': 'US',
#   'IXP_id': 'Digital Realty Ashburn',
#   'URL(website)': [],
#   'Location': 'Vienna',
#   'URL(Graph stats)': []},
#  {'pdb_id': 78,
#   'id': 29,
#   'Country': 'DK',
#   'IXP_id': 'DIX',
#   'URL(website)': [],
#   'Location': 'Lyngby',
#   'URL(Graph stats)': []},
#  {'pdb_id': 92,
#   'id': 441,
#   'Country': 'JP',
#   'IXP_id': 'DIX-IE (Distributed IX in EDO)',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 967,
#   'id': 549,
#   'Country': 'DJ',
#   'IXP_id': 'DjIX (Djibouti IX)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 766,
#   'id': 322,
#   'Country': 'UA',
#   'IXP_id': 'DN-IX (Donetsk Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Donetsk',
#   'URL(Graph stats)': []},
#  {'pdb_id': 762,
#   'id': 463,
#   'Country': 'DE',
#   'IXP_id': 'DO-IX (DOrtmund Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Dortmund',
#   'URL(Graph stats)': []},
#  {'pdb_id': 267,
#   'id': 270,
#   'Country': 'US',
#   'IXP_id': 'DRF IX (DRFortress Exchange)',
#   'URL(website)': [],
#   'Location': 'Honolulu',
#   'URL(Graph stats)': []},
#  {'pdb_id': 327,
#   'id': 198,
#   'Country': 'UA',
#   'IXP_id': 'DTEL-IX (Digital Telecom Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Kiev',
#   'URL(Graph stats)': []},
#  {'pdb_id': 610,
#   'id': 487,
#   'Country': 'ZA',
#   'IXP_id': 'Durban Internet Exchange Point (INX)',
#   'URL(website)': [],
#   'Location': 'Durban',
#   'URL(Graph stats)': []},
#  {'pdb_id': 602,
#   'id': 485,
#   'Country': 'JP',
#   'IXP_id': 'Echigo-IX (Echigo Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Niigata',
#   'URL(Graph stats)': []},
#  {'pdb_id': 209,
#   'id': 30,
#   'Country': 'DE',
#   'IXP_id': 'ECIX-BER',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 91,
#   'id': 340,
#   'Country': 'DE',
#   'IXP_id': 'ECIX-DUS',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 676,
#   'id': 431,
#   'Country': 'DE',
#   'IXP_id': 'ECIX-FRA',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 291,
#   'id': 341,
#   'Country': 'DE',
#   'IXP_id': 'ECIX-HAM',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 73,
#   'id': 77,
#   'Country': 'DE',
#   'IXP_id': 'ECIX-MUC',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1786,
#   'id': 772,
#   'Country': 'IN',
#   'IXP_id': 'EIX Chennai (Extreme Internet Exchange India)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1323,
#   'id': 683,
#   'Country': 'IN',
#   'IXP_id': 'EIX Delhi (Extreme Internet Exchange India)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1785,
#   'id': 773,
#   'Country': 'IN',
#   'IXP_id': 'EIX Hyderabad (Extreme Internet Exchange India)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2167,
#   'id': 771,
#   'Country': 'IN',
#   'IXP_id': 'EIX Kolkata (Extreme Internet Exchange India)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1627,
#   'id': 694,
#   'Country': 'IN',
#   'IXP_id': 'EIX Mumbai (Extreme Internet Exchange India)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 350,
#   'id': 169,
#   'Country': 'RU',
#   'IXP_id': 'ekt-ix (EKT-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'Ekaterinburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 491,
#   'id': 548,
#   'Country': 'PL',
#   'IXP_id': 'EPIX (e-Poludnie Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 474,
#   'id': 436,
#   'Country': 'PL',
#   'IXP_id': 'EPIX Warsaw (e-Poludnie Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2031,
#   'id': 779,
#   'Country': '',
#   'IXP_id': 'Equinix Amsterdam',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1,
#   'id': 68,
#   'Country': 'US',
#   'IXP_id': 'Equinix Ashburn (Equinix Ashburn)',
#   'URL(website)': [],
#   'Location': 'Ashburn',
#   'URL(Graph stats)': []},
#  {'pdb_id': 9,
#   'id': 439,
#   'Country': 'US',
#   'IXP_id': 'Equinix Atlanta (Equinix Atlanta)',
#   'URL(website)': [],
#   'Location': 'Atlanta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2289,
#   'id': 776,
#   'Country': 'CO',
#   'IXP_id': 'Equinix Bogotá',
#   'URL(website)': [],
#   'Location': 'Bogotá',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2,
#   'id': 236,
#   'Country': 'US',
#   'IXP_id': 'Equinix Chicago (Equinix Chicago)',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 3,
#   'id': 235,
#   'Country': 'US',
#   'IXP_id': 'Equinix Dallas (Equinix Dallas)',
#   'URL(website)': [],
#   'Location': 'Dallas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2182,
#   'id': 780,
#   'Country': '',
#   'IXP_id': 'Equinix Denver',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1926,
#   'id': 714,
#   'Country': 'IE',
#   'IXP_id': 'Equinix Dublin (Equinix Dublin)',
#   'URL(website)': [],
#   'Location': 'Dublin',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1998,
#   'id': 715,
#   'Country': 'DE',
#   'IXP_id': 'Equinix Frankfurt (Equinix Frankfurt)',
#   'URL(website)': [],
#   'Location': 'Frankfurt',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1464,
#   'id': 440,
#   'Country': 'AT',
#   'IXP_id': 'Equinix Helsinki (Equinix Helsinki)',
#   'URL(website)': [],
#   'Location': 'Helsinki',
#   'URL(Graph stats)': []},
#  {'pdb_id': 125,
#   'id': 180,
#   'Country': 'HK',
#   'IXP_id': 'Equinix Hong Kong (Equinix Hong Kong Exchange)',
#   'URL(website)': [],
#   'Location': 'Hong Kong',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2183,
#   'id': 781,
#   'Country': '',
#   'IXP_id': 'Equinix Houston',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2131,
#   'id': 782,
#   'Country': '',
#   'IXP_id': 'Equinix Lisbon',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1997,
#   'id': 716,
#   'Country': 'GB',
#   'IXP_id': 'Equinix London (Equinix London)',
#   'URL(website)': [],
#   'Location': 'London',
#   'URL(Graph stats)': []},
#  {'pdb_id': 4,
#   'id': 234,
#   'Country': 'US',
#   'IXP_id': 'Equinix Los Angeles (Equinix Los Angeles)',
#   'URL(website)': [],
#   'Location': 'Los Angeles',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2130,
#   'id': 783,
#   'Country': '',
#   'IXP_id': 'Equinix Madrid',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1927,
#   'id': 717,
#   'Country': 'GB',
#   'IXP_id': 'Equinix Manchester (Equinix Manchester)',
#   'URL(website)': [],
#   'Location': 'Manchester',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1026,
#   'id': 568,
#   'Country': 'AU',
#   'IXP_id': 'Equinix Melbourne (Equinix Melbourne)',
#   'URL(website)': [],
#   'Location': 'Melbourne',
#   'URL(Graph stats)': []},
#  {'pdb_id': 593,
#   'id': 484,
#   'Country': 'US',
#   'IXP_id': 'Equinix Miami (Equinix Miami)',
#   'URL(website)': [],
#   'Location': 'Miami',
#   'URL(Graph stats)': []},
#  {'pdb_id': 17,
#   'id': 784,
#   'Country': '',
#   'IXP_id': 'Equinix Miami (formerly NOTA)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1925,
#   'id': 719,
#   'Country': 'IT',
#   'IXP_id': 'Equinix Milan (Equinix Milan)',
#   'URL(website)': [],
#   'Location': 'Milan',
#   'URL(Graph stats)': []},
#  {'pdb_id': 12,
#   'id': 237,
#   'Country': 'US',
#   'IXP_id': 'Equinix New York (Equinix New York)',
#   'URL(website)': [],
#   'Location': 'New York',
#   'URL(Graph stats)': []},
#  {'pdb_id': 948,
#   'id': 651,
#   'Country': 'JP',
#   'IXP_id': 'Equinix Osaka (Equinix Osaka)',
#   'URL(website)': [],
#   'Location': 'Osaka',
#   'URL(Graph stats)': []},
#  {'pdb_id': 7,
#   'id': 251,
#   'Country': 'US',
#   'IXP_id': 'Equinix Palo Alto (Equinix Palo Alto)',
#   'URL(website)': [],
#   'Location': 'Palo Alto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 255,
#   'id': 39,
#   'Country': 'FR',
#   'IXP_id': 'Equinix Paris (Equinix Internet Exchange - Paris)',
#   'URL(website)': [],
#   'Location': 'Paris',
#   'URL(Graph stats)': []},
#  {'pdb_id': 5,
#   'id': 233,
#   'Country': 'US',
#   'IXP_id': 'Equinix San Jose (Equinix San Jose)',
#   'URL(website)': [],
#   'Location': 'San Jose',
#   'URL(Graph stats)': []},
#  {'pdb_id': 119,
#   'id': 215,
#   'Country': 'BR',
#   'IXP_id': 'Equinix São Paulo',
#   'URL(website)': [],
#   'Location': 'Sao Paulo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 11,
#   'id': 343,
#   'Country': 'US',
#   'IXP_id': 'Equinix Seattle (Equinix Seattle)',
#   'URL(website)': [],
#   'Location': 'Seattle',
#   'URL(Graph stats)': []},
#  {'pdb_id': 158,
#   'id': 181,
#   'Country': 'SG',
#   'IXP_id': 'Equinix Singapore (Equinix Singapore Exchange)',
#   'URL(website)': [],
#   'Location': 'Singapore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1923,
#   'id': 718,
#   'Country': 'SE',
#   'IXP_id': 'Equinix Stockholm (Equinix Stockholm)',
#   'URL(website)': [],
#   'Location': 'Stockholm',
#   'URL(Graph stats)': []},
#  {'pdb_id': 94,
#   'id': 179,
#   'Country': 'AU',
#   'IXP_id': 'Equinix Sydney (Equinix Sydney Data Centers)',
#   'URL(website)': [],
#   'Location': 'Sydney',
#   'URL(Graph stats)': []},
#  {'pdb_id': 167,
#   'id': 182,
#   'Country': 'JP',
#   'IXP_id': 'Equinix Tokyo (Equinix Tokyo Exchange)',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 373,
#   'id': 344,
#   'Country': 'CA',
#   'IXP_id': 'Equinix Toronto (Equinix Toronto)',
#   'URL(website)': [],
#   'Location': 'Toronto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 10,
#   'id': 785,
#   'Country': '',
#   'IXP_id': 'Equinix Vienna (VA)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 264,
#   'id': 36,
#   'Country': 'PL',
#   'IXP_id': 'Equinix WA IX (Equinix Warsaw)',
#   'URL(website)': [],
#   'Location': 'Warsaw',
#   'URL(Graph stats)': []},
#  {'pdb_id': 29,
#   'id': 22,
#   'Country': 'CH',
#   'IXP_id': 'Equinix Zurich (Equinix Internet Exchange - Zurich)',
#   'URL(website)': [],
#   'Location': 'Zurich',
#   'URL(Graph stats)': []},
#  {'pdb_id': 63,
#   'id': 62,
#   'Country': 'ES',
#   'IXP_id': 'ESPANIX Madrid Lower LAN',
#   'URL(website)': [],
#   'Location': 'Madrid',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1146,
#   'id': 667,
#   'Country': 'ES',
#   'IXP_id': 'ESPANIX Madrid Upper LAN',
#   'URL(website)': [],
#   'Location': 'Madrid',
#   'URL(Graph stats)': []},
#  {'pdb_id': 148,
#   'id': 302,
#   'Country': 'FR',
#   'IXP_id': 'EuroGIX (European Global Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Strasbourg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2274,
#   'id': 756,
#   'Country': 'US',
#   'IXP_id': 'EVIX (Experimental Virtual Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1332,
#   'id': 171,
#   'Country': 'FI',
#   'IXP_id': 'FICIX - Espoo (Finnish Communication and Internet Exchange - Espoo)',
#   'URL(website)': [],
#   'Location': 'Espoo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 98,
#   'id': 23,
#   'Country': 'FI',
#   'IXP_id': 'FICIX - Helsinki (Finnish Communication and Internet Exchange - Helsinki)',
#   'URL(website)': [],
#   'Location': 'Helsinki',
#   'URL(Graph stats)': []},
#  {'pdb_id': 492,
#   'id': 172,
#   'Country': 'FI',
#   'IXP_id': 'FICIX - Oulu (Finnish Communication and Internet Exchange - Oulu)',
#   'URL(website)': [],
#   'Location': 'Oulu',
#   'URL(Graph stats)': []},
#  {'pdb_id': 453,
#   'id': 150,
#   'Country': 'NO',
#   'IXP_id': 'FIXO (Free Internet eXchange Oslo)',
#   'URL(website)': [],
#   'Location': 'Oslo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 954,
#   'id': 543,
#   'Country': 'US',
#   'IXP_id': 'FL-IX (Florida Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Florida',
#   'URL(Graph stats)': []},
#  {'pdb_id': 175,
#   'id': 157,
#   'Country': 'BR',
#   'IXP_id': 'Florianópolis (SC) (IX.br - Florianópolis (SC))',
#   'URL(website)': [],
#   'Location': 'Florianopolis ',
#   'URL(Graph stats)': []},
#  {'pdb_id': 710,
#   'id': 263,
#   'Country': 'BR',
#   'IXP_id': 'Fortaleza (CE) (IX.br - Fortaleza (CE))',
#   'URL(website)': [],
#   'Location': 'Fortaleza',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1276,
#   'id': 616,
#   'Country': 'BR',
#   'IXP_id': 'Foz do Iguaçu (IGU) (IX.br - Foz do Iguaçu (IGU))',
#   'URL(website)': [],
#   'Location': 'Foz do Iguaçu',
#   'URL(Graph stats)': []},
#  {'pdb_id': 880,
#   'id': 434,
#   'Country': 'FR',
#   'IXP_id': 'France-IX (FranceIX Marseille)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 359,
#   'id': 41,
#   'Country': 'FR',
#   'IXP_id': 'France-IX (FranceIX Paris)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 0,
#   'id': 59,
#   'Country': 'IT',
#   'IXP_id': 'FVG-IX (Friuli Venezia Giulia Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Udine',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1776,
#   'id': 807,
#   'Country': 'GA',
#   'IXP_id': 'Gabon Internet eXchange (GABIX)',
#   'URL(website)': [],
#   'Location': 'Libreville',
#   'URL(Graph stats)': []},
#  {'pdb_id': 640,
#   'id': 491,
#   'Country': 'US',
#   'IXP_id': 'GCIIX (Greater Chicago International Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Chicago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1094,
#   'id': 632,
#   'Country': 'CH',
#   'IXP_id': 'GE-CIX (GE-CIX)',
#   'URL(website)': [],
#   'Location': 'Zurich',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2345,
#   'id': 755,
#   'Country': 'PH',
#   'IXP_id': 'GetaFIX',
#   'URL(website)': [],
#   'Location': 'Manila',
#   'URL(Graph stats)': []},
#  {'pdb_id': 655,
#   'id': 165,
#   'Country': 'UA',
#   'IXP_id': 'Giganet (Giganet)',
#   'URL(website)': [],
#   'Location': 'kiev',
#   'URL(Graph stats)': []},
#  {'pdb_id': 72,
#   'id': 10,
#   'Country': 'PT',
#   'IXP_id': 'GIGAPIX (Gigabit Portuguese Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 694,
#   'id': 92,
#   'Country': 'GH',
#   'IXP_id': 'GIX - Accra (Ghana Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Accra',
#   'URL(Graph stats)': []},
#  {'pdb_id': 146,
#   'id': 103,
#   'Country': 'SE',
#   'IXP_id': 'GIX (Gothenburg Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Gothenburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 498,
#   'id': 474,
#   'Country': 'PL',
#   'IXP_id': 'GIX Gdansk (Gdansk Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Gdansk',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1088,
#   'id': 581,
#   'Country': 'RU',
#   'IXP_id': 'Global-IX (Global-IX)',
#   'URL(website)': [],
#   'Location': 'Saint Petersburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 76,
#   'id': 24,
#   'Country': 'NL',
#   'IXP_id': 'GN-IX (Groningen Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Groningen',
#   'URL(Graph stats)': []},
#  {'pdb_id': 575,
#   'id': 284,
#   'Country': 'BR',
#   'IXP_id': 'Goiânia (GYN) (IX.br - Goiânia (GYN))',
#   'URL(website)': [],
#   'Location': 'Goiania',
#   'URL(Graph stats)': []},
#  {'pdb_id': 281,
#   'id': 57,
#   'Country': 'EG',
#   'IXP_id': 'GPX MEIX (Middle East Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Cairo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 347,
#   'id': 752,
#   'Country': 'GR',
#   'IXP_id': 'GR-IX::Athens (Greek Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2386,
#   'id': 753,
#   'Country': 'GR',
#   'IXP_id': 'GR-IX::Thessaloniki (Greek Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 430,
#   'id': 348,
#   'Country': 'AT',
#   'IXP_id': 'GraX (Grazer Internet Exchange )',
#   'URL(website)': [],
#   'Location': 'Graz',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1428,
#   'id': 527,
#   'Country': 'FR',
#   'IXP_id': 'GrenoblIX (Grenoble Internet eXchange Point)',
#   'URL(website)': [],
#   'Location': 'Grenoble',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1790,
#   'id': 539,
#   'Country': 'GD',
#   'IXP_id': 'GREX (Grenada Internet Exchange)',
#   'URL(website)': [],
#   'Location': "St. George's",
#   'URL(Graph stats)': []},
#  {'pdb_id': 506,
#   'id': 476,
#   'Country': 'CA',
#   'IXP_id': 'GTIIX (Greater Toronto IIX)',
#   'URL(website)': [],
#   'Location': 'Toronto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 463,
#   'id': 472,
#   'Country': 'GU',
#   'IXP_id': 'GU-IX (Guam Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Hagåtña',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1134,
#   'id': 530,
#   'Country': 'GY',
#   'IXP_id': 'Guyanix (Guyana Internet Exchange Point)',
#   'URL(website)': [],
#   'Location': 'Cayenne',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2617,
#   'id': 730,
#   'Country': 'ZW',
#   'IXP_id': 'Harare IX (Harare Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Harare',
#   'URL(Graph stats)': []},
#  {'pdb_id': 906,
#   'id': 659,
#   'Country': 'CA',
#   'IXP_id': 'HFXIX (Halifax Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Halifax',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1836,
#   'id': 184,
#   'Country': 'NZ',
#   'IXP_id': 'HIX - Hamilton (Hamilton Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Hamilton',
#   'URL(Graph stats)': []},
#  {'pdb_id': 189,
#   'id': 201,
#   'Country': 'US',
#   'IXP_id': 'HIX - Honolulu (Hawaii Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Honolulu',
#   'URL(Graph stats)': []},
#  {'pdb_id': 42,
#   'id': 110,
#   'Country': 'HK',
#   'IXP_id': 'HKIX (Hong Kong Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Hong Kong',
#   'URL(Graph stats)': []},
#  {'pdb_id': 854,
#   'id': 136,
#   'Country': 'KH',
#   'IXP_id': 'HTN-IX (Cambodia Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Phnom Penh',
#   'URL(Graph stats)': []},
#  {'pdb_id': 88,
#   'id': 331,
#   'Country': 'HK',
#   'IXP_id': 'iAIX  (iAdvantage Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Hong Kong',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2051,
#   'id': 727,
#   'Country': 'UA',
#   'IXP_id': 'IF-IX (Ivano-Frankivsk Internet Exchnage)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 393,
#   'id': 112,
#   'Country': 'IL',
#   'IXP_id': 'IIX - Tel Aviv (Israeli Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Tel-Aviv',
#   'URL(Graph stats)': []},
#  {'pdb_id': 210,
#   'id': 111,
#   'Country': 'ID',
#   'IXP_id': 'IIX Jakarta',
#   'URL(website)': [],
#   'Location': 'Jakarta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 626,
#   'id': 361,
#   'Country': 'ID',
#   'IXP_id': 'IIX Surabaya',
#   'URL(website)': [],
#   'Location': 'Surabaya ',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1262,
#   'id': 646,
#   'Country': 'IE',
#   'IXP_id': 'INEX Cork (Internet Neutral Exchange Association Limited by Guarantee)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 48,
#   'id': 20,
#   'Country': 'IE',
#   'IXP_id': 'INEX LAN1 (Internet Neutral Exchange Association Limited by Guarantee)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 387,
#   'id': 645,
#   'Country': 'IE',
#   'IXP_id': 'INEX LAN2 (Internet Neutral Exchange Association Limited by Guarantee)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 573,
#   'id': 488,
#   'Country': 'HT',
#   'IXP_id': 'Infrastructure #1 (AHTIC Internet eXchange Point)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 60,
#   'id': 34,
#   'Country': 'CH',
#   'IXP_id': 'Infrastructure #1 (SwissIX Internet Exchang)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 270,
#   'id': 37,
#   'Country': 'RO',
#   'IXP_id': 'InterLAN Internet Exchange (Interlan IX)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1577,
#   'id': 617,
#   'Country': 'IN',
#   'IXP_id': 'IX Kolkata (IIFON IX Kolkata)',
#   'URL(website)': [],
#   'Location': 'Kolkata',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1302,
#   'id': 578,
#   'Country': 'GB',
#   'IXP_id': 'IX Liverpool (IX Liverpool)',
#   'URL(website)': [],
#   'Location': 'Liverpool',
#   'URL(Graph stats)': []},
#  {'pdb_id': 984,
#   'id': 572,
#   'Country': 'NZ',
#   'IXP_id': 'IX-AKL (Auckland IX)',
#   'URL(website)': [],
#   'Location': 'Auckland',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1178,
#   'id': 608,
#   'Country': 'US',
#   'IXP_id': 'IX-ASH (Ashburn IX)',
#   'URL(website)': [],
#   'Location': 'Ashburn',
#   'URL(Graph stats)': []},
#  {'pdb_id': 781,
#   'id': 606,
#   'Country': 'AU',
#   'IXP_id': 'IX-BNE (Brisbane IX)',
#   'URL(website)': [],
#   'Location': 'Brisbane',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1180,
#   'id': 610,
#   'Country': 'US',
#   'IXP_id': 'IX-DAL (Dallas IX)',
#   'URL(website)': [],
#   'Location': 'Dallas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1207,
#   'id': 650,
#   'Country': 'US',
#   'IXP_id': 'IX-Denver (Interconnection Exchange Denver)',
#   'URL(website)': [],
#   'Location': 'Denver',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1628,
#   'id': 647,
#   'Country': 'US',
#   'IXP_id': 'IX-LAS (Las Vegas IX)',
#   'URL(website)': [],
#   'Location': 'Las Vegas',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1175,
#   'id': 611,
#   'Country': 'US',
#   'IXP_id': 'IX-LAX (Los Angeles IX)',
#   'URL(website)': [],
#   'Location': 'Los Angeles',
#   'URL(Graph stats)': []},
#  {'pdb_id': 779,
#   'id': 563,
#   'Country': 'AU',
#   'IXP_id': 'IX-MEL (Melbourne IX)',
#   'URL(website)': [],
#   'Location': 'Melbourne',
#   'URL(Graph stats)': []},
#  {'pdb_id': 815,
#   'id': 194,
#   'Country': 'RU',
#   'IXP_id': 'IX-NN (IX of Nizhny Novgorod)',
#   'URL(website)': [],
#   'Location': 'Nizhny Novgorod',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1235,
#   'id': 607,
#   'Country': 'AU',
#   'IXP_id': 'IX-PER (Perth IX)',
#   'URL(website)': [],
#   'Location': 'Perth',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1174,
#   'id': 613,
#   'Country': 'US',
#   'IXP_id': 'IX-SEA (Seattle IX)',
#   'URL(website)': [],
#   'Location': 'Seattle',
#   'URL(Graph stats)': []},
#  {'pdb_id': 965,
#   'id': 574,
#   'Country': 'SG',
#   'IXP_id': 'IX-SIN (Singapore IX)',
#   'URL(website)': [],
#   'Location': 'Singapore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1056,
#   'id': 731,
#   'Country': 'BG',
#   'IXP_id': 'IX-SOF (Sofia IX)',
#   'URL(website)': [],
#   'Location': 'Sofia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 780,
#   'id': 570,
#   'Country': 'AU',
#   'IXP_id': 'IX-SYD (Sydney IX)',
#   'URL(website)': [],
#   'Location': 'Sydney',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1307,
#   'id': 575,
#   'Country': 'CA',
#   'IXP_id': 'IX-TOR (Toronto IX)',
#   'URL(website)': [],
#   'Location': 'Toronto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1983,
#   'id': 787,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) João Pessoa',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2291,
#   'id': 788,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) Maceió',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1847,
#   'id': 789,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) Santa Maria',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2086,
#   'id': 790,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) São Luís',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 171,
#   'id': 791,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) São Paulo',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2078,
#   'id': 792,
#   'Country': '',
#   'IXP_id': 'IX.br (PTT.br) Teresina',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1516,
#   'id': 540,
#   'Country': 'PL',
#   'IXP_id': 'IX.LODZ.PL (Lodz Telecommunication Node)',
#   'URL(website)': [],
#   'Location': 'Lodz',
#   'URL(Graph stats)': []},
#  {'pdb_id': 435,
#   'id': 281,
#   'Country': 'GB',
#   'IXP_id': 'IXLeeds (Leeds Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Leeds',
#   'URL(Graph stats)': []},
#  {'pdb_id': 231,
#   'id': 106,
#   'Country': 'SE',
#   'IXP_id': 'IXOR (Internet eXchange point of the Oresund Region)',
#   'URL(website)': [],
#   'Location': 'Malmoe',
#   'URL(Graph stats)': []},
#  {'pdb_id': 842,
#   'id': 428,
#   'Country': 'BO',
#   'IXP_id': 'IXP-MegaLink (IXP MegaLink)',
#   'URL(website)': [],
#   'Location': 'La Paz',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2276,
#   'id': 760,
#   'Country': 'MK',
#   'IXP_id': 'IXP.Mk',
#   'URL(website)': [],
#   'Location': 'skopje',
#   'URL(Graph stats)': []},
#  {'pdb_id': 488,
#   'id': 60,
#   'Country': 'NG',
#   'IXP_id': 'IXPN (Internet Exchange Point of Nigeria)',
#   'URL(website)': [],
#   'Location': 'Lagos',
#   'URL(Graph stats)': []},
#  {'pdb_id': 129,
#   'id': 95,
#   'Country': 'ZA',
#   'IXP_id': 'Johannesburg Internet Exchange Point (INX)',
#   'URL(website)': [],
#   'Location': ' Johannesburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2279,
#   'id': 764,
#   'Country': 'MY',
#   'IXP_id': 'Johor Bahru Internet Exchange (Johor Bahru Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 564,
#   'id': 119,
#   'Country': 'JP',
#   'IXP_id': 'JPIX - Osaka (Japan Internet Exchange - Osaka)',
#   'URL(website)': [],
#   'Location': 'Osaka',
#   'URL(Graph stats)': []},
#  {'pdb_id': 30,
#   'id': 44,
#   'Country': 'JP',
#   'IXP_id': 'JPIX - Tokyo (Japan Internet Exchange - Tokyo)',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 145,
#   'id': 120,
#   'Country': 'JP',
#   'IXP_id': 'JPNAP - Osaka (Japan Network Access Point - Osaka)',
#   'URL(website)': [],
#   'Location': 'Osaka',
#   'URL(Graph stats)': []},
#  {'pdb_id': 95,
#   'id': 42,
#   'Country': 'JP',
#   'IXP_id': 'JPNAP - Tokyo (Japan Network Access Point - Tokyo)',
#   'URL(website)': [],
#   'Location': 'Tokyo',
#   'URL(Graph stats)': []},
#  {'pdb_id': 563,
#   'id': 417,
#   'Country': 'US',
# ...
#   'URL(website)': [],
#   'Location': 'Rio de Janeiro',
#   'URL(Graph stats)': []},
#  {'pdb_id': 228,
#   'id': 33,
#   'Country': 'IS',
#   'IXP_id': 'RIX (Reykjavik Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 380,
#   'id': 178,
#   'Country': 'RU',
#   'IXP_id': 'rnd-ix (RND-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'Rostov on Don',
#   'URL(Graph stats)': []},
#  {'pdb_id': 301,
#   'id': 16,
#   'Country': 'RO',
#   'IXP_id': 'RoNIX (Romanian Network for Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Bucharest',
#   'URL(Graph stats)': []},
#  {'pdb_id': 538,
#   'id': 479,
#   'Country': 'EE',
#   'IXP_id': 'RTIX (Tallinn Governmental Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Tallin',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1002,
#   'id': 661,
#   'Country': 'US',
#   'IXP_id': 'RVA-IX (Richmond Virginia Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Richmond',
#   'URL(Graph stats)': []},
#  {'pdb_id': 691,
#   'id': 391,
#   'Country': 'AU',
#   'IXP_id': 'SA-IX',
#   'URL(website)': [],
#   'Location': 'Adelaide',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1073,
#   'id': 553,
#   'Country': 'AT',
#   'IXP_id': 'SAIX (Salzburg Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Salzburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 556,
#   'id': 160,
#   'Country': 'BR',
#   'IXP_id': 'Salvador (BA) (IX.br - Salvador (BA))',
#   'URL(website)': [],
#   'Location': 'Salvador da Bahia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 709,
#   'id': 374,
#   'Country': 'BR',
#   'IXP_id': 'São José do Rio Preto (SJP) (IX.br - São José do Rio Preto (SJP))',
#   'URL(website)': [],
#   'Location': 'São José do Rio Preto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 638,
#   'id': 289,
#   'Country': 'BR',
#   'IXP_id': 'São José dos Campos (SJC) (IX.br - São José dos Campos (SJC))',
#   'URL(website)': [],
#   'Location': 'São José dos Campos',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2299,
#   'id': 770,
#   'Country': 'SA',
#   'IXP_id': 'Saudi Arabia Internet eXchange (SAIX)',
#   'URL(website)': [],
#   'Location': 'Riyadh',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1634,
#   'id': 674,
#   'Country': 'CL',
#   'IXP_id': 'SCL-IX (SCL-IX)',
#   'URL(website)': [],
#   'Location': 'Santiago',
#   'URL(Graph stats)': []},
#  {'pdb_id': 633,
#   'id': 489,
#   'Country': 'RU',
#   'IXP_id': 'Sea-IX (South Russia IX)',
#   'URL(website)': [],
#   'Location': 'Krasnodar',
#   'URL(Graph stats)': []},
#  {'pdb_id': 34,
#   'id': 32,
#   'Country': 'FR',
#   'IXP_id': 'SFINX (Service for French Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Paris',
#   'URL(Graph stats)': []},
#  {'pdb_id': 155,
#   'id': 223,
#   'Country': 'US',
#   'IXP_id': 'SFMIX (San Francisco Metropolitan Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1154,
#   'id': 668,
#   'Country': 'RU',
#   'IXP_id': 'SFO-IX (SFO-IX)',
#   'URL(website)': [],
#   'Location': 'Barnaul',
#   'URL(Graph stats)': []},
#  {'pdb_id': 429,
#   'id': 371,
#   'Country': 'SG',
#   'IXP_id': 'SGIX (Singapore Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Singapore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 822,
#   'id': 655,
#   'Country': 'RU',
#   'IXP_id': 'SIBIR-IX (SIBIR-IX)',
#   'URL(website)': [],
#   'Location': 'Krasnoyarsk',
#   'URL(Graph stats)': []},
#  {'pdb_id': 559,
#   'id': 167,
#   'Country': 'SK',
#   'IXP_id': 'SIX - Košice (Slovak Internet eXchange - Košice)',
#   'URL(website)': [],
#   'Location': 'Košice',
#   'URL(Graph stats)': []},
#  {'pdb_id': 13,
#   'id': 148,
#   'Country': 'US',
#   'IXP_id': 'SIX (Seattle Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 319,
#   'id': 25,
#   'Country': 'SI',
#   'IXP_id': 'SIX (Slovenian Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Ljubljana',
#   'URL(Graph stats)': []},
#  {'pdb_id': 84,
#   'id': 89,
#   'Country': 'SK',
#   'IXP_id': 'SIX Bratislava (Slovak Internet eXchange Bratislava)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1285,
#   'id': 679,
#   'Country': 'US',
#   'IXP_id': 'SIX Seattle (Jumbo) (Seattle Internet Exchange (9000 MTU))',
#   'URL(website)': [],
#   'Location': 'Seattle',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1419,
#   'id': 200,
#   'Country': 'NO',
#   'IXP_id': 'SIX Stavanger (Stavanger Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Stavanger',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1074,
#   'id': 723,
#   'Country': 'GM',
#   'IXP_id': 'SIXP (Serrekunda IXP)',
#   'URL(website)': [],
#   'Location': 'Serrekunda',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2320,
#   'id': 388,
#   'Country': 'SD',
#   'IXP_id': 'SIXP (Sudan Internet Exchange Point)',
#   'URL(website)': [],
#   'Location': 'Khartoum',
#   'URL(Graph stats)': []},
#  {'pdb_id': 829,
#   'id': 503,
#   'Country': 'US',
#   'IXP_id': 'SLIX (Salt Lake Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Salt Lake City',
#   'URL(Graph stats)': []},
#  {'pdb_id': 866,
#   'id': 320,
#   'Country': 'AE',
#   'IXP_id': 'SMARTHUB Internet Exchange / SH-IX',
#   'URL(website)': [],
#   'Location': 'Abu Dhabi',
#   'URL(Graph stats)': []},
#  {'pdb_id': 364,
#   'id': 228,
#   'Country': 'LV',
#   'IXP_id': 'SMILE (Santa Monica Internet Local Exchange)',
#   'URL(website)': [],
#   'Location': 'Riga',
#   'URL(Graph stats)': []},
#  {'pdb_id': 379,
#   'id': 88,
#   'Country': 'RU',
#   'IXP_id': 'smr-ix (SMR-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'Samara',
#   'URL(Graph stats)': []},
#  {'pdb_id': 627,
#   'id': 423,
#   'Country': 'US',
#   'IXP_id': 'SNAP (Southeast Network Access Point)',
#   'URL(website)': [],
#   'Location': 'Atlanta',
#   'URL(Graph stats)': []},
#  {'pdb_id': 357,
#   'id': 271,
#   'Country': 'US',
#   'IXP_id': 'SOAX (Southern Oregon Access Exchange)',
#   'URL(website)': [],
#   'Location': 'Medford',
#   'URL(Graph stats)': []},
#  {'pdb_id': 128,
#   'id': 91,
#   'Country': 'SE',
#   'IXP_id': 'SOLIX - Stockholm (SOLIX)',
#   'URL(website)': [],
#   'Location': 'Stockholm',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2410,
#   'id': 754,
#   'Country': 'SO',
#   'IXP_id': 'Somali Internet Exchange Point - Mogadishu',
#   'URL(website)': [],
#   'Location': 'Mogadishu',
#   'URL(Graph stats)': []},
#  {'pdb_id': 93,
#   'id': 133,
#   'Country': 'SG',
#   'IXP_id': 'SOX - Singapore (Singapore Open eXchange)',
#   'URL(website)': [],
#   'Location': 'Singapore',
#   'URL(Graph stats)': []},
#  {'pdb_id': 424,
#   'id': 292,
#   'Country': 'RS',
#   'IXP_id': 'SOX (Serbian Open eXchange)',
#   'URL(website)': [],
#   'Location': 'Belgrade',
#   'URL(Graph stats)': []},
#  {'pdb_id': 107,
#   'id': 87,
#   'Country': 'RU',
#   'IXP_id': 'spb-ix (SPB-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'St.-Petersburg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2457,
#   'id': 758,
#   'Country': 'KG',
#   'IXP_id': 'SR-IX (Silk Road Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1869,
#   'id': 713,
#   'Country': 'SE',
#   'IXP_id': 'STHIX - Copenhagen (Stockholm Internet eXchange AB)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1868,
#   'id': 712,
#   'Country': 'SE',
#   'IXP_id': 'STHIX - Gothenburg (Stockholm Internet eXchange AB)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 172,
#   'id': 144,
#   'Country': 'SE',
#   'IXP_id': 'STHIX - Stockholm (Stockholm Internet eXchange AB)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 580,
#   'id': 384,
#   'Country': 'RU',
#   'IXP_id': 'stw-ix (STW-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'Stavropol',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1089,
#   'id': 666,
#   'Country': 'BG',
#   'IXP_id': 'T-CIX (T-CIX)',
#   'URL(website)': [],
#   'Location': 'Sofia',
#   'URL(Graph stats)': []},
#  {'pdb_id': 938,
#   'id': 635,
#   'Country': 'US',
#   'IXP_id': 'TahoeIX (Tahoe Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Tahoe',
#   'URL(Graph stats)': []},
#  {'pdb_id': 363,
#   'id': 424,
#   'Country': 'US',
#   'IXP_id': 'tdc-ops-sw1 (SUPRnet)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 481,
#   'id': 346,
#   'Country': 'PL',
#   'IXP_id': 'Thinx (Thinx)',
#   'URL(website)': [],
#   'Location': 'Warsaw',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1009,
#   'id': 663,
#   'Country': 'AT',
#   'IXP_id': 'Tirol-IX (Tirol-IX)',
#   'URL(website)': [],
#   'Location': 'Hall in Tirol',
#   'URL(Graph stats)': []},
#  {'pdb_id': 361,
#   'id': 50,
#   'Country': 'TZ',
#   'IXP_id': 'TIX - Tanzania (Tanzania Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Dar es Salaam',
#   'URL(Graph stats)': []},
#  {'pdb_id': 187,
#   'id': 76,
#   'Country': 'EE',
#   'IXP_id': 'TIX Tallinn (Tallinn Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Tallinn',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1574,
#   'id': 675,
#   'Country': 'TZ',
#   'IXP_id': 'TIX Tanzania - Mwanza IXP (TIX Tanzania - Mwanza IXP)',
#   'URL(website)': [],
#   'Location': 'Mwanza',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1418,
#   'id': 199,
#   'Country': 'NO',
#   'IXP_id': 'TIX Tromsø (Tromsø Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Tromsø',
#   'URL(Graph stats)': []},
#  {'pdb_id': 273,
#   'id': 26,
#   'Country': 'IT',
#   'IXP_id': 'TIX Tuscany (Tuscany Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Florence',
#   'URL(Graph stats)': []},
#  {'pdb_id': 190,
#   'id': 98,
#   'Country': 'EE',
#   'IXP_id': 'TLLIX (Tallinn Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Tallinn',
#   'URL(Graph stats)': []},
#  {'pdb_id': 115,
#   'id': 14,
#   'Country': 'IT',
#   'IXP_id': 'TOP-IX (Torino Piemonte Exchange Point)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 24,
#   'id': 163,
#   'Country': 'CA',
#   'IXP_id': 'TorIX (Toronto Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Toronto',
#   'URL(Graph stats)': []},
#  {'pdb_id': 336,
#   'id': 274,
#   'Country': 'FR',
#   'IXP_id': 'TOUIX (Toulouse Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Toulouse',
#   'URL(Graph stats)': []},
#  {'pdb_id': 624,
#   'id': 495,
#   'Country': 'US',
#   'IXP_id': 'TP-IX (Twin Ports IX)',
#   'URL(website)': [],
#   'Location': 'Duluth',
#   'URL(Graph stats)': []},
#  {'pdb_id': 833,
#   'id': 656,
#   'Country': 'US',
#   'IXP_id': 'TPA-IX (Tampa Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Tampa',
#   'URL(Graph stats)': []},
#  {'pdb_id': 823,
#   'id': 185,
#   'Country': 'TW',
#   'IXP_id': 'TPIX - Taipei (Taipei Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Taipei',
#   'URL(Graph stats)': []},
#  {'pdb_id': 482,
#   'id': 401,
#   'Country': 'PL',
#   'IXP_id': 'TPIX (Orange Polska Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Warsaw',
#   'URL(Graph stats)': []},
#  {'pdb_id': 269,
#   'id': 330,
#   'Country': 'AU',
#   'IXP_id': 'TransACT IX (TransACT IX)',
#   'URL(website)': [],
#   'Location': 'Canberra',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1420,
#   'id': 193,
#   'Country': 'NO',
#   'IXP_id': 'TRDIX (Trondheim Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Trondheim',
#   'URL(Graph stats)': []},
#  {'pdb_id': 328,
#   'id': 46,
#   'Country': 'FI',
#   'IXP_id': 'TREX (TREX Regional Exchanges Oy)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 940,
#   'id': 536,
#   'Country': 'TT',
#   'IXP_id': 'TTIX',
#   'URL(website)': [],
#   'Location': 'Barataria',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2272,
#   'id': 799,
#   'Country': '',
#   'IXP_id': 'TTIX2',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2355,
#   'id': 757,
#   'Country': 'BT',
#   'IXP_id': 'TTPL LAN (Bhutan Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1105,
#   'id': 370,
#   'Country': 'TN',
#   'IXP_id': 'TunIXP (Tunisian Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Tunis',
#   'URL(Graph stats)': []},
#  {'pdb_id': 2527,
#   'id': 767,
#   'Country': 'TR',
#   'IXP_id': 'Turk-IX',
#   'URL(website)': [],
#   'Location': 'Istanbul',
#   'URL(Graph stats)': []},
#  {'pdb_id': 43,
#   'id': 113,
#   'Country': 'TW',
#   'IXP_id': 'TWIX - Taipei (Taiwan Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Taipei',
#   'URL(Graph stats)': []},
#  {'pdb_id': 184,
#   'id': 48,
#   'Country': 'UA',
#   'IXP_id': 'UA-IX (Ukrainian Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Kiev',
#   'URL(Graph stats)': []},
#  {'pdb_id': 587,
#   'id': 373,
#   'Country': 'AE',
#   'IXP_id': 'UAE-IX (United Arab Emirates Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Dubai',
#   'URL(Graph stats)': []},
#  {'pdb_id': 340,
#   'id': 187,
#   'Country': 'RU',
#   'IXP_id': 'ULN-IX (Ulyanovsk Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1469,
#   'id': 598,
#   'Country': 'GB',
#   'IXP_id': 'UNIFI-IX (UNIFI-IX)',
#   'URL(website)': [],
#   'Location': 'Coventry',
#   'URL(Graph stats)': []},
#  {'pdb_id': 863,
#   'id': 535,
#   'Country': 'CA',
#   'IXP_id': 'VANIX (Vancouver Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Vancouver',
#   'URL(Graph stats)': []},
#  {'pdb_id': 513,
#   'id': 393,
#   'Country': 'AU',
#   'IXP_id': 'VIC-IX',
#   'URL(website)': [],
#   'Location': 'Melbourne',
#   'URL(Graph stats)': []},
#  {'pdb_id': 706,
#   'id': 377,
#   'Country': 'BR',
#   'IXP_id': 'Vitória (VIX) (IX.br -  Vitória (VIX))',
#   'URL(website)': [],
#   'Location': 'Vitória',
#   'URL(Graph stats)': []},
#  {'pdb_id': 50,
#   'id': 3,
#   'Country': 'AT',
#   'IXP_id': 'VIX (Vienna Internet Exchange)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 378,
#   'id': 170,
#   'Country': 'RU',
#   'IXP_id': 'vlv-ix (VLV-IX public peering VLAN)',
#   'URL(website)': [],
#   'Location': 'Vladivostok',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1772,
#   'id': 134,
#   'Country': 'VN',
#   'IXP_id': 'VNIX - Hanoi (Vietnam National Internet eXchange - Hanoi)',
#   'URL(website)': [],
#   'Location': 'Hanoi',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1771,
#   'id': 135,
#   'Country': 'VN',
#   'IXP_id': 'VNIX - Ho Chi Minh (Vietnam National Internet eXchange - Ho Chi Minh)',
#   'URL(website)': [],
#   'Location': 'Ho Chi Minh City',
#   'URL(Graph stats)': []},
#  {'pdb_id': 311,
#   'id': 38,
#   'Country': 'IT',
#   'IXP_id': 'VSIX (VSIX Nap del Nord Est)',
#   'URL(website)': [],
#   'Location': '',
#   'URL(Graph stats)': []},
#  {'pdb_id': 971,
#   'id': 494,
#   'Country': 'VU',
#   'IXP_id': 'VUIX (Vanuatu Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Port Vila',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1242,
#   'id': 678,
#   'Country': 'RU',
#   'IXP_id': 'W-IX (W-IX)',
#   'URL(website)': [],
#   'Location': 'Moscow',
#   'URL(Graph stats)': []},
#  {'pdb_id': 21,
#   'id': 108,
#   'Country': 'AU',
#   'IXP_id': 'WA-IX',
#   'URL(website)': [],
#   'Location': 'Perth',
#   'URL(Graph stats)': []},
#  {'pdb_id': 96,
#   'id': 85,
#   'Country': 'PL',
#   'IXP_id': 'WIX - Poland (Warsaw Internet eXchange)',
#   'URL(website)': [],
#   'Location': 'Warsaw',
#   'URL(Graph stats)': []},
#  {'pdb_id': 348,
#   'id': 132,
#   'Country': 'NZ',
#   'IXP_id': 'WIX - Wellington (Wellington Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Wellington',
#   'URL(Graph stats)': []},
#  {'pdb_id': 776,
#   'id': 386,
#   'Country': 'CA',
#   'IXP_id': 'WPG-IX (Winnipeg Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Winnipeg',
#   'URL(Graph stats)': []},
#  {'pdb_id': 683,
#   'id': 493,
#   'Country': 'RU',
#   'IXP_id': 'YAR-IX (Yaroslavl Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Yaroslavl',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1169,
#   'id': 669,
#   'Country': 'CA',
#   'IXP_id': 'YEGIX (YEGIX)',
#   'URL(website)': [],
#   'Location': 'Edmonton',
#   'URL(Graph stats)': []},
#  {'pdb_id': 199,
#   'id': 219,
#   'Country': 'US',
#   'IXP_id': 'YRIX (Yellowstone Regional Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Billings',
#   'URL(Graph stats)': []},
#  {'pdb_id': 639,
#   'id': 398,
#   'Country': 'CA',
#   'IXP_id': 'YYCIX (Calgary Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Calgary',
#   'URL(Graph stats)': []},
#  {'pdb_id': 1293,
#   'id': 213,
#   'Country': 'ZW',
#   'IXP_id': 'ZINX (Zimbabwe Internet Exchange)',
#   'URL(website)': [],
#   'Location': 'Harare',
#   'URL(Graph stats)': []}]

# %%
# %store DB1
# Out:
# Stored 'DB1' (list)

# %%
length_of_DB1=len(DB1)
# %store length_of_DB1
# Out:
# Stored 'length_of_DB1' (int)
