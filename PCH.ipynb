# %%
## This script get all information needed about IXPs in PCH using its API.
from datetime import datetime
import json, requests, sys, time
from pprint import pprint
import os


## This function requests the output of any API endpoint.
def fetch_api_url(url):
    r = requests.get(url)
    #time.sleep(0.5) ## necessary to make sure that the output is fully fetched
    content_url = r.content
    # Put content_url in json variable and return it
    json_val = {}
    try:
        json_val = json.loads(content_url)
    except:
        pass
    return json_val


print('Step 1: Getting all IDs of IXPs in the Peering database')
query = "https://www.pch.net/api/ixp/directory/"

# If you want to fetch them all
list_IXPs = fetch_api_url(query)
# Out:
# Step 1: Getting all IDs of IXPs in the Peering database

# %%
list_IXPs
# Out:
# [{'id': '83',
#   'ctry': 'Germany',
#   'cit': 'Frankfurt',
#   'reg': 'Europe',
#   'name': 'Deutscher Commercial Internet Exchange DE-CIX Frankfurt',
#   'url': 'https://www.de-cix.net/en/locations/germany/frankfurt',
#   'stat': 'Active',
#   'date': '19950500',
#   'prfs': '1492263',
#   'lat': '50.12000',
#   'lon': '8.68000',
#   'prts': '776',
#   'traf': '6158000200',
#   'avg': '4313000000',
#   'trgh': '2200000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '1',
#   'pc_rank': '1',
#   'pr_rank': '2',
#   'pw_rank': '4',
#   'tr_rank': '1',
#   'prts_url': 'https://www.de-cix.net/en/locations/germany/frankfurt/connected-networks',
#   'q9': 'Yes',
#   'iata': 'FRA',
#   'regct': 325},
#  {'id': '160',
#   'ctry': 'Netherlands',
#   'cit': 'Amsterdam',
#   'reg': 'Europe',
#   'name': 'Amsterdam Internet Exchange',
#   'url': 'https://ams-ix.net/',
#   'stat': 'Active',
#   'date': '19971229',
#   'prfs': '1204334',
#   'lat': '52.30000',
#   'lon': '4.77000',
#   'prts': '807',
#   'traf': '5752000000',
#   'avg': '4208000000',
#   'trgh': '2563000000',
#   'ipv6_avg': '2.566540',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '2',
#   'pc_rank': '1',
#   'pr_rank': '1',
#   'pw_rank': '2',
#   'tr_rank': '2',
#   'prts_url': 'https://ams-ix.net/connected_parties',
#   'q9': 'Yes',
#   'iata': 'AMS',
#   'regct': 325},
#  {'id': '30',
#   'ctry': 'Brazil',
#   'cit': 'São Paulo',
#   'reg': 'Latin America',
#   'name': 'Ponto de Troca de Tráfego Metro São Paulo',
#   'url': 'http://ix.br/adesao/sp',
#   'stat': 'Active',
#   'date': '20041004',
#   'prfs': '0',
#   'lat': '-23.62000',
#   'lon': '-46.65000',
#   'prts': '1467',
#   'traf': '5223000000',
#   'avg': '2854000000',
#   'trgh': '1050000000',
#   'ipv6_avg': '8.899790',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '3',
#   'pc_rank': '1',
#   'pr_rank': '1',
#   'pw_rank': '1',
#   'tr_rank': '1',
#   'prts_url': 'http://ix.br/adesao/sp',
#   'q9': 'Yes',
#   'iata': 'GRU',
#   'regct': 122},
#  {'id': '62',
#   'ctry': 'United Kingdom',
#   'cit': 'London',
#   'reg': 'Europe',
#   'name': 'London Internet Exchange',
#   'url': 'https://www.linx.net/',
#   'stat': 'Active',
#   'date': '19941108',
#   'prfs': '757539',
#   'lat': '51.48000',
#   'lon': '-0.45000',
#   'prts': '770',
#   'traf': '4216000000',
#   'avg': '2700000000',
#   'trgh': '1400000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2018-08-22',
#   'tc_rank': '1',
#   'tw_rank': '4',
#   'pc_rank': '1',
#   'pr_rank': '3',
#   'pw_rank': '5',
#   'tr_rank': '3',
#   'prts_url': 'https://portal.linx.net/members/list-ip-asn',
#   'q9': 'Yes',
#   'iata': 'LHR',
#   'regct': 325},
#  {'id': '572',
#   'ctry': 'Netherlands',
#   'cit': 'Amsterdam',
#   'reg': 'Europe',
#   'name': 'Neutral Internet Exchange',
#   'url': 'https://www.nl-ix.net/',
#   'stat': 'Active',
#   'date': '20020301',
#   'prfs': '345945',
#   'lat': '52.30000',
#   'lon': '4.77000',
#   'prts': '654',
#   'traf': '2200000000',
#   'avg': '1500000000',
#   'trgh': '800000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '5',
#   'pc_rank': '2',
#   'pr_rank': '4',
#   'pw_rank': '6',
#   'tr_rank': '4',
#   'prts_url': 'https://www.nl-ix.net/network/connected-networks/',
#   'q9': 'Yes',
#   'iata': 'AMS',
#   'regct': 325},
#  {'id': '130',
#   'ctry': 'Japan',
#   'cit': 'Tokyo',
#   'reg': 'Asia-Pacific',
#   'name': 'JPNAP Tokyo I - Otemachi',
#   'url': 'http://www.jpnap.net/english/jpnap-tokyo/index.html',
#   'stat': 'Active',
#   'date': '20010000',
#   'prfs': '0',
#   'lat': '35.55000',
#   'lon': '139.78000',
#   'prts': '130',
#   'traf': '1322568000',
#   'avg': '780000000',
#   'trgh': '338000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-03-25',
#   'tc_rank': '1',
#   'tw_rank': '6',
#   'pc_rank': '3',
#   'pr_rank': '12',
#   'pw_rank': '57',
#   'tr_rank': '1',
#   'prts_url': 'http://www.jpnap.net/english/jpnap-tokyo/customer.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '464',
#   'ctry': 'Singapore',
#   'cit': 'Singapore',
#   'reg': 'Asia-Pacific',
#   'name': 'Equinix Singapore IBX',
#   'url': 'https://www.equinix.sg/',
#   'stat': 'Active',
#   'date': '20040426',
#   'prfs': '767349',
#   'lat': '1.37000',
#   'lon': '103.98000',
#   'prts': '156',
#   'traf': '650000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '1',
#   'tw_rank': '7',
#   'pc_rank': '1',
#   'pr_rank': '8',
#   'pw_rank': '39',
#   'tr_rank': '2',
#   'prts_url': '',
#   'q9': 'Yes',
#   'iata': 'QPG, QPG',
#   'regct': 204},
#  {'id': '1124',
#   'ctry': 'France',
#   'cit': 'Paris',
#   'reg': 'Europe',
#   'name': 'France-IX',
#   'url': 'https://www.franceix.net/en/',
#   'stat': 'Active',
#   'date': '20101100',
#   'prfs': '433040',
#   'lat': '48.80000',
#   'lon': '2.33000',
#   'prts': '346',
#   'traf': '1300000000',
#   'avg': '1016000000',
#   'trgh': '634000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '7',
#   'pc_rank': '2',
#   'pr_rank': '9',
#   'pw_rank': '12',
#   'tr_rank': '5',
#   'prts_url': 'https://www.franceix.net/en/france-ix-paris/members-in-paris/',
#   'q9': 'Yes',
#   'iata': 'CDG',
#   'regct': 325},
#  {'id': '96',
#   'ctry': 'China',
#   'cit': 'Hong Kong',
#   'reg': 'Asia-Pacific',
#   'name': 'Hong Kong Internet Exchange',
#   'url': 'http://www.hkix.net',
#   'stat': 'Active',
#   'date': '19950400',
#   'prfs': '648896',
#   'lat': '22.33000',
#   'lon': '114.18000',
#   'prts': '293',
#   'traf': '1208960000',
#   'avg': '852000000',
#   'trgh': '400000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-01-28',
#   'tc_rank': '1',
#   'tw_rank': '9',
#   'pc_rank': '1',
#   'pr_rank': '2',
#   'pw_rank': '15',
#   'tr_rank': '3',
#   'prts_url': 'http://www.hkix.net/hkix/participant.htm',
#   'q9': 'Yes',
#   'iata': 'HKG',
#   'regct': 204},
#  {'id': '415',
#   'ctry': 'Brazil',
#   'cit': 'Rio de Janeiro',
#   'reg': 'Latin America',
#   'name': 'Ponto de Troca de Tráfego do Rio de Janeiro',
#   'url': 'https://ix.br/adesao/rj',
#   'stat': 'Active',
#   'date': '20100000',
#   'prfs': '0',
#   'lat': '-22.90000',
#   'lon': '-43.17000',
#   'prts': '137',
#   'traf': '1124000000',
#   'avg': '791000000',
#   'trgh': '210000000',
#   'ipv6_avg': '9.481670',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '10',
#   'pc_rank': '3',
#   'pr_rank': '4',
#   'pw_rank': '50',
#   'tr_rank': '2',
#   'prts_url': 'https://ix.br/particip/rj',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '1270',
#   'ctry': 'Russia',
#   'cit': 'Moscow',
#   'reg': 'Europe',
#   'name': 'DataIX Moscow',
#   'url': 'http://www.dataix.ru/',
#   'stat': 'Active',
#   'date': '20101020',
#   'prfs': '0',
#   'lat': '55.75000',
#   'lon': '37.60000',
#   'prts': '282',
#   'traf': '1100000000',
#   'avg': '0',
#   'trgh': '300000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '11',
#   'pc_rank': '3',
#   'pr_rank': '11',
#   'pw_rank': '16',
#   'tr_rank': '6',
#   'prts_url': 'http://www.dataix.ru/members/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '345',
#   'ctry': 'United States',
#   'cit': 'Seattle',
#   'reg': 'North America',
#   'name': 'Seattle Internet Exchange',
#   'url': 'https://www.seattleix.net/',
#   'stat': 'Active',
#   'date': '19970620',
#   'prfs': '478310',
#   'lat': '47.61000',
#   'lon': '-122.33000',
#   'prts': '271',
#   'traf': '1037436322',
#   'avg': '772000000',
#   'trgh': '500000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '13',
#   'pc_rank': '2',
#   'pr_rank': '2',
#   'pw_rank': '17',
#   'tr_rank': '1',
#   'prts_url': 'https://www.seattleix.net/participants/',
#   'q9': 'Yes',
#   'iata': 'SEA',
#   'regct': 224},
#  {'id': '227',
#   'ctry': 'Sweden',
#   'cit': 'Stockholm',
#   'reg': 'Europe',
#   'name': 'Netnod Stockholm',
#   'url': 'https://www.netnod.se/',
#   'stat': 'Active',
#   'date': '19970000',
#   'prfs': '0',
#   'lat': '59.33000',
#   'lon': '18.05000',
#   'prts': '162',
#   'traf': '1000711000',
#   'avg': '680000000',
#   'trgh': '300000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '14',
#   'pc_rank': '1',
#   'pr_rank': '21',
#   'pw_rank': '37',
#   'tr_rank': '8',
#   'prts_url': 'https://www.netnod.se/ix/networks',
#   'q9': 'Yes',
#   'iata': 'ARN',
#   'regct': 325},
#  {'id': '1240',
#   'ctry': 'Ukraine',
#   'cit': 'Kiev',
#   'reg': 'Europe',
#   'name': 'Digital Telecom Internet Exchange',
#   'url': 'https://dtel-ix.net/',
#   'stat': 'Active',
#   'date': '20090000',
#   'prfs': '0',
#   'lat': '50.40000',
#   'lon': '30.45000',
#   'prts': '140',
#   'traf': '979000000',
#   'avg': '608800000',
#   'trgh': '200040000',
#   'ipv6_avg': '1.609720',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '15',
#   'pc_rank': '2',
#   'pr_rank': '24',
#   'pw_rank': '48',
#   'tr_rank': '9',
#   'prts_url': 'https://dtel-ix.net/en/members',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '255',
#   'ctry': 'United States',
#   'cit': 'Ashburn',
#   'reg': 'North America',
#   'name': 'Equinix IBX Ashburn',
#   'url': 'https://www.equinix.com/',
#   'stat': 'Active',
#   'date': '20021031',
#   'prfs': '940424',
#   'lat': '39.02000',
#   'lon': '-77.46000',
#   'prts': '208',
#   'traf': '610000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '2',
#   'tw_rank': '17',
#   'pc_rank': '4',
#   'pr_rank': '5',
#   'pw_rank': '27',
#   'tr_rank': '2',
#   'prts_url': '',
#   'q9': 'Yes',
#   'iata': 'IAD',
#   'regct': 224},
#  {'id': '509',
#   'ctry': 'Poland',
#   'cit': 'Warsaw',
#   'reg': 'Europe',
#   'name': 'Equinix IX Warsaw (ex-PLIX)',
#   'url': 'http://www.plix.pl/pl',
#   'stat': 'Active',
#   'date': '20060402',
#   'prfs': '304605',
#   'lat': '52.23000',
#   'lon': '21.00000',
#   'prts': '266',
#   'traf': '883000000',
#   'avg': '521000000',
#   'trgh': '150000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2018-11-02',
#   'tc_rank': '2',
#   'tw_rank': '19',
#   'pc_rank': '3',
#   'pr_rank': '12',
#   'pw_rank': '18',
#   'tr_rank': '12',
#   'prts_url': 'http://www.plix.pl/pl/member',
#   'q9': 'Yes',
#   'iata': 'WAW',
#   'regct': 325},
#  {'id': '129',
#   'ctry': 'Japan',
#   'cit': 'Tokyo',
#   'reg': 'Asia-Pacific',
#   'name': 'Japan Internet Exchange',
#   'url': 'https://www.jpix.ad.jp/jp/index.php',
#   'stat': 'Active',
#   'date': '19970700',
#   'prfs': '341786',
#   'lat': '35.55000',
#   'lon': '139.78000',
#   'prts': '174',
#   'traf': '881000000',
#   'avg': '591000000',
#   'trgh': '240000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '20',
#   'pc_rank': '1',
#   'pr_rank': '7',
#   'pw_rank': '34',
#   'tr_rank': '4',
#   'prts_url': 'https://www.jpix.ad.jp/en/member.php?qso=b&qar=2',
#   'q9': 'Yes',
#   'iata': 'NRT',
#   'regct': 204},
#  {'id': '1306',
#   'ctry': 'South Africa',
#   'cit': 'Johannesburg',
#   'reg': 'Africa',
#   'name': 'NAPAfrica Johannesburg',
#   'url': 'https://www.napafrica.net/',
#   'stat': 'Active',
#   'date': '20120000',
#   'prfs': '260323',
#   'lat': '-26.13000',
#   'lon': '28.23000',
#   'prts': '308',
#   'traf': '720000000',
#   'avg': '0',
#   'trgh': '180000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '22',
#   'pc_rank': '1',
#   'pr_rank': '1',
#   'pw_rank': '13',
#   'tr_rank': '1',
#   'prts_url': 'https://www.napafrica.net/who-is-peering/',
#   'q9': 'Yes',
#   'iata': 'JNB',
#   'regct': 78},
#  {'id': '55',
#   'ctry': 'Czech Republic',
#   'cit': 'Prague',
#   'reg': 'Europe',
#   'name': 'NIX.CZ - Neutral Internet eXchange for the Czech Republic',
#   'url': 'https://www.nix.cz/cs',
#   'stat': 'Active',
#   'date': '19960831',
#   'prfs': '0',
#   'lat': '50.08000',
#   'lon': '14.43000',
#   'prts': '150',
#   'traf': '680000000',
#   'avg': '0',
#   'trgh': '150000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '23',
#   'pc_rank': '1',
#   'pr_rank': '22',
#   'pw_rank': '41',
#   'tr_rank': '13',
#   'prts_url': 'https://www.nix.cz/en/networks',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '15',
#   'ctry': 'Austria',
#   'cit': 'Vienna',
#   'reg': 'Europe',
#   'name': 'Vienna Internet Exchange',
#   'url': 'https://www.vix.at/vixhome.html',
#   'stat': 'Active',
#   'date': '19960400',
#   'prfs': '145453',
#   'lat': '48.20000',
#   'lon': '16.37000',
#   'prts': '131',
#   'traf': '611000000',
#   'avg': '353700000',
#   'trgh': '105000000',
#   'ipv6_avg': '4.156060',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '25',
#   'pc_rank': '1',
#   'pr_rank': '28',
#   'pw_rank': '55',
#   'tr_rank': '14',
#   'prts_url': 'https://www.vix.at/vix_participants.html',
#   'q9': 'Yes',
#   'iata': 'VIE',
#   'regct': 325},
#  {'id': '118',
#   'ctry': 'Italy',
#   'cit': 'Milan',
#   'reg': 'Europe',
#   'name': 'Milan Internet Exchange',
#   'url': 'http://www.mix-it.net/',
#   'stat': 'Active',
#   'date': '20001100',
#   'prfs': '0',
#   'lat': '45.45000',
#   'lon': '9.17000',
#   'prts': '245',
#   'traf': '596522000',
#   'avg': '382137000',
#   'trgh': '140100000',
#   'ipv6_avg': '0.035850',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '27',
#   'pc_rank': '1',
#   'pr_rank': '13',
#   'pw_rank': '20',
#   'tr_rank': '16',
#   'prts_url': 'http://www.mix-it.net/index.php?option=com_content&view=article&id=85&Itemid=84&lang=en',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '39',
#   'ctry': 'Canada',
#   'cit': 'Toronto',
#   'reg': 'North America',
#   'name': 'Toronto Internet Exchange',
#   'url': 'https://www.torix.ca/',
#   'stat': 'Active',
#   'date': '19980724',
#   'prfs': '341350',
#   'lat': '43.67000',
#   'lon': '-79.40000',
#   'prts': '226',
#   'traf': '564000000',
#   'avg': '402000000',
#   'trgh': '201000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '28',
#   'pc_rank': '1',
#   'pr_rank': '3',
#   'pw_rank': '21',
#   'tr_rank': '4',
#   'prts_url': 'https://www.torix.ca/peers/',
#   'q9': 'Yes',
#   'iata': 'YYZ',
#   'regct': 224},
#  {'id': '80',
#   'ctry': 'Germany',
#   'cit': 'Berlin',
#   'reg': 'Europe',
#   'name': 'Berlin Commercial Internet Exchange',
#   'url': 'https://www.bcix.de/bcix/',
#   'stat': 'Active',
#   'date': '20020906',
#   'prfs': '303761',
#   'lat': '52.38000',
#   'lon': '13.52000',
#   'prts': '83',
#   'traf': '520000000',
#   'avg': '0',
#   'trgh': '100000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '31',
#   'pc_rank': '6',
#   'pr_rank': '45',
#   'pw_rank': '85',
#   'tr_rank': '18',
#   'prts_url': 'https://www.bcix.de/bcix/members/',
#   'q9': 'Yes',
#   'iata': 'BER',
#   'regct': 325},
#  {'id': '320',
#   'ctry': 'United States',
#   'cit': 'New York',
#   'reg': 'North America',
#   'name': 'New York International Internet Exchange',
#   'url': 'http://www.nyiix.net/',
#   'stat': 'Active',
#   'date': '19960000',
#   'prfs': '157',
#   'lat': '40.75000',
#   'lon': '-74.00000',
#   'prts': '174',
#   'traf': '510000000',
#   'avg': '405000000',
#   'trgh': '260000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '4',
#   'tw_rank': '32',
#   'pc_rank': '5',
#   'pr_rank': '6',
#   'pw_rank': '34',
#   'tr_rank': '5',
#   'prts_url': 'http://www.nyiix.net/members/',
#   'q9': 'Yes',
#   'iata': 'LGA',
#   'regct': 224},
#  {'id': '126',
#   'ctry': 'Japan',
#   'cit': 'Osaka',
#   'reg': 'Asia-Pacific',
#   'name': 'JPNAP Osaka',
#   'url': 'http://www.mfeed.co.jp/english/jpnap-osaka/index.html',
#   'stat': 'Active',
#   'date': '20020002',
#   'prfs': '0',
#   'lat': '34.53000',
#   'lon': '135.50000',
#   'prts': '52',
#   'traf': '487180000',
#   'avg': '284000000',
#   'trgh': '113000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '33',
#   'pc_rank': '5',
#   'pr_rank': '30',
#   'pw_rank': '128',
#   'tr_rank': '6',
#   'prts_url': 'http://www.mfeed.co.jp/english/jpnap-osaka/customer.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '1265',
#   'ctry': 'United States',
#   'cit': 'Minneapolis',
#   'reg': 'North America',
#   'name': 'Midwest Internet Cooperative Exchange',
#   'url': 'http://www.micemn.net/',
#   'stat': 'Active',
#   'date': '20110111',
#   'prfs': '0',
#   'lat': '44.98550',
#   'lon': '-93.27190',
#   'prts': '64',
#   'traf': '219000000',
#   'avg': '1',
#   'trgh': '60000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '5',
#   'tw_rank': '34',
#   'pc_rank': '19',
#   'pr_rank': '21',
#   'pw_rank': '112',
#   'tr_rank': '6',
#   'prts_url': 'http://www.micemn.net/participants.html',
#   'q9': 'Yes',
#   'iata': 'MSP',
#   'regct': 224},
#  {'id': '125',
#   'ctry': 'Japan',
#   'cit': 'Osaka',
#   'reg': 'Asia-Pacific',
#   'name': 'JPIX Osaka',
#   'url': 'https://www.jpix.ad.jp/en/',
#   'stat': 'Active',
#   'date': '20020400',
#   'prfs': '0',
#   'lat': '34.53000',
#   'lon': '135.50000',
#   'prts': '49',
#   'traf': '443000000',
#   'avg': '281000000',
#   'trgh': '100000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '4',
#   'tw_rank': '35',
#   'pc_rank': '7',
#   'pr_rank': '33',
#   'pw_rank': '140',
#   'tr_rank': '7',
#   'prts_url': 'https://www.jpix.ad.jp/jp/member.php',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '249',
#   'ctry': 'Ukraine',
#   'cit': 'Kiev',
#   'reg': 'Europe',
#   'name': 'Ukrainian Internet Exchange',
#   'url': 'https://www.ix.net.ua/en',
#   'stat': 'Active',
#   'date': '20000700',
#   'prfs': '103258',
#   'lat': '50.40000',
#   'lon': '30.45000',
#   'prts': '180',
#   'traf': '416000000',
#   'avg': '169',
#   'trgh': '100000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '36',
#   'pc_rank': '1',
#   'pr_rank': '18',
#   'pw_rank': '31',
#   'tr_rank': '19',
#   'prts_url': 'https://www.ix.net.ua/members',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '213',
#   'ctry': 'Spain',
#   'cit': 'Madrid',
#   'reg': 'Europe',
#   'name': 'Punto Neutro Español de Internet',
#   'url': 'http://www.espanix.net/en/index.html',
#   'stat': 'Active',
#   'date': '19970000',
#   'prfs': '148611',
#   'lat': '40.43000',
#   'lon': '-3.70000',
#   'prts': '97',
#   'traf': '415000000',
#   'avg': '260000000',
#   'trgh': '100000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '37',
#   'pc_rank': '2',
#   'pr_rank': '36',
#   'pw_rank': '68',
#   'tr_rank': '20',
#   'prts_url': 'http://www.espanix.net/en/partners.html',
#   'q9': 'Yes',
#   'iata': 'MAD',
#   'regct': 325},
#  {'id': '116',
#   'ctry': 'Ireland',
#   'cit': 'Dublin',
#   'reg': 'Europe',
#   'name': 'Internet Neutral Exchange Association Limited',
#   'url': 'https://www.inex.ie/',
#   'stat': 'Active',
#   'date': '19960000',
#   'prfs': '1011441',
#   'lat': '53.33000',
#   'lon': '-6.25000',
#   'prts': '57',
#   'traf': '252000000',
#   'avg': '0',
#   'trgh': '70000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '38',
#   'pc_rank': '1',
#   'pr_rank': '32',
#   'pw_rank': '62',
#   'tr_rank': '21',
#   'prts_url': 'https://www.inex.ie/about-us/inex-members/',
#   'q9': 'Yes',
#   'iata': 'DUB',
#   'regct': 325},
#  {'id': '64',
#   'ctry': 'United Kingdom',
#   'cit': 'London',
#   'reg': 'Europe',
#   'name': 'London Network Access Point',
#   'url': 'https://www.lonap.net/',
#   'stat': 'Active',
#   'date': '19980000',
#   'prfs': '89149',
#   'lat': '51.48000',
#   'lon': '-0.45000',
#   'prts': '185',
#   'traf': '3716165670',
#   'avg': '0',
#   'trgh': '90000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-09',
#   'tc_rank': '2',
#   'tw_rank': '39',
#   'pc_rank': '2',
#   'pr_rank': '17',
#   'pw_rank': '30',
#   'tr_rank': '22',
#   'prts_url': 'https://www.lonap.net/members.shtml',
#   'q9': 'Yes',
#   'iata': 'LHR',
#   'regct': 325},
#  {'id': '616',
#   'ctry': 'Nigeria',
#   'cit': 'Lagos',
#   'reg': 'Africa',
#   'name': 'IXPN - Lagos',
#   'url': 'http://ixp.net.ng/',
#   'stat': 'Active',
#   'date': '20070500',
#   'prfs': '9298',
#   'lat': '6.55000',
#   'lon': '3.35000',
#   'prts': '52',
#   'traf': '290106459',
#   'avg': '0',
#   'trgh': '36000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-09',
#   'tc_rank': '1',
#   'tw_rank': '42',
#   'pc_rank': '1',
#   'pr_rank': '5',
#   'pw_rank': '128',
#   'tr_rank': '2',
#   'prts_url': 'http://ixp.net.ng/member-list/',
#   'q9': 'Yes',
#   'iata': 'LOS',
#   'regct': 78},
#  {'id': '81',
#   'ctry': 'Germany',
#   'cit': 'Berlin',
#   'reg': 'Europe',
#   'name': 'European Commercial Internet Exchange Berlin',
#   'url': 'https://www.ecix.net/',
#   'stat': 'Active',
#   'date': '20030000',
#   'prfs': '225699',
#   'lat': '52.38000',
#   'lon': '13.52000',
#   'prts': '56',
#   'traf': '286000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '3',
#   'tw_rank': '43',
#   'pc_rank': '8',
#   'pr_rank': '59',
#   'pw_rank': '121',
#   'tr_rank': '24',
#   'prts_url': 'https://www.ecix.net/connected-networks',
#   'q9': 'Yes',
#   'iata': 'FRA',
#   'regct': 325},
#  {'id': '1272',
#   'ctry': 'Singapore',
#   'cit': 'Singapore',
#   'reg': 'Asia-Pacific',
#   'name': 'Singapore Internet Exchange',
#   'url': 'https://www.sgix.sg/',
#   'stat': 'Active',
#   'date': '20100607',
#   'prfs': '295147',
#   'lat': '1.37000',
#   'lon': '103.98000',
#   'prts': '92',
#   'traf': '279000000',
#   'avg': '200000000',
#   'trgh': '90000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '44',
#   'pc_rank': '2',
#   'pr_rank': '15',
#   'pw_rank': '73',
#   'tr_rank': '8',
#   'prts_url': 'https://www.sgix.sg/peering-members/',
#   'q9': 'Yes',
#   'iata': 'QPG',
#   'regct': 204},
#  {'id': '307',
#   'ctry': 'United States',
#   'cit': 'Miami',
#   'reg': 'North America',
#   'name': 'NAP of the Americas',
#   'url': 'https://enterprise.verizon.com/',
#   'stat': 'Active',
#   'date': '20040812',
#   'prfs': '619952',
#   'lat': '25.83000',
#   'lon': '-80.29000',
#   'prts': '87',
#   'traf': '250000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '7',
#   'tw_rank': '45',
#   'pc_rank': '13',
#   'pr_rank': '14',
#   'pw_rank': '82',
#   'tr_rank': '8',
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '803',
#   'ctry': 'Netherlands',
#   'cit': 'Rotterdam',
#   'reg': 'Europe',
#   'name': 'Rotterdam Internet eXchange',
#   'url': 'https://r-ix.nl/',
#   'stat': 'Active',
#   'date': '20070000',
#   'prfs': '15279',
#   'lat': '51.95000',
#   'lon': '4.45000',
#   'prts': '29',
#   'traf': '250000000',
#   'avg': '0',
#   'trgh': '40000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2018-02-28',
#   'tc_rank': '3',
#   'tw_rank': '45',
#   'pc_rank': '7',
#   'pr_rank': '102',
#   'pw_rank': '205',
#   'tr_rank': '25',
#   'prts_url': 'https://r-ix.nl/content/customerlist',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '601',
#   'ctry': 'Malaysia',
#   'cit': 'Kuala Lumpur',
#   'reg': 'Asia-Pacific',
#   'name': 'Malaysia Internet Exchange',
#   'url': 'http://www.myix.my/',
#   'stat': 'Active',
#   'date': '20061215',
#   'prfs': '779150',
#   'lat': '3.13000',
#   'lon': '101.70000',
#   'prts': '75',
#   'traf': '249000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '1',
#   'tw_rank': '47',
#   'pc_rank': '1',
#   'pr_rank': '24',
#   'pw_rank': '97',
#   'tr_rank': '9',
#   'prts_url': 'http://www.myix.my/our-members/ordinary',
#   'q9': 'Yes',
#   'iata': 'KUL',
#   'regct': 204},
#  {'id': '1092',
#   'ctry': 'Brazil',
#   'cit': 'Porto Alegre',
#   'reg': 'Latin America',
#   'name': 'Ponto de Troca de Trafego do Porto Alegre',
#   'url': 'https://ix.br/adesao/rs',
#   'stat': 'Active',
#   'date': '20020400',
#   'prfs': '0',
#   'lat': '-30.00000',
#   'lon': '-51.18000',
#   'prts': '141',
#   'traf': '229000000',
#   'avg': '129000000',
#   'trgh': '40000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '48',
#   'pc_rank': '2',
#   'pr_rank': '3',
#   'pw_rank': '47',
#   'tr_rank': '4',
#   'prts_url': 'https://ix.br/particip/rs',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '1137',
#   'ctry': 'Bulgaria',
#   'cit': 'Sofia',
#   'reg': 'Europe',
#   'name': 'Bulgarian Internet eXchange',
#   'url': 'https://www.bix.bg/en/home.html',
#   'stat': 'Active',
#   'date': '20090801',
#   'prfs': '255099',
#   'lat': '42.65000',
#   'lon': '23.38000',
#   'prts': '77',
#   'traf': '227000000',
#   'avg': '158000000',
#   'trgh': '40000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '49',
#   'pc_rank': '2',
#   'pr_rank': '48',
#   'pw_rank': '95',
#   'tr_rank': '26',
#   'prts_url': 'https://www.bix.bg/en/members/public_peers.html',
#   'q9': 'Yes',
#   'iata': 'SOF',
#   'regct': 325},
#  {'id': '1269',
#   'ctry': 'Russia',
#   'cit': 'St. Petersburg',
#   'reg': 'Europe',
#   'name': 'DataIX St Petersburg',
#   'url': 'http://www.dataix.ru/',
#   'stat': 'Active',
#   'date': '20101020',
#   'prfs': '0',
#   'lat': '59.93000',
#   'lon': '30.30000',
#   'prts': '298',
#   'traf': '220000000',
#   'avg': '0',
#   'trgh': '60000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '51',
#   'pc_rank': '2',
#   'pr_rank': '10',
#   'pw_rank': '14',
#   'tr_rank': '28',
#   'prts_url': 'http://www.dataix.ru/members/',
#   'q9': 'Yes',
#   'iata': 'LED',
#   'regct': 325},
#  {'id': '1089',
#   'ctry': 'Brazil',
#   'cit': 'Fortaleza',
#   'reg': 'Latin America',
#   'name': 'Ponto de Troca de Trafego do Fortaleza',
#   'url': 'https://ix.br/adesao/ce',
#   'stat': 'Active',
#   'date': '20081001',
#   'prfs': '0',
#   'lat': '-3.78000',
#   'lon': '-38.53000',
#   'prts': '31',
#   'traf': '208000000',
#   'avg': '145000000',
#   'trgh': '40000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-06-30',
#   'tc_rank': '4',
#   'tw_rank': '53',
#   'pc_rank': '11',
#   'pr_rank': '15',
#   'pw_rank': '196',
#   'tr_rank': '5',
#   'prts_url': 'https://ix.br/particip/ce',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '17',
#   'ctry': 'Belgium',
#   'cit': 'Brussels',
#   'reg': 'Europe',
#   'name': 'Belgian National Internet Exchange',
#   'url': 'https://bnix.net/',
#   'stat': 'Active',
#   'date': '19950000',
#   'prfs': '0',
#   'lat': '50.90000',
#   'lon': '4.53000',
#   'prts': '61',
#   'traf': '200000000',
#   'avg': '0',
#   'trgh': '50000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '54',
#   'pc_rank': '1',
#   'pr_rank': '56',
#   'pw_rank': '115',
#   'tr_rank': '29',
#   'prts_url': 'https://bnix.net/en/content/participants',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '1234',
#   'ctry': 'Luxembourg',
#   'cit': 'Luxembourg',
#   'reg': 'Europe',
#   'name': 'Luxembourg Commercial Internet Exchange',
#   'url': 'http://www.lu-cix.lu/',
#   'stat': 'Active',
#   'date': '20100000',
#   'prfs': '0',
#   'lat': '49.62000',
#   'lon': '6.22000',
#   'prts': '79',
#   'traf': '197000000',
#   'avg': '104000000',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '57',
#   'pc_rank': '1',
#   'pr_rank': '47',
#   'pw_rank': '93',
#   'tr_rank': '30',
#   'prts_url': 'http://www.lu-cix.lu/members-list.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '99',
#   'ctry': 'Hungary',
#   'cit': 'Budapest',
#   'reg': 'Europe',
#   'name': 'Budapest Internet Exchange',
#   'url': 'http://www.bix.hu/',
#   'stat': 'Active',
#   'date': '19960000',
#   'prfs': '0',
#   'lat': '47.43000',
#   'lon': '19.18000',
#   'prts': '67',
#   'traf': '194000000',
#   'avg': '121000000',
#   'trgh': '36000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '58',
#   'pc_rank': '1',
#   'pr_rank': '53',
#   'pw_rank': '108',
#   'tr_rank': '31',
#   'prts_url': 'http://www.bix.hu/en/members',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '234',
#   'ctry': 'Switzerland',
#   'cit': 'Zurich',
#   'reg': 'Europe',
#   'name': 'SwissIX',
#   'url': 'https://www.swissix.ch/',
#   'stat': 'Active',
#   'date': '20010309',
#   'prfs': '98444',
#   'lat': '47.48000',
#   'lon': '8.53000',
#   'prts': '225',
#   'traf': '179000000',
#   'avg': '108000000',
#   'trgh': '50000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '59',
#   'pc_rank': '1',
#   'pr_rank': '14',
#   'pw_rank': '22',
#   'tr_rank': '32',
#   'prts_url': 'https://www.swissix.ch/participation/participants',
#   'q9': 'Yes',
#   'iata': 'ZRH',
#   'regct': 325},
#  {'id': '917',
#   'ctry': 'Poland',
#   'cit': 'Poznan',
#   'reg': 'Europe',
#   'name': 'Poznan Internet Exchange',
#   'url': 'https://www.pozix.pl/',
#   'stat': 'Active',
#   'date': '20060310',
#   'prfs': '0',
#   'lat': '52.42000',
#   'lon': '16.83000',
#   'prts': '15',
#   'traf': '176000000',
#   'avg': '90000000',
#   'trgh': '28000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-06-30',
#   'tc_rank': '5',
#   'tw_rank': '60',
#   'pc_rank': '9',
#   'pr_rank': '129',
#   'pw_rank': '290',
#   'tr_rank': '33',
#   'prts_url': 'https://www.pozix.pl/en/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '238',
#   'ctry': 'Taiwan',
#   'cit': 'Taipei',
#   'reg': 'Asia-Pacific',
#   'name': 'Taiwan Internet Exchange',
#   'url': 'http://www.twix.net.tw/index_e.html',
#   'stat': 'Active',
#   'date': '19971200',
#   'prfs': '35830',
#   'lat': '25.03000',
#   'lon': '121.52000',
#   'prts': '26',
#   'traf': '169000000',
#   'avg': '102000000',
#   'trgh': '50000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-01-30',
#   'tc_rank': '1',
#   'tw_rank': '61',
#   'pc_rank': '2',
#   'pr_rank': '51',
#   'pw_rank': '216',
#   'tr_rank': '12',
#   'prts_url': 'http://www.twix.net/member_e.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '627',
#   'ctry': 'Sweden',
#   'cit': 'Stockholm',
#   'reg': 'Europe',
#   'name': 'Stockholm Internet Exchange',
#   'url': 'https://www.sthix.net/',
#   'stat': 'Active',
#   'date': '20070000',
#   'prfs': '0',
#   'lat': '59.33000',
#   'lon': '18.05000',
#   'prts': '136',
#   'traf': '164000000',
#   'avg': '103000000',
#   'trgh': '50000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '63',
#   'pc_rank': '2',
#   'pr_rank': '26',
#   'pw_rank': '51',
#   'tr_rank': '34',
#   'prts_url': 'https://www.sthix.net/index.php/home/connected-networks/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '147',
#   'ctry': 'South Korea',
#   'cit': 'Seoul',
#   'reg': 'Asia-Pacific',
#   'name': 'Korea Internet Neutral Exchange KINX',
#   'url': 'https://www.kinx.net/?lang=en',
#   'stat': 'Active',
#   'date': '20000600',
#   'prfs': '191654',
#   'lat': '37.50000',
#   'lon': '126.93000',
#   'prts': '42',
#   'traf': '157000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2016-03-08',
#   'tc_rank': '1',
#   'tw_rank': '64',
#   'pc_rank': '3',
#   'pr_rank': '39',
#   'pw_rank': '164',
#   'tr_rank': '14',
#   'prts_url': 'https://www.kinx.net/service/network/ix/localpeering/?lang=en',
#   'q9': 'Yes',
#   'iata': 'ICN',
#   'regct': 204},
#  {'id': '804',
#   'ctry': 'Romania',
#   'cit': 'Bucharest',
#   'reg': 'Europe',
#   'name': 'InterLAN-IX',
#   'url': 'https://www.interlan.ro/',
#   'stat': 'Active',
#   'date': '20070000',
#   'prfs': '269021',
#   'lat': '44.50000',
#   'lon': '26.13000',
#   'prts': '83',
#   'traf': '142000000',
#   'avg': '91000000',
#   'trgh': '30000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '66',
#   'pc_rank': '1',
#   'pr_rank': '45',
#   'pw_rank': '85',
#   'tr_rank': '35',
#   'prts_url': 'https://www.interlan.ro/?t=5',
#   'q9': 'Yes',
#   'iata': 'OTP',
#   'regct': 325},
#  {'id': '29',
#   'ctry': 'Brazil',
#   'cit': 'São Paulo',
#   'reg': 'Latin America',
#   'name': 'Equinix São Paulo',
#   'url': 'https://ix.equinix.com',
#   'stat': 'Active',
#   'date': '19980000',
#   'prfs': '0',
#   'lat': '-23.62000',
#   'lon': '-46.65000',
#   'prts': '50',
#   'traf': '70000000',
#   'avg': '50000000',
#   'trgh': '38000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': '5',
#   'tw_rank': '67',
#   'pc_rank': '5',
#   'pr_rank': '8',
#   'pw_rank': '136',
#   'tr_rank': '6',
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '1194',
#   'ctry': 'Bulgaria',
#   'cit': 'Sofia',
#   'reg': 'Europe',
#   'name': 'Balkan Internet Exchange',
#   'url': 'http://www.b-ix.net/',
#   'stat': 'Active',
#   'date': '20100000',
#   'prfs': '0',
#   'lat': '42.65000',
#   'lon': '23.38000',
#   'prts': '47',
#   'traf': '137000000',
#   'avg': '99000000',
#   'trgh': '50000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '68',
#   'pc_rank': '3',
#   'pr_rank': '73',
#   'pw_rank': '145',
#   'tr_rank': '36',
#   'prts_url': 'http://www.b-ix.net/members/peers/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '204',
#   'ctry': 'Slovakia',
#   'cit': 'Bratislava',
#   'reg': 'Europe',
#   'name': 'Slovak Internet eXchange Bratislava',
#   'url': 'http://www.six.sk/',
#   'stat': 'Active',
#   'date': '19961000',
#   'prfs': '0',
#   'lat': '48.20000',
#   'lon': '17.20000',
#   'prts': '59',
#   'traf': '131780248',
#   'avg': '0',
#   'trgh': '25000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-09',
#   'tc_rank': '1',
#   'tw_rank': '69',
#   'pc_rank': '1',
#   'pr_rank': '57',
#   'pw_rank': '118',
#   'tr_rank': '37',
#   'prts_url': 'http://www.six.sk/index.php?lang=en&page=pripojene_siete',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '237',
#   'ctry': 'Taiwan',
#   'cit': 'Taipei',
#   'reg': 'Asia-Pacific',
#   'name': 'Taipei Internet Exchange (TPIX)',
#   'url': 'http://www.tpix.net.tw/',
#   'stat': 'Active',
#   'date': '20020702',
#   'prfs': '0',
#   'lat': '25.03000',
#   'lon': '121.52000',
#   'prts': '42',
#   'traf': '120000000',
#   'avg': '75',
#   'trgh': '32000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '70',
#   'pc_rank': '1',
#   'pr_rank': '39',
#   'pw_rank': '164',
#   'tr_rank': '16',
#   'prts_url': 'http://www.tpix.net.tw/mem_list.html',
#   'q9': 'No',
#   'iata': 'TPE',
#   'regct': 204},
#  {'id': '51',
#   'ctry': 'Croatia',
#   'cit': 'Zagreb',
#   'reg': 'Europe',
#   'name': 'Croatian Internet Exchange',
#   'url': 'https://www.cix.hr/',
#   'stat': 'Active',
#   'date': '20000000',
#   'prfs': '0',
#   'lat': '45.82000',
#   'lon': '16.03000',
#   'prts': '34',
#   'traf': '60000000',
#   'avg': '0',
#   'trgh': '15000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '70',
#   'pc_rank': '1',
#   'pr_rank': '94',
#   'pw_rank': '188',
#   'tr_rank': '38',
#   'prts_url': 'https://www.cix.hr/clanice/clanice',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '8',
#   'ctry': 'Australia',
#   'cit': 'Melbourne',
#   'reg': 'Asia-Pacific',
#   'name': 'Victoria Internet Exchange',
#   'url': 'https://www.ix.asn.au/peering/',
#   'stat': 'Active',
#   'date': '20110000',
#   'prfs': '0',
#   'lat': '-37.82000',
#   'lon': '144.97000',
#   'prts': '66',
#   'traf': '111000000',
#   'avg': '51400000',
#   'trgh': '23000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '73',
#   'pc_rank': '8',
#   'pr_rank': '27',
#   'pw_rank': '110',
#   'tr_rank': '17',
#   'prts_url': 'https://www.ix.asn.au/peers-vic/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '1308',
#   'ctry': 'South Africa',
#   'cit': 'Cape Town',
#   'reg': 'Africa',
#   'name': 'NAPAfrica Cape Town',
#   'url': 'https://www.napafrica.net/',
#   'stat': 'Active',
#   'date': '20120000',
#   'prfs': '252104',
#   'lat': '-33.98000',
#   'lon': '18.60000',
#   'prts': '160',
#   'traf': '104000000',
#   'avg': '0',
#   'trgh': '26000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '74',
#   'pc_rank': '2',
#   'pr_rank': '2',
#   'pw_rank': '38',
#   'tr_rank': '3',
#   'prts_url': 'https://www.napafrica.net/who-is-peering/',
#   'q9': 'Yes',
#   'iata': 'SDB',
#   'regct': 78},
#  {'id': '121',
#   'ctry': 'Italy',
#   'cit': 'Torino',
#   'reg': 'Europe',
#   'name': 'Torino Piemonte Exchange Point',
#   'url': 'https://www.top-ix.org/it/home/',
#   'stat': 'Active',
#   'date': '20020400',
#   'prfs': '217948',
#   'lat': '45.22000',
#   'lon': '7.65000',
#   'prts': '120',
#   'traf': '101000000',
#   'avg': '58000000',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '75',
#   'pc_rank': '2',
#   'pr_rank': '30',
#   'pw_rank': '59',
#   'tr_rank': '39',
#   'prts_url': 'https://www.top-ix.org/en/connected_networks/',
#   'q9': 'Yes',
#   'iata': 'TRN',
#   'regct': 325},
#  {'id': '894',
#   'ctry': 'Japan',
#   'cit': 'Tokyo',
#   'reg': 'Asia-Pacific',
#   'name': 'JPNAP Tokyo II - Ikebukuro',
#   'url': 'http://www.jpnap.net/english/jpnap-tokyo-ii/index.html',
#   'stat': 'Active',
#   'date': '20080401',
#   'prfs': '0',
#   'lat': '35.55000',
#   'lon': '139.78000',
#   'prts': '5',
#   'traf': '100000000',
#   'avg': '48000000',
#   'trgh': '19000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-03-25',
#   'tc_rank': '5',
#   'tw_rank': '76',
#   'pc_rank': '12',
#   'pr_rank': '87',
#   'pw_rank': '462',
#   'tr_rank': '18',
#   'prts_url': 'http://www.jpnap.net/english/jpnap-tokyo-ii/customer.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '1350',
#   'ctry': 'Serbia',
#   'cit': 'Belgrade',
#   'reg': 'Europe',
#   'name': 'Serbian Open Exchange',
#   'url': 'http://www.sox.rs/',
#   'stat': 'Active',
#   'date': '20100900',
#   'prfs': '303547',
#   'lat': '44.82958',
#   'lon': '20.46547',
#   'prts': '40',
#   'traf': '100000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '0000-00-00',
#   'tc_rank': '1',
#   'tw_rank': '76',
#   'pc_rank': '1',
#   'pr_rank': '86',
#   'pw_rank': '171',
#   'tr_rank': '40',
#   'prts_url': 'http://www.sox.rs/en/?id=News&lang=en',
#   'q9': 'Yes',
#   'iata': 'BEG',
#   'regct': 325},
#  {'id': '613',
#   'ctry': 'Czech Republic',
#   'cit': 'Prague',
#   'reg': 'Europe',
#   'name': 'Neutral czFree eXchange',
#   'url': 'http://www.nfx.cz/',
#   'stat': 'Active',
#   'date': '20070000',
#   'prfs': '0',
#   'lat': '50.08000',
#   'lon': '14.43000',
#   'prts': '10',
#   'traf': '98000000',
#   'avg': '54000000',
#   'trgh': '15000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '79',
#   'pc_rank': '3',
#   'pr_rank': '150',
#   'pw_rank': '356',
#   'tr_rank': '42',
#   'prts_url': 'http://www.nfx.cz/clenove',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '1149',
#   'ctry': 'United States',
#   'cit': 'New York',
#   'reg': 'North America',
#   'name': 'Digital Realty New York Internet Exchange',
#   'url': 'https://ix.digitalrealty.com/',
#   'stat': 'Active',
#   'date': '20090000',
#   'prfs': '145150',
#   'lat': '40.75000',
#   'lon': '-74.00000',
#   'prts': '68',
#   'traf': '86000000',
#   'avg': '0',
#   'trgh': '30000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '10',
#   'tw_rank': '83',
#   'pc_rank': '17',
#   'pr_rank': '18',
#   'pw_rank': '105',
#   'tr_rank': '11',
#   'prts_url': 'https://ix.digitalrealty.com/',
#   'q9': 'Yes',
#   'iata': 'LGA',
#   'regct': 224},
#  {'id': '195',
#   'ctry': 'Russia',
#   'cit': 'St. Petersburg',
#   'reg': 'Europe',
#   'name': 'MSK-IX St. Petersburg',
#   'url': 'http://www.msk-ix.ru/eng/',
#   'stat': 'Active',
#   'date': '20090000',
#   'prfs': '0',
#   'lat': '59.93000',
#   'lon': '30.30000',
#   'prts': '92',
#   'traf': '83400000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2016-06-06',
#   'tc_rank': '4',
#   'tw_rank': '87',
#   'pc_rank': '7',
#   'pr_rank': '40',
#   'pw_rank': '73',
#   'tr_rank': '47',
#   'prts_url': ' http://www.msk-ix.ru/en/members/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '117',
#   'ctry': 'Israel',
#   'cit': 'Tel Aviv',
#   'reg': 'Europe',
#   'name': 'Israeli Internet Exchange',
#   'url': 'https://en.isoc.org.il/iix/2x.html',
#   'stat': 'Active',
#   'date': '19960000',
#   'prfs': '0',
#   'lat': '32.00000',
#   'lon': '34.90000',
#   'prts': '20',
#   'traf': '83000000',
#   'avg': '48000000',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '88',
#   'pc_rank': '1',
#   'pr_rank': '119',
#   'pw_rank': '259',
#   'tr_rank': '48',
#   'prts_url': 'https://en.isoc.org.il/iix/iix-users',
#   'q9': 'Yes',
#   'iata': 'TLV',
#   'regct': 325},
#  {'id': '332',
#   'ctry': 'United States',
#   'cit': 'Portland',
#   'reg': 'North America',
#   'name': 'Northwest Access Exchange',
#   'url': 'http://www.nwax.net/',
#   'stat': 'Active',
#   'date': '20021200',
#   'prfs': '242807',
#   'lat': '45.52000',
#   'lon': '-122.68000',
#   'prts': '89',
#   'traf': '80000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2018-04-16',
#   'tc_rank': '11',
#   'tw_rank': '89',
#   'pc_rank': '12',
#   'pr_rank': '13',
#   'pw_rank': '78',
#   'tr_rank': '12',
#   'prts_url': 'http://www.nwax.net/Members',
#   'q9': 'Yes',
#   'iata': 'PDX',
#   'regct': 224},
#  {'id': '49',
#   'ctry': 'Colombia',
#   'cit': 'Bogotá',
#   'reg': 'Latin America',
#   'name': 'NAP-Colombia',
#   'url': 'http://nap.co/',
#   'stat': 'Active',
#   'date': '20000629',
#   'prfs': '0',
#   'lat': '4.70000',
#   'lon': '-74.13000',
#   'prts': '21',
#   'traf': '80000000',
#   'avg': '0',
#   'trgh': '12000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '89',
#   'pc_rank': '1',
#   'pr_rank': '24',
#   'pw_rank': '247',
#   'tr_rank': '8',
#   'prts_url': 'http://nap.co/html/integrantes.php',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '128',
#   'ctry': 'Japan',
#   'cit': 'Osaka',
#   'reg': 'Asia-Pacific',
#   'name': 'NSPIXP-3',
#   'url': 'http://nspixp.wide.ad.jp/3/',
#   'stat': 'Active',
#   'date': '19970300',
#   'prfs': '0',
#   'lat': '34.53000',
#   'lon': '135.50000',
#   'prts': '23',
#   'traf': '72000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': '6',
#   'tw_rank': '92',
#   'pc_rank': '9',
#   'pr_rank': '54',
#   'pw_rank': '232',
#   'tr_rank': '19',
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '174',
#   'ctry': 'Norway',
#   'cit': 'Oslo',
#   'reg': 'Europe',
#   'name': 'Norwegian Internet Exchange Oslo 1',
#   'url': 'http://www.nix.no/',
#   'stat': 'Active',
#   'date': '19930300',
#   'prfs': '0',
#   'lat': '59.95000',
#   'lon': '10.70000',
#   'prts': '91',
#   'traf': '60000000',
#   'avg': '0',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '93',
#   'pc_rank': '1',
#   'pr_rank': '41',
#   'pw_rank': '77',
#   'tr_rank': '49',
#   'prts_url': 'https://www.nix.no/who-is-connected/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '145',
#   'ctry': 'South Korea',
#   'cit': 'Seoul',
#   'reg': 'Asia-Pacific',
#   'name': 'LGDACOM Internet Exchange',
#   'url': '',
#   'stat': 'Active',
#   'date': '19961000',
#   'prfs': '0',
#   'lat': '37.50000',
#   'lon': '126.93000',
#   'prts': '52',
#   'traf': '70000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': '2',
#   'tw_rank': '94',
#   'pc_rank': '2',
#   'pr_rank': '30',
#   'pw_rank': '128',
#   'tr_rank': '20',
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '1341',
#   'ctry': 'United Arab Emirates',
#   'cit': 'Dubai',
#   'reg': 'Europe',
#   'name': 'UAE-IX by DE-CIX',
#   'url': 'https://www.uae-ix.net/',
#   'stat': 'Active',
#   'date': '20120224',
#   'prfs': '2438',
#   'lat': '25.25000',
#   'lon': '55.33000',
#   'prts': '70',
#   'traf': '69600000',
#   'avg': '49600000',
#   'trgh': '30000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '97',
#   'pc_rank': '1',
#   'pr_rank': '51',
#   'pw_rank': '102',
#   'tr_rank': '50',
#   'prts_url': 'https://www.uae-ix.net/customers-partners/customers/',
#   'q9': 'Yes',
#   'iata': 'DXB',
#   'regct': 325},
#  {'id': '186',
#   'ctry': 'Portugal',
#   'cit': 'Lisbon',
#   'reg': 'Europe',
#   'name': 'Gigabit Portuguese Internet Exchange Point',
#   'url': 'https://gigapix.pt/en/index/',
#   'stat': 'Active',
#   'date': '19951000',
#   'prfs': '181368',
#   'lat': '38.73000',
#   'lon': '-9.15000',
#   'prts': '33',
#   'traf': '69500000',
#   'avg': '39500000',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '98',
#   'pc_rank': '1',
#   'pr_rank': '95',
#   'pw_rank': '190',
#   'tr_rank': '51',
#   'prts_url': 'https://gigapix.pt/en/members/',
#   'q9': 'No',
#   'iata': 'LIS',
#   'regct': 325},
#  {'id': '120',
#   'ctry': 'Italy',
#   'cit': 'Rome',
#   'reg': 'Europe',
#   'name': 'NaMeX - Nautilus Mediterranean Exchange Point',
#   'url': 'https://www.namex.it/',
#   'stat': 'Active',
#   'date': '19960000',
#   'prfs': '0',
#   'lat': '41.90000',
#   'lon': '12.45000',
#   'prts': '88',
#   'traf': '69000000',
#   'avg': '47000000',
#   'trgh': '15000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '3',
#   'tw_rank': '99',
#   'pc_rank': '3',
#   'pr_rank': '43',
#   'pw_rank': '81',
#   'tr_rank': '52',
#   'prts_url': 'https://www.namex.it/connected_networks/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '373',
#   'ctry': 'United States',
#   'cit': 'Los Angeles',
#   'reg': 'North America',
#   'name': 'Any2 California',
#   'url': 'https://www.coresite.com/',
#   'stat': 'Active',
#   'date': '20051200',
#   'prfs': '621289',
#   'lat': '33.97000',
#   'lon': '-118.25000',
#   'prts': '449',
#   'traf': '68000000',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2009-06-22',
#   'tc_rank': '14',
#   'tw_rank': '100',
#   'pc_rank': '1',
#   'pr_rank': '1',
#   'pw_rank': '8',
#   'tr_rank': '16',
#   'prts_url': 'https://www.coresite.com/solutions/interconnection/peering-exchanges/any2-internet-peering-exchange/any2-peering-participants',
#   'q9': 'Yes',
#   'iata': 'SNA',
#   'regct': 224},
#  {'id': '1332',
#   'ctry': 'United Kingdom',
#   'cit': 'Manchester',
#   'reg': 'Europe',
#   'name': 'IXManchester powered by LINX',
#   'url': 'https://www.linx.net/',
#   'stat': 'Active',
#   'date': '20120429',
#   'prfs': '4695',
#   'lat': '53.35000',
#   'lon': '-2.27000',
#   'prts': '89',
#   'traf': '64000000',
#   'avg': '45000000',
#   'trgh': '20000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2018-08-22',
#   'tc_rank': '3',
#   'tw_rank': '101',
#   'pc_rank': '4',
#   'pr_rank': '42',
#   'pw_rank': '78',
#   'tr_rank': '53',
#   'prts_url': 'https://portal.linx.net/members/list-ip-asn',
#   'q9': 'Yes',
#   'iata': 'MAN',
#   'regct': 325},
#  {'id': '516',
#   'ctry': 'Russia',
#   'cit': 'Krasnoyarsk',
#   'reg': 'Europe',
#   'name': 'Krasnoyarsk Internet Exchange',
#   'url': 'http://www.red-ix.ru/',
#   'stat': 'Active',
#   'date': '20060000',
#   'prfs': '0',
#   'lat': '56.17000',
#   'lon': '92.50000',
#   'prts': '48',
#   'traf': '63000000',
#   'avg': '40000000',
#   'trgh': '16500000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '5',
#   'tw_rank': '103',
#   'pc_rank': '15',
#   'pr_rank': '71',
#   'pw_rank': '142',
#   'tr_rank': '54',
#   'prts_url': 'http://www.red-ix.ru/members/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '574',
#   'ctry': 'Slovakia',
#   'cit': 'Bratislava',
#   'reg': 'Europe',
#   'name': 'NIX.SK - exSitelIX',
#   'url': 'https://www.nix.sk/sk',
#   'stat': 'Active',
#   'date': '20050801',
#   'prfs': '0',
#   'lat': '48.20000',
#   'lon': '17.20000',
#   'prts': '45',
#   'traf': '60000000',
#   'avg': '0',
#   'trgh': '13000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': '2',
#   'tw_rank': '104',
#   'pc_rank': '2',
#   'pr_rank': '78',
#   'pw_rank': '153',
#   'tr_rank': '55',
#   'prts_url': 'https://www.nix.sk/en/networks',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '16',
#   'ctry': 'Bangladesh',
#   'cit': 'Dhaka',
#   'reg': 'Asia-Pacific',
#   'name': 'Bangladesh Internet Exchange',
#   'url': 'http://www.bdix.net/',
#   'stat': 'Active',
#   'date': '20040826',
#   'prfs': '4640',
#   'lat': '23.77000',
#   'lon': '90.38000',
#   'prts': '79',
#   'traf': '59000000',
#   'avg': '30000000',
#   'trgh': '10000000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
#   'tc_rank': '1',
#   'tw_rank': '106',
#   'pc_rank': '1',
#   'pr_rank': '23',
#   'pw_rank': '93',
#   'tr_rank': '23',
#   'prts_url': 'http://www.bdix.net/members.html',
#   'q9': 'Yes',
#   'iata': 'DAC',
#   'regct': 204},
#  {'id': '9',
#   'ctry': 'Australia',
#   'cit': 'Perth',
#   'reg': 'Asia-Pacific',
#   'name': 'Western Australian Internet Association',
#   'url': 'https://www.ix.asn.au/peering/',
#   'stat': 'Active',
#   'date': '19970000',
#   'prfs': '32274',
#   'lat': '-31.93000',
#   'lon': '115.95000',
#   'prts': '81',
#   'traf': '58000000',
#   'avg': '29400000',
#   'trgh': '11500000',
#   'ipv6_avg': '0.000000',
#   'pch': 'Yes',
#   'updt': '2019-07-07',
# ...
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2044',
#   'ctry': 'India',
#   'cit': 'Guntur',
#   'reg': 'Asia-Pacific',
#   'name': 'Remki Internet Exchange',
#   'url': 'https://internet-exchange.remki.net/',
#   'stat': 'Unknown',
#   'date': '20170000',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2046',
#   'ctry': 'India',
#   'cit': 'Guwahati',
#   'reg': 'Asia-Pacific',
#   'name': 'National Internet Exchange of India',
#   'url': 'http://nixi.in/en',
#   'stat': 'Unknown',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2019-07-07',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'http://nixi.in/en/connected-parties',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2049',
#   'ctry': 'Canada',
#   'cit': 'Charlottetown',
#   'reg': 'North America',
#   'name': 'Charlottetown Internet Exchange',
#   'url': '',
#   'stat': 'Unknown',
#   'date': '0',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2051',
#   'ctry': 'United States',
#   'cit': 'Cleveland',
#   'reg': 'North America',
#   'name': 'MidWest-IX Cleveland',
#   'url': 'https://midwest-ix.com',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '41.49307',
#   'lon': '-81.66832',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2053',
#   'ctry': 'Canada',
#   'cit': 'Saint John',
#   'reg': 'North America',
#   'name': 'Saint John IXP',
#   'url': 'https://sjix.ca',
#   'stat': 'Planned',
#   'date': '20180901',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'https://sjix.ca/peering-lan-ip-assignments/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2056',
#   'ctry': 'Puerto Rico',
#   'cit': 'San Juan',
#   'reg': 'North America',
#   'name': 'Puerto Rico Internet Exchange',
#   'url': 'https://www.puertorico-ix.com/',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': '18.47000',
#   'lon': '-66.11000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2060',
#   'ctry': 'Colombia',
#   'cit': 'Bogota',
#   'reg': 'Latin America',
#   'name': 'IXP del Caribe',
#   'url': '',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': '4.70000',
#   'lon': '-74.13000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '2062',
#   'ctry': 'Portugal',
#   'cit': 'Lisbon',
#   'reg': 'Europe',
#   'name': 'DE-CIX Lisbon',
#   'url': 'https://www.de-cix.net/en/locations/portugal/Lisbon',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '38.73000',
#   'lon': '-9.15000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2063',
#   'ctry': 'Switzerland',
#   'cit': 'Frauenfeld',
#   'reg': 'Europe',
#   'name': 'CHIX',
#   'url': 'https://chix.ch/',
#   'stat': 'Planned',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2070',
#   'ctry': 'Guinea',
#   'cit': 'Conakry',
#   'reg': 'Africa',
#   'name': 'IXP-GUINEE',
#   'url': '',
#   'stat': 'Planned',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 78},
#  {'id': '2071',
#   'ctry': 'Canada',
#   'cit': 'Iqaluit',
#   'reg': 'North America',
#   'name': 'Iqaluit Internet Exchange',
#   'url': 'https://arcticix.ca/',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2074',
#   'ctry': 'Pakistan',
#   'cit': 'Lahore',
#   'reg': 'Asia-Pacific',
#   'name': 'PKIXP Lahore',
#   'url': 'http://www.pkix.pk/index.html',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': '31.52000',
#   'lon': '74.40000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2077',
#   'ctry': 'United States',
#   'cit': 'St. Louis',
#   'reg': 'North America',
#   'name': 'MidWest-IX St. Louis',
#   'url': 'https://midwest-ix.com',
#   'stat': 'Unknown',
#   'date': '0',
#   'prfs': '0',
#   'lat': '38.58000',
#   'lon': '-90.20000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'https://www.midwest-ix.com/locations/stlouis/index.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2078',
#   'ctry': 'United Kingdom',
#   'cit': 'London',
#   'reg': 'Europe',
#   'name': 'Unifi-IX',
#   'url': 'http://www.unifi-ix.net/',
#   'stat': 'Planned',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': '51.48000',
#   'lon': '-0.45000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2080',
#   'ctry': 'United States',
#   'cit': 'Fremont',
#   'reg': 'North America',
#   'name': 'Experimental Virtual Internet Exchange',
#   'url': 'https://evix.org',
#   'stat': 'Not an exchange',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': '37.56283',
#   'lon': '-122.00044',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '2018-12-16',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'https://evix.org/#peers',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2082',
#   'ctry': 'Kuwait',
#   'cit': 'Kuwait',
#   'reg': 'Europe',
#   'name': 'Kuwait Internet Exchange',
#   'url': 'https://ix.kw/',
#   'stat': 'Planned',
#   'date': '20180000',
#   'prfs': '0',
#   'lat': '29.22000',
#   'lon': '47.98000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2084',
#   'ctry': 'France',
#   'cit': 'Annecy',
#   'reg': 'Europe',
#   'name': 'AnnecIX ',
#   'url': 'https://www.rezopole.net/',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2085',
#   'ctry': 'Mongolia',
#   'cit': 'Ulaanbaatar',
#   'reg': 'Asia-Pacific',
#   'name': 'MISPA-IXP',
#   'url': '',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': '47.90882',
#   'lon': '106.86346',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2104',
#   'ctry': 'Belgium',
#   'cit': 'Brussels',
#   'reg': 'Europe',
#   'name': 'Belgium Internet Exchange',
#   'url': 'https://belgiumix.net/',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '50.90000',
#   'lon': '4.53000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'https://belgiumix.net/members.html',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2115',
#   'ctry': 'Canada',
#   'cit': 'Whitehorse',
#   'reg': 'North America',
#   'name': 'Whitehorse Internet Exchange',
#   'url': 'https://arcticix.ca/',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2116',
#   'ctry': 'Canada',
#   'cit': 'Yellowknife',
#   'reg': 'North America',
#   'name': 'Yellowknife Internet Exchange',
#   'url': 'https://arcticix.ca/',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': None,
#   'lon': None,
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 224},
#  {'id': '2118',
#   'ctry': 'Turkey',
#   'cit': 'Istanbul',
#   'reg': 'Europe',
#   'name': 'TR-IX',
#   'url': 'https://tr-ix.com/',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '40.97000',
#   'lon': '28.82000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2120',
#   'ctry': 'Saint Kitts and Nevis',
#   'cit': 'Basseterre',
#   'reg': 'Latin America',
#   'name': 'Saint Kitts and Nevis Internet Exchange',
#   'url': '',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '17.28000',
#   'lon': '-62.73000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 122},
#  {'id': '2121',
#   'ctry': 'Saudi Arabia',
#   'cit': 'Jeddah',
#   'reg': 'Europe',
#   'name': 'JEDIX',
#   'url': 'https://www.jedix.net/',
#   'stat': 'Planned',
#   'date': '20181200',
#   'prfs': '0',
#   'lat': '21.67000',
#   'lon': '39.15000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': 'https://www.jedix.net/customer-list/',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2122',
#   'ctry': 'Qatar',
#   'cit': 'Doha',
#   'reg': 'Europe',
#   'name': 'Doha IX',
#   'url': '',
#   'stat': 'Unknown',
#   'date': '0',
#   'prfs': '0',
#   'lat': '25.25000',
#   'lon': '51.57000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2124',
#   'ctry': 'Syria',
#   'cit': 'Damascus',
#   'reg': 'Europe',
#   'name': 'Syrian Internet Exchange Point',
#   'url': '',
#   'stat': 'Planned',
#   'date': '0',
#   'prfs': '0',
#   'lat': '33.42000',
#   'lon': '36.52000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 325},
#  {'id': '2128',
#   'ctry': 'India',
#   'cit': 'Chennai',
#   'reg': 'Asia-Pacific',
#   'name': 'DE-CIX Chennai',
#   'url': 'https://www.de-cix.in/locations/de-cix-chennai',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '13.07000',
#   'lon': '80.20000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2129',
#   'ctry': 'India',
#   'cit': 'New Delhi',
#   'reg': 'Asia-Pacific',
#   'name': 'DE-CIX Delhi',
#   'url': 'https://www.de-cix.in/locations/de-cix-delhi',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '28.58000',
#   'lon': '77.20000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204},
#  {'id': '2130',
#   'ctry': 'India',
#   'cit': 'Kolkata',
#   'reg': 'Asia-Pacific',
#   'name': ' DE-CIX Kolkata',
#   'url': 'https://www.de-cix.in/locations/de-cix-kolkata',
#   'stat': 'Planned',
#   'date': '20190000',
#   'prfs': '0',
#   'lat': '22.57000',
#   'lon': '88.40000',
#   'prts': '0',
#   'traf': '0',
#   'avg': '0',
#   'trgh': '0',
#   'ipv6_avg': '0.000000',
#   'pch': 'No',
#   'updt': '0000-00-00',
#   'tc_rank': None,
#   'tw_rank': None,
#   'pc_rank': None,
#   'pr_rank': None,
#   'pw_rank': None,
#   'tr_rank': None,
#   'prts_url': '',
#   'q9': 'No',
#   'iata': '',
#   'regct': 204}]
