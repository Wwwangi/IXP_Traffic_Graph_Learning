# %%
# %store -r mapped
# %store -r subnets
# %store -r DB3
# %store -r PDB

# %%
sum=0
for item in subnets:
    if(item['traffic_graph_url']!=''):
        sum+=1
print(sum)
# Out:
# 346

# %%
mapped[1]
# Out:
# {'IXP_Country_ISO_Alpha2': 'US',
#  'PDB_id': '2',
#  'IXP_name_PDB': 'Equinix Chicago',
#  'IXP_City': 'Chicago',
#  'IXP_region_continent': 'North America',
#  'Date_Creation_IXP_PDB': '2010-07-29T00:00:00Z',
#  'IXP_Website': 'https://ix.equinix.com',
#  'IXP_Url_Stats': '',
#  'IXPDB_id': '236',
#  'IXP_name_IXPDB': 'Equinix Chicago (Equinix Chicago)',
#  'Date_update_IXPDB': '2019-08-07T13:04:58Z'}

# %%
DB3[160]
# Out:
# {'id': '946',
#  'Country': 'United States',
#  'IXP_id': 'Digital Realty Phoenix Internet Exchange',
#  'URL(website)': 'https://ix.digitalrealty.com/',
#  'Location': 'Phoenix',
#  'URL(Graph stats)': 'none',
#  'region_continent': 'North America',
#  'created': '20080602',
#  'updated': '2019-07-28',
#  'participants_url': 'https://ix.digitalrealty.com/'}

# %%
PDB[2]
# Out:
# {'id_PDB': 2, 'prefix_PDB': '208.115.136.0/23', 'protocol_PDB': 'IPv4'}

# %%
for i in range(len(mapped)):
    aa=0
    prefix_PDB=[]
    graph=[]
    comb=0
    obtain=False
    for x in PDB:
        if(mapped[i]['PDB_id']==str(x['id_PDB'])):
            prefix_PDB.append(x['prefix_PDB'])
            #print(prefix_PDB)
    for j in range(len(prefix_PDB)):
        for k in range(len(subnets)):
            if(prefix_PDB[j]==subnets[k]['subnet']):
                aa=1
                cc=0
                obtain=True
                comb=subnets[k]['parent']
                mapped[i]['PCH_id']=comb
                #print(comb)
                for item in subnets:
                    if(item['parent']==comb and item['traffic_graph_url']!=''):
                        graph.append(item['traffic_graph_url'])
                if(len(graph)!=0):
                    #print(len(graph))
                    mapped[i]['graph_url_PCH']=graph
                else:
                    mapped[i]['graph_url_PCH']=''
                for item in DB3:
                    if(item['id']==comb):
                        cc=1
                        mapped[i]['IXP_name_PCH']=item['IXP_id']
                        mapped[i]['Date_Creation_IXP_PCH']=item['created']
                        mapped[i]['Date_updated_PCH']=item['updated']
                if(cc==0):
                    mapped[i]['IXP_name_PCH']=''
                    mapped[i]['Date_Creation_IXP_PCH']=''
                    mapped[i]['Date_updated_PCH']=''
                break
    if(aa==0):
        mapped[i]['PCH_id']=''
        mapped[i]['graph_url_PCH']=''
        mapped[i]['IXP_name_PCH']=''
        mapped[i]['Date_Creation_IXP_PCH']=''
        mapped[i]['Date_updated_PCH']=''
                
        if(obtain==True):
            break

# %%
ToCheck=[]
for i in range(len(mapped)):
    ToCheck.append(mapped[i]['PCH_id'])

# %%
pip install pycountry
# Out:
# Requirement already satisfied: pycountry in c:\users\10111\anaconda3\lib\site-packages (19.7.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
DB3[5]
# Out:
# {'id': '1124',
#  'Country': 'France',
#  'IXP_id': 'France-IX',
#  'URL(website)': 'https://www.franceix.net/en/',
#  'Location': 'Paris',
#  'URL(Graph stats)': 'none',
#  'region_continent': 'Europe',
#  'created': '20101100',
#  'updated': '2019-07-28',
#  'participants_url': 'https://www.franceix.net/en/france-ix-paris/members-in-paris/'}

# %%
subnets[5]
# Out:
# {'id': '195',
#  'name': 'AusBONE-BIX',
#  'subnet': '198.32.230.0/24',
#  'protocol': 'IPv4',
#  'traffic_graph_url': '',
#  'traffic_url': '',
#  'traffic(in bytes)': '0',
#  'parent': '4'}

# %%
import pycountry
sum=0
mapped1=[]
for item in DB3:
    tem_d={}
    graph1=[]
    if(item['id'] not in ToCheck):
        sum+=1
        if(item['Country']!=''):
            change=pycountry.countries.get(name=item['Country'])
            if change:
                tem_d['IXP_Country_ISO_Alpha2']=change.alpha_2
            else:
                tem_d['IXP_Country_ISO_Alpha2']=''
        else:
            tem_d['IXP_Country_ISO_Alpha2']=''
        tem_d['IXPDB_id']=''
        tem_d['PCH_id']=item['id']
        tem_d['PDB_id']=''
        tem_d['IXP_name_IXPDB']=''
        tem_d['IXP_name_PCH']=item['IXP_id']
        tem_d['IXP_name_PDB']=''
        tem_d['IXP_City']=item['Location']
        tem_d['IXP_region_continent']=item['region_continent']
        tem_d['Date_Creation_IXP_PDB']=''
        tem_d['Date_Creation_IXP_PCH']=item['created']
        tem_d['Date_updated_PCH']=item['updated']
        tem_d['Date_update_IXPDB']=''
        tem_d['IXP_Website']=item['URL(website)']
        tem_d['IXP_Url_Stats']=''
        for x in subnets:
            if(x['parent']==item['id'] and x['traffic_graph_url']!=''):
                graph1.append(x['traffic_graph_url'])
        if(len(graph)!=0):
            #print(len(graph))
            tem_d['graph_url_PCH']=graph
        else:
            tem_d['graph_url_PCH']=''
        tem_d['comment']=''
        tem_d['date']=''
        mapped1.append(tem_d)

# %%
len(DB3)  # Total number of IXPs in PCH dataset
# Out:
# 957

# %%
len(mapped1)    # 957 - 619 = 338 IXP in PCH is matched with IXP in PDB
# Out:
# 619

# %%
len(mapped)   # 704 - 338 = 366 rows do not have PCH IDs
# Out:
# 704

# %%
mapped2=[]
mapped2=mapped+mapped1

# %%
len(mapped2)   # Total number of entries in 3 dataset (the combination)
# Out:
# 1323

# %%
mapped[2]
# Out:
# {'IXP_Country_ISO_Alpha2': 'US',
#  'PDB_id': '3',
#  'IXP_name_PDB': 'Equinix Dallas',
#  'IXP_City': 'Dallas',
#  'IXP_region_continent': 'North America',
#  'Date_Creation_IXP_PDB': '2010-07-29T00:00:00Z',
#  'IXP_Website': 'https://ix.equinix.com',
#  'IXP_Url_Stats': '',
#  'IXPDB_id': '235',
#  'IXP_name_IXPDB': 'Equinix Dallas (Equinix Dallas)',
#  'Date_update_IXPDB': '2019-08-07T13:04:58Z',
#  'PCH_id': '278',
#  'graph_url_PCH': '',
#  'IXP_name_PCH': 'Equinix IBX Dallas',
#  'Date_Creation_IXP_PCH': '20010615',
#  'Date_updated_PCH': '0000-00-00'}

# %%
mapped1[2]
# Out:
# {'IXP_Country_ISO_Alpha2': 'CN',
#  'IXPDB_id': '',
#  'PCH_id': '96',
#  'PDB_id': '',
#  'IXP_name_IXPDB': '',
#  'IXP_name_PCH': 'Hong Kong Internet Exchange',
#  'IXP_name_PDB': '',
#  'IXP_City': 'Hong Kong',
#  'IXP_region_continent': 'Asia-Pacific',
#  'Date_Creation_IXP_PDB': '',
#  'Date_Creation_IXP_PCH': '19950400',
#  'Date_updated_PCH': '2019-01-28',
#  'Date_update_IXPDB': '',
#  'IXP_Website': 'http://www.hkix.net',
#  'IXP_Url_Stats': '',
#  'graph_url_PCH': '',
#  'comment': '',
#  'date': ''}

# %%
import csv
with open('D://third/python/mapping_all3.csv','w',encoding='GB18030',newline='')as csvfile:
    writer=csv.writer(csvfile)
    writer.writerow(['IXP_Country_ISO_Alpha2','IXPDB_ID','PCH_ID','PeeringDB_ID','IXP_name_IXPDB','IXP_name_PCH','IXP_name_PDB','IXP_City','IXP_region_continent','Date_Creation_PDB','Date_Creation_PCH','Date_Update_PCH','Date_Update_IXPDB','IXP_Website','IXP_Url_Stats','IXP_Url_Stats_PCH','Url_Stats_comments','Date_check_Stats'])
    for i in range(len(mapped2)):
        writer.writerow([mapped2[i]['IXP_Country_ISO_Alpha2'],mapped2[i]['IXPDB_id'],mapped2[i]['PCH_id'],mapped2[i]['PDB_id'],mapped2[i]['IXP_name_IXPDB'],mapped2[i]['IXP_name_PCH'],mapped2[i]['IXP_name_PDB'],mapped2[i]['IXP_City'],mapped2[i]['IXP_region_continent'],mapped2[i]['Date_Creation_IXP_PDB'],mapped2[i]['Date_Creation_IXP_PCH'],mapped2[i]['Date_updated_PCH'],mapped2[i]['Date_update_IXPDB'],mapped2[i]['IXP_Website'],mapped2[i]['IXP_Url_Stats'],mapped2[i]['graph_url_PCH'],'none','none'])

# %%
file=open('IXP.csv')
file.readline()

t=[]

for line in file:
    items=line.strip().split(',')
    PeerDB_id=str(items[3])
    comment=str(items[-2])
    date=str(items[-1])
    #print(check)
    t.append({'PeerDB_id':PeerDB_id,'comment':comment,'date':date})

# %%
t
# Out:
# [{'PeerDB_id': '13', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '14', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '18', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '21',
#   'comment': 'OK (Grafana home page linked to IX aggregates Overview and Peers)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '23', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '24', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '26',
#   'comment': 'Not OK (traffic data graphs available at https://www.ams-ix.net/ams/documentation/total-stats)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '29', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '30', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '31', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '33', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '35', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '40',
#   'comment': 'Not OK (connection time out)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '41',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '42', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '43', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '48', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '50', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '53', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '55',
#   'comment': 'OK (Links to member traffic graphs)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '59', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '60', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '62', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '63', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '64', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '69', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '70', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '71', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '72', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '73',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '74', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '78', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '83', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '84', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '87', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '89', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '91',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '92',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '95', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '96',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '98', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '100', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '107', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '115', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '119', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '121', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '123',
#   'comment': 'Not OK (need to login)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '127',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '145', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '171', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '172', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '173', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '174', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '175', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '176', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '177', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '178', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '184', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '192', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '193', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '194', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '209',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '210',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '223', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '228', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '230', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '231',
#   'comment': 'Not OK (404 Page not found)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '239', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '241', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '248', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '252', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '255', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '257', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '264', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '270', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '274', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '291',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '298', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '301', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '303', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '311', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '313', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '314', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '319', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '321', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '326', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '327', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '328', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '331', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '347', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '350', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '355', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '358',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '359', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '366',
#   'comment': 'Not OK (traffic data graphs available at https://www.ams-ix.net/car/documentation/total-stats)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '372',
#   'comment': 'Not OK (404 Page not found but traffic data graphs available at http://www.balcan-ix.net/traffic-statistics/)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '378', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '379', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '380', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '383', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '387', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '398', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '415', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '422', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '429', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '430',
#   'comment': 'Not OK (totally blank)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '435',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '446', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '463',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '474',
#   'comment': 'Not OK (access to the site is limited for security reasons)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '481',
#   'comment': 'Not OK (need to login)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '482', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '488',
#   'comment': 'Not OK (access to the site is blocked in accordance with company policy)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '491',
#   'comment': 'Not OK (access to the site is limited for security reasons)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '492',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '499',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '512', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '513',
#   'comment': 'OK (Grafana home page linked to IX aggregates  Overview and Peers)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '526', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '528',
#   'comment': 'Not OK (requested URL not found on the server)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '543', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '556', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '558', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '559', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '564', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '575', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '576',
#   'comment': 'OK (Grafana home page linked to IX aggregates Overview and Peers)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '577',
#   'comment': 'Not OK (traffic data graphs available at https://www.ams-ix.net/hk/documentation/total-stats)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '580', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '582', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '583', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '587', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '592',
#   'comment': 'Not OK (404 Page not found but traffic data graphs available at https://www.napafrica.net/peering-traffic/)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '597',
#   'comment': 'Not OK (404 Page not found but traffic data graphs available at https://www.napafrica.net/peering-traffic/)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '603', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '627', 'comment': 'Not OK (Coming soon)', 'date': '2019/7/11'},
#  {'PeerDB_id': '628', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '638', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '639', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '655', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '662', 'comment': 'Not OK (No graph)', 'date': '2019/7/11'},
#  {'PeerDB_id': '676',
#   'comment': 'OK (should click the link)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '683', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '691',
#   'comment': 'OK (Grafana home page linked to IX aggregates Overview and Peers)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '694',
#   'comment': 'Not OK (404 Page not found but traffic data graphs available at http://www.gixa.org.gh/technical/statistics/)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '699',
#   'comment': 'Not OK (ERR_CERT_COMMON_NAME_INVALID)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '703', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '705', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '706', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '707', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '708', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '709', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '710', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '711', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '713',
#   'comment': 'Not OK (traffic data graphs available at https://www.peering.cz/statistics)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '716',
#   'comment': 'OK (Grafana home page linked to IX aggregates Overview and Peers)',
#   'date': '2019/7/11'},
#  {'PeerDB_id': '745', 'comment': 'OK', 'date': '2019/7/11'},
#  {'PeerDB_id': '776',
#   'comment': 'Not OK (Connection refused)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '777',
#   'comment': 'Not OK (404 Page not found)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '779',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '780',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '781',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '790', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '796',
#   'comment': 'Not OK (ERR_CERT_DATE_INVALID)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '804', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '810',
#   'comment': 'OK (username: civix  password: civix)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '818', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '823', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '832',
#   'comment': 'OK (last updated: 2019/6/25)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '851',
#   'comment': 'OK (should click the figure first)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '859', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '864',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '876', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '880', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '922',
#   'comment': 'Not OK (Account has been suspended)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '938', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '940',
#   'comment': 'OK (Only graphs for TTIX2 Sourthern IXP   no graphs for TTIX Northern IXP)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '944',
#   'comment': 'Not OK (traffic graphs available at https://www.ams-ix.net/chi/documentation/total-stats)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '954',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '965',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '969',
#   'comment': 'Not OK (404 Page not found)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '976',
#   'comment': 'OK (Grafana home page linked to IX aggregates  Overview and Peers)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '977',
#   'comment': 'OK (Grafana home page linked to IX aggregates Overview and Peers)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '984',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1006',
#   'comment': 'Not OK (Need to login)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1007', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1009',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1016', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1019', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1023', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1025', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1032', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1056',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1073', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1086', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1094', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1105', 'comment': 'Not OK (Coming soon)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1131', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1146', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1149', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1150', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1154', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1160', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1169', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1172', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1174',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1175',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1180',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1207', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1209', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1214', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1235',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1242',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1249', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1276', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1277', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1285', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1307',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1308',
#   'comment': 'Not OK (traffic graph available at https://my.lsix.net/statistics/ixp)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1317',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1320', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1329', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1332', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1335', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1375',
#   'comment': 'Not OK (ERR_CERT_REVOKED)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1418', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1419', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1420', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1428', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1464', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1481', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1484', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1508',
#   'comment': '"OK (But still have to click on the ""Statistics"" label)"',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1514', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1516', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1522',
#   'comment': 'Not OK (connection time out)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1561', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1623', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1628',
#   'comment': 'OK (Main page that has links to all the traffic graph of several IXPs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1660',
#   'comment': 'OK (traffic graph availble at http://www.ixp.ec/#3)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1668',
#   'comment': 'OK (just one single png graph for month  but other graphs can be obtained by changing the string in url)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1679',
#   'comment': 'Not OK (ERR_CERT_DATE_INVALID)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1684', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1748', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1812', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1829', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1842',
#   'comment': 'Not OK (404 Page not found)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1847', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1861', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1862', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1863', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1868',
#   'comment': 'Not OK (traffic graph available at https://www.sthix.net/index.php/home/statistics/)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1869', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1870',
#   'comment': 'Not OK (ERR_CONNECTION_RESET)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '1886', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1919', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1923', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1925', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1926', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1927', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1983', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '1997', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1998', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '1999',
#   'comment': 'Not OK (traffic graph available at https://pit-ix.net/#section-services)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2004',
#   'comment': 'Not OK (graphs cannot be loaded)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2005', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2031', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2032',
#   'comment': 'Not OK (error between cloudflare and origin web server)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2035', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2039', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2040', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2070', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2078', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2084',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2086', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2102',
#   'comment': 'OK (just one single png graph)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2116', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2130', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2131', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2149', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2176', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2182', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2183', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2186', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2245',
#   'comment': 'Not OK (ERR_CERT_COMMON_NAME_INVALID)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2250', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2272',
#   'comment': 'OK (Only graphs for TTIX2 Sourthern IXP  no graphs for TTIX Northern IXP)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2274', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2289', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2291', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2341',
#   'comment': 'OK (But no x and y axis labels)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2353',
#   'comment': 'Not OK (ERR_CONNECTION_CLOSED)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2355',
#   'comment': 'OK (should click on the figure first to get more graphs)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2365', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2386', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2410', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2415',
#   'comment': 'Not OK (ERR_CONNECTION_RESET)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2447', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2452',
#   'comment': 'OK (A daily traffic graph but do not know what day it is. Maybe not updated in time)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2454', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2494', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2495', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2497',
#   'comment': 'Not OK (traffic graph available at https://kaznix.kz/ru/monitoring)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2516',
#   'comment': 'Not OK (404 Page not found)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2522',
#   'comment': 'Not OK (connection time out)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2527',
#   'comment': 'Not OK (graphs cannot be loaded)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2541',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2551', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2554',
#   'comment': 'Not OK (name not resolved)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2558', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2568', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2585',
#   'comment': 'Not OK (traffic graph available at http://www.stlix.net/stats.php)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2587', 'comment': 'OK', 'date': '2019/7/25'},
#  {'PeerDB_id': '2588',
#   'comment': 'Not OK (graffic graph available at https://www.de-cix.in/statistics)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2589',
#   'comment': 'Not OK (graffic graph available at https://www.de-cix.in/statistics)',
#   'date': '2019/7/25'},
#  {'PeerDB_id': '2601', 'comment': 'Not OK (No graph)', 'date': '2019/7/25'},
#  {'PeerDB_id': '2611',
#   'comment': 'OK (should click on the figure first to get more graphs)',
#   'date': '2019/7/25'}]

# %%
import csv
with open('D://third/python/mapping_all3_with_graph_url.csv','w',encoding='GB18030',newline='')as csvfile:
    writer=csv.writer(csvfile)
    writer.writerow(['IXP_Country_ISO_Alpha2','IXPDB_ID','PCH_ID','PeeringDB_ID','IXP_name_IXPDB','IXP_name_PCH','IXP_name_PDB','IXP_City','IXP_region_continent','Date_Creation_PDB','Date_Creation_PCH','Date_Update_PCH','Date_Update_IXPDB','IXP_Website','IXP_Url_Stats','IXP_Url_Stats_PCH','Url_Stats_comments','Date_check_Stats'])
    for i in range(len(mapped2)):
        check=0
        for item in t:
            if(item['PeerDB_id']==mapped2[i]['PDB_id']):
                check=1
                mapped2[i]['comment']=item['comment']
                mapped2[i]['date']=item['date']
            if(check==0):
                mapped2[i]['comment']=''
                mapped2[i]['date']=''
        if(mapped2[i]['IXP_Url_Stats']!='' or mapped2[i]['graph_url_PCH']!=''):
            writer.writerow([mapped2[i]['IXP_Country_ISO_Alpha2'],mapped2[i]['IXPDB_id'],mapped2[i]['PCH_id'],mapped2[i]['PDB_id'],mapped2[i]['IXP_name_IXPDB'],mapped2[i]['IXP_name_PCH'],mapped2[i]['IXP_name_PDB'],mapped2[i]['IXP_City'],mapped2[i]['IXP_region_continent'],mapped2[i]['Date_Creation_IXP_PDB'],mapped2[i]['Date_Creation_IXP_PCH'],mapped2[i]['Date_updated_PCH'],mapped2[i]['Date_update_IXPDB'],mapped2[i]['IXP_Website'],mapped2[i]['IXP_Url_Stats'],mapped2[i]['graph_url_PCH'],mapped2[i]['comment'],mapped2[i]['date']])

# %%
for i in mapped2:
    #print(mapped2[i]['IXP_Country_ISO_Alpha2'])
    i['IXPDB_id']
