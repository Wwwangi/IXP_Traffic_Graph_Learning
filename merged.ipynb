# %%
# %store -r DB1
# %store -r DB2
# %store -r length_of_DB1
# %store -r length_of_DB2

# %%
DB=[]
for i in range(len(DB2)):
    DB.append({'IXP_Country_ISO_Alpha2':DB2[i]['Country'],'IXPDB_ID':'','PCH_ID':'','PeeringDB_ID':DB2[i]['id'],'IXP_name':DB2[i]['IXP_id'],'IXP_City':DB2[i]['Location'],'IXP_region_continent':DB2[i]['region_continent'],'Date_Creation_IXP':DB2[i]['created'],'IXP_Website':DB2[i]['URL(website)'],'IXP_Url_Stats':DB2[i]['URL(Graph stats)'],'URL_stats_comments':'','Date_check_Stats':''})

# %%
det=0
for i in range(len(DB)):
    det=0
    for j in range(len(DB1)):
        if(DB1[j]['pdb_id']==DB[i]['PeeringDB_ID']):
            DB[i]['IXPDB_ID']=DB1[j]['id']
            det=1
    if(det==0):
        DB[i]['IXPDB_ID']='None'

# %%
DB_with_url_Stats=[]
for i in range(len(DB)):
    if(DB[i]['IXP_Url_Stats']!=''):
        DB_with_url_Stats.append(DB[i])

# %%
import csv
with open('D://third/python/IXP.csv','w',encoding='GB18030',newline='')as csvfile:
    writer=csv.writer(csvfile)
    writer.writerow(['IXP_Country_ISO_Alpha2','IXPDB_ID','PCH_ID','PeeringDB_ID','IXP_name','IXP_City','IXP_region_continent','Date_Creation_IXP','IXP_Website','IXP_Url_Stats','URL_stats_comments','Date_check_Stats'])
    for i in range(len(DB_with_url_Stats)):
        writer.writerow([DB_with_url_Stats[i]['IXP_Country_ISO_Alpha2'],DB_with_url_Stats[i]['IXPDB_ID'],DB_with_url_Stats[i]['PCH_ID'],DB_with_url_Stats[i]['PeeringDB_ID'],DB_with_url_Stats[i]['IXP_name'],DB_with_url_Stats[i]['IXP_City'],DB_with_url_Stats[i]['IXP_region_continent'],DB_with_url_Stats[i]['Date_Creation_IXP'],DB_with_url_Stats[i]['IXP_Website'],DB_with_url_Stats[i]['IXP_Url_Stats'],DB_with_url_Stats[i]['URL_stats_comments'],DB_with_url_Stats[i]['Date_check_Stats']])

# %%
DB_with_url_stats
# Out:
# [{'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 148,
#   'PCH_ID': '',
#   'PeeringDB_ID': 13,
#   'IXP_name': 'SIX Seattle',
#   'IXP_City': 'Seattle',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.seattleix.net/',
#   'IXP_Url_Stats': 'https://www.seattleix.net/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 138,
#   'PCH_ID': '',
#   'PeeringDB_ID': 14,
#   'IXP_name': 'NYIIX',
#   'IXP_City': 'New York',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.nyiix.net/locations/nyiix-new-york/',
#   'IXP_Url_Stats': 'https://www.nyiix.net/mrtg/sum.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GB',
#   'IXPDB_ID': 1,
#   'PCH_ID': '',
#   'PeeringDB_ID': 18,
#   'IXP_name': 'LINX LON1',
#   'IXP_City': 'London',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.linx.net/',
#   'IXP_Url_Stats': 'https://stats.linx.net/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'AU',
#   'IXPDB_ID': 108,
#   'PCH_ID': '',
#   'PeeringDB_ID': 21,
#   'IXP_name': 'IX Australia WA',
#   'IXP_City': 'Perth/WA',
#   'IXP_region_continent': 'Australia',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.ix.asn.au',
#   'IXP_Url_Stats': 'https://metrics.ix.asn.au',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 137,
#   'PCH_ID': '',
#   'PeeringDB_ID': 23,
#   'IXP_name': 'NYIIX Los Angeles',
#   'IXP_City': 'Los Angeles',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.nyiix.net/locations/nyiix-la/',
#   'IXP_Url_Stats': 'https://www.nyiix.net/LA-mrtg/sum.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CA',
#   'IXPDB_ID': 163,
#   'PCH_ID': '',
#   'PeeringDB_ID': 24,
#   'IXP_name': 'TorIX',
#   'IXP_City': 'Toronto',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.torix.ca/',
#   'IXP_Url_Stats': 'https://www.torix.ca/traffic-statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NL',
#   'IXPDB_ID': 2,
#   'PCH_ID': '',
#   'PeeringDB_ID': 26,
#   'IXP_name': 'AMS-IX',
#   'IXP_City': 'Amsterdam',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.ams-ix.net/',
#   'IXP_Url_Stats': 'https://www.ams-ix.net/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CH',
#   'IXPDB_ID': 22,
#   'PCH_ID': '',
#   'PeeringDB_ID': 29,
#   'IXP_name': 'Equinix Zurich',
#   'IXP_City': 'Zurich',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.equinix.ch/services/interconnection-connectivity/internet-exchange/',
#   'IXP_Url_Stats': 'https://ix.equinix.com/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'JP',
#   'IXPDB_ID': 44,
#   'PCH_ID': '',
#   'PeeringDB_ID': 30,
#   'IXP_name': 'JPIX TOKYO',
#   'IXP_City': 'Tokyo',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.jpix.ad.jp/en/',
#   'IXP_Url_Stats': 'https://www.jpix.ad.jp/en/technical_traffic.php',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 9,
#   'PCH_ID': '',
#   'PeeringDB_ID': 31,
#   'IXP_name': 'DE-CIX Frankfurt',
#   'IXP_City': 'Frankfurt',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://fra.de-cix.net',
#   'IXP_Url_Stats': 'https://www.de-cix.net/en/locations/germany/frankfurt/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CH',
#   'IXPDB_ID': 7,
#   'PCH_ID': '',
#   'PeeringDB_ID': 33,
#   'IXP_name': 'CIXP',
#   'IXP_City': 'Geneva',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.cixp.net/',
#   'IXP_Url_Stats': 'http://cixp.net/technical/members-traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IT',
#   'IXPDB_ID': 8,
#   'PCH_ID': '',
#   'PeeringDB_ID': 35,
#   'IXP_name': 'MIX-IT',
#   'IXP_City': 'Milan',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.mix-it.net/',
#   'IXP_Url_Stats': 'http://www.mix-it.net/statistics/cgi-bin/14all-Totale_globale.cgi?log=totaltraffic_global',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FR',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 40,
#   'IXP_name': 'PARIX',
#   'IXP_City': 'Paris',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.parix.net/',
#   'IXP_Url_Stats': 'http://www.parix.net/cgi-bin/mrtg-rrd.cgi/giga.parix.net_total.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 41,
#   'IXP_name': 'NYCX',
#   'IXP_City': 'New York',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.nycx.net/',
#   'IXP_Url_Stats': 'http://www.nycx.net/index.php?page=Traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'HK',
#   'IXPDB_ID': 110,
#   'PCH_ID': '',
#   'PeeringDB_ID': 42,
#   'IXP_name': 'HKIX',
#   'IXP_City': 'Hong Kong',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.hkix.net/',
#   'IXP_Url_Stats': 'https://www.hkix.net/hkix/stat/aggt/hkix-aggregate.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TW',
#   'IXPDB_ID': 113,
#   'PCH_ID': '',
#   'PeeringDB_ID': 43,
#   'IXP_name': 'TWIX',
#   'IXP_City': 'Taipei',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.twix.net',
#   'IXP_Url_Stats': 'http://www.twix.net/all_e.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IE',
#   'IXPDB_ID': 20,
#   'PCH_ID': '',
#   'PeeringDB_ID': 48,
#   'IXP_name': 'INEX LAN1',
#   'IXP_City': 'Dublin',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.inex.ie/',
#   'IXP_Url_Stats': 'https://www.inex.ie/ixp/statistics/ixp',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'AT',
#   'IXPDB_ID': 3,
#   'PCH_ID': '',
#   'PeeringDB_ID': 50,
#   'IXP_name': 'VIX',
#   'IXP_City': 'Vienna',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.vix.at',
#   'IXP_Url_Stats': 'https://www.vix.at/vix_statistics.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GB',
#   'IXPDB_ID': 18,
#   'PCH_ID': '',
#   'PeeringDB_ID': 53,
#   'IXP_name': 'LONAP',
#   'IXP_City': 'London',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.lonap.net/',
#   'IXP_Url_Stats': 'https://www.lonap.net/bandwidth.shtml',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'HU',
#   'IXPDB_ID': 55,
#   'PCH_ID': '',
#   'PeeringDB_ID': 55,
#   'IXP_name': 'BiX',
#   'IXP_City': 'Budapest',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://bix.hu/en',
#   'IXP_Url_Stats': 'http://bix.hu/en/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BE',
#   'IXPDB_ID': 4,
#   'PCH_ID': '',
#   'PeeringDB_ID': 59,
#   'IXP_name': 'BNIX',
#   'IXP_City': 'Brussels',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.bnix.net',
#   'IXP_Url_Stats': 'https://bnix.net/en/content/figures',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CH',
#   'IXPDB_ID': 34,
#   'PCH_ID': '',
#   'PeeringDB_ID': 60,
#   'IXP_name': 'SwissIX',
#   'IXP_City': 'Zurich',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.swissix.ch/',
#   'IXP_Url_Stats': 'https://www.swissix.net/infrastructure/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'ES',
#   'IXPDB_ID': 11,
#   'PCH_ID': '',
#   'PeeringDB_ID': 62,
#   'IXP_name': 'CATNIX',
#   'IXP_City': 'Barcelona',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.catnix.net',
#   'IXP_Url_Stats': 'http://www.catnix.net/en/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'ES',
#   'IXPDB_ID': 62,
#   'PCH_ID': '',
#   'PeeringDB_ID': 63,
#   'IXP_name': 'ESPANIX Madrid Lower LAN',
#   'IXP_City': 'Madrid',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.espanix.net',
#   'IXP_Url_Stats': 'http://stats.espanix.net/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NL',
#   'IXPDB_ID': 27,
#   'PCH_ID': '',
#   'PeeringDB_ID': 64,
#   'IXP_name': 'NL-ix',
#   'IXP_City': 'Amsterdam',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.nl-ix.net/',
#   'IXP_Url_Stats': 'https://www.nl-ix.net/traffic.php',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FR',
#   'IXPDB_ID': 31,
#   'PCH_ID': '',
#   'PeeringDB_ID': 69,
#   'IXP_name': 'LyonIX',
#   'IXP_City': 'Lyon',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.lyonix.net/',
#   'IXP_Url_Stats': 'http://noc.rezopole.net/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 5,
#   'PCH_ID': '',
#   'PeeringDB_ID': 70,
#   'IXP_name': 'Netnod Stockholm',
#   'IXP_City': 'Stockholm',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.netnod.se',
#   'IXP_Url_Stats': 'http://www.netnod.se/ix/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CZ',
#   'IXPDB_ID': 15,
#   'PCH_ID': '',
#   'PeeringDB_ID': 71,
#   'IXP_name': 'NIX.CZ',
#   'IXP_City': 'Prague',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.nix.cz/',
#   'IXP_Url_Stats': 'https://www.nix.cz/en/port/mrtg2/nix-all',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PT',
#   'IXPDB_ID': 10,
#   'PCH_ID': '',
#   'PeeringDB_ID': 72,
#   'IXP_name': 'GigaPIX',
#   'IXP_City': 'Lisbon',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.gigapix.pt',
#   'IXP_Url_Stats': 'https://gigapix.pt/pt/informacao-tecnica/estatisticas-de-trafego/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 77,
#   'PCH_ID': '',
#   'PeeringDB_ID': 73,
#   'IXP_name': 'ECIX-MUC / INXS by ecix',
#   'IXP_City': 'Munich',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.ecix.net',
#   'IXP_Url_Stats': 'https://www.ecix.net/infrastructure/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 47,
#   'PCH_ID': '',
#   'PeeringDB_ID': 74,
#   'IXP_name': 'DE-CIX Hamburg',
#   'IXP_City': 'Hamburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://ham.de-cix.net',
#   'IXP_Url_Stats': 'https://www.de-cix.net/locations/germany/hamburg/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DK',
#   'IXPDB_ID': 29,
#   'PCH_ID': '',
#   'PeeringDB_ID': 78,
#   'IXP_name': 'DIX',
#   'IXP_City': 'Copenhagen',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.dix.dk/',
#   'IXP_Url_Stats': 'http://www.dix.dk/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NO',
#   'IXPDB_ID': 19,
#   'PCH_ID': '',
#   'PeeringDB_ID': 83,
#   'IXP_name': 'NIX1',
#   'IXP_City': 'Oslo',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.nix.no',
#   'IXP_Url_Stats': 'https://www.nix.no/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SK',
#   'IXPDB_ID': 89,
#   'PCH_ID': '',
#   'PeeringDB_ID': 84,
#   'IXP_name': 'SIX.SK',
#   'IXP_City': 'Bratislava',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.six.sk',
#   'IXP_Url_Stats': 'http://www.six.sk/stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 21,
#   'PCH_ID': '',
#   'PeeringDB_ID': 87,
#   'IXP_name': 'BCIX',
#   'IXP_City': 'Berlin',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.bcix.de/',
#   'IXP_Url_Stats': 'https://www.bcix.de/bcix/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 267,
#   'PCH_ID': '',
#   'PeeringDB_ID': 89,
#   'IXP_name': 'MadIX',
#   'IXP_City': 'Madison',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://kb.wisc.edu/ns/page.php?id=6636',
#   'IXP_Url_Stats': 'http://stats.net.wisc.edu/madix.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 340,
#   'PCH_ID': '',
#   'PeeringDB_ID': 91,
#   'IXP_name': 'ECIX-DUS',
#   'IXP_City': 'Duesseldorf',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.ecix.net/',
#   'IXP_Url_Stats': 'https://www.ecix.net/infrastructure/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'JP',
#   'IXPDB_ID': 441,
#   'PCH_ID': '',
#   'PeeringDB_ID': 92,
#   'IXP_name': 'DIX-IE',
#   'IXP_City': 'Tokyo',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://nspixp.wide.ad.jp/',
#   'IXP_Url_Stats': 'http://nspixp.wide.ad.jp/2/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'JP',
#   'IXPDB_ID': 42,
#   'PCH_ID': '',
#   'PeeringDB_ID': 95,
#   'IXP_name': 'JPNAP Tokyo',
#   'IXP_City': 'Tokyo',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.jpnap.net/en/',
#   'IXP_Url_Stats': 'https://www.jpnap.net/en/tokyo/traffic.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 85,
#   'PCH_ID': '',
#   'PeeringDB_ID': 96,
#   'IXP_name': 'WIX',
#   'IXP_City': 'Warsaw',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.wix.net.pl/',
#   'IXP_Url_Stats': 'http://www.wix.net.pl/vxb/w/index.asp?statystyki_x=statystyki',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FI',
#   'IXPDB_ID': 23,
#   'PCH_ID': '',
#   'PeeringDB_ID': 98,
#   'IXP_name': 'FICIX 2 (Helsinki)',
#   'IXP_City': 'Helsinki',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.ficix.fi/',
#   'IXP_Url_Stats': 'https://stats-ficix.basen.com/#/page?name=StatsWelcome&source=wiki',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 13,
#   'PCH_ID': '',
#   'PeeringDB_ID': 100,
#   'IXP_name': 'MSK-IX Moscow',
#   'IXP_City': 'Moscow',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 87,
#   'PCH_ID': '',
#   'PeeringDB_ID': 107,
#   'IXP_name': 'MSK-IX Saint-Petersburg',
#   'IXP_City': 'St.Petersburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/spb',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IT',
#   'IXPDB_ID': 14,
#   'PCH_ID': '',
#   'PeeringDB_ID': 115,
#   'IXP_name': 'TOP-IX',
#   'IXP_City': 'Turin',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.top-ix.org',
#   'IXP_Url_Stats': 'http://www.top-ix.org/traffic-summary',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 215,
#   'PCH_ID': '',
#   'PeeringDB_ID': 119,
#   'IXP_name': 'Equinix São Paulo',
#   'IXP_City': 'São Paulo',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.equinix.com',
#   'IXP_Url_Stats': 'https://ix.equinix.com',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IT',
#   'IXPDB_ID': 17,
#   'PCH_ID': '',
#   'PeeringDB_ID': 121,
#   'IXP_name': 'NaMeX Rome IXP',
#   'IXP_City': 'Rome',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.namex.it',
#   'IXP_Url_Stats': 'https://www.namex.it/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 78,
#   'PCH_ID': '',
#   'PeeringDB_ID': 123,
#   'IXP_name': 'KleyReX',
#   'IXP_City': 'Frankfurt',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.kleyrex.net/',
#   'IXP_Url_Stats': 'http://www.kleyrex.net/stats.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 256,
#   'PCH_ID': '',
#   'PeeringDB_ID': 127,
#   'IXP_name': 'Oregon Internet Exchange (OIX)',
#   'IXP_City': 'Eugene, Oregon',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.oregon-ix.net/',
#   'IXP_Url_Stats': 'http://www.oregon-ix.net/stat-frme.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'JP',
#   'IXPDB_ID': 120,
#   'PCH_ID': '',
#   'PeeringDB_ID': 145,
#   'IXP_name': 'JPNAP Osaka',
#   'IXP_City': 'Osaka',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.jpnap.net/en/',
#   'IXP_Url_Stats': 'https://www.jpnap.net/en/osaka/traffic.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 791,
#   'PCH_ID': '',
#   'PeeringDB_ID': 171,
#   'IXP_name': 'IX.br (PTT.br) São Paulo',
#   'IXP_City': 'São Paulo/SP',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/sp',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 144,
#   'PCH_ID': '',
#   'PeeringDB_ID': 172,
#   'IXP_name': 'STHIX - Stockholm',
#   'IXP_City': 'Stockholm',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.sthix.net/',
#   'IXP_Url_Stats': 'http://www.sthix.net/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 158,
#   'PCH_ID': '',
#   'PeeringDB_ID': 173,
#   'IXP_name': 'IX.br (PTT.br) Porto Alegre',
#   'IXP_City': 'Porto Alegre/RS',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/rs',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 156,
#   'PCH_ID': '',
#   'PeeringDB_ID': 174,
#   'IXP_name': 'IX.br (PTT.br) Curitiba',
#   'IXP_City': 'Curitiba/PR',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/pr',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 157,
#   'PCH_ID': '',
#   'PeeringDB_ID': 175,
#   'IXP_name': 'IX.br (PTT.br) Florianópolis',
#   'IXP_City': 'Florianópolis/SC',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/sc',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 154,
#   'PCH_ID': '',
#   'PeeringDB_ID': 176,
#   'IXP_name': 'IX.br (PTT.br) Belo Horizonte',
#   'IXP_City': 'Belo Horizonte/MG',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/mg',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 159,
#   'PCH_ID': '',
#   'PeeringDB_ID': 177,
#   'IXP_name': 'IX.br (PTT.br) Rio de Janeiro',
#   'IXP_City': 'Rio de Janeiro/RJ',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br/',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/rj',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 155,
#   'PCH_ID': '',
#   'PeeringDB_ID': 178,
#   'IXP_name': 'IX.br (PTT.br) Brasília',
#   'IXP_City': 'Brasília/DF',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/df',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'UA',
#   'IXPDB_ID': 48,
#   'PCH_ID': '',
#   'PeeringDB_ID': 184,
#   'IXP_name': 'UA-IX',
#   'IXP_City': 'Kiev',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.ua-ix.net.ua/en',
#   'IXP_Url_Stats': 'http://www.ix.net.ua/pro-kompaniyu/statystyka',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 100,
#   'PCH_ID': '',
#   'PeeringDB_ID': 192,
#   'IXP_name': 'Netnod Gothenburg',
#   'IXP_City': 'Gothenburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.netnod.se',
#   'IXP_Url_Stats': 'http://www.netnod.se/ix/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DK',
#   'IXPDB_ID': 294,
#   'PCH_ID': '',
#   'PeeringDB_ID': 193,
#   'IXP_name': 'Netnod Copenhagen',
#   'IXP_City': 'Malmo / Copenhagen',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.netnod.se',
#   'IXP_Url_Stats': 'http://www.netnod.se/ix/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 102,
#   'PCH_ID': '',
#   'PeeringDB_ID': 194,
#   'IXP_name': 'Netnod Sundsvall',
#   'IXP_City': 'Sundsvall',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.netnod.se',
#   'IXP_Url_Stats': 'http://www.netnod.se/ix/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 30,
#   'PCH_ID': '',
#   'PeeringDB_ID': 209,
#   'IXP_name': 'ECIX-BER',
#   'IXP_City': 'Berlin',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.ecix.net/',
#   'IXP_Url_Stats': 'https://www.ecix.net/infrastructure/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'ID',
#   'IXPDB_ID': 111,
#   'PCH_ID': '',
#   'PeeringDB_ID': 210,
#   'IXP_name': 'IIX-Jakarta',
#   'IXP_City': 'Jakarta',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.iix.net.id',
#   'IXP_Url_Stats': 'http://mrtg.iix.net.id',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 86,
#   'PCH_ID': '',
#   'PeeringDB_ID': 223,
#   'IXP_name': 'MSK-IX Novosibirsk',
#   'IXP_City': 'Novosibirsk',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/nsk',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IS',
#   'IXPDB_ID': 33,
#   'PCH_ID': '',
#   'PeeringDB_ID': 228,
#   'IXP_name': 'RIX',
#   'IXP_City': 'Reykjavik',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.rix.is/',
#   'IXP_Url_Stats': 'https://www.rix.is/english/statistics.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 151,
#   'PCH_ID': '',
#   'PeeringDB_ID': 230,
#   'IXP_name': 'POZIX',
#   'IXP_City': 'Poznan',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.pozix.pl/',
#   'IXP_Url_Stats': 'https://www.pozix.pl/#statystyki',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 106,
#   'PCH_ID': '',
#   'PeeringDB_ID': 231,
#   'IXP_name': 'MalmIX Malmo / IXOR',
#   'IXP_City': 'Malmö',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.ixor.se',
#   'IXP_Url_Stats': 'http://www.ixor.se/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 149,
#   'PCH_ID': '',
#   'PeeringDB_ID': 239,
#   'IXP_name': 'ChIX',
#   'IXP_City': 'Chicago',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://unitedix.net/location/chicago',
#   'IXP_Url_Stats': 'https://unitedix.net/location/chicago/networks',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NP',
#   'IXPDB_ID': 53,
#   'PCH_ID': '',
#   'PeeringDB_ID': 241,
#   'IXP_name': 'npIX PTS',
#   'IXP_City': 'Kathmandu',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.npix.net.np/',
#   'IXP_Url_Stats': 'http://www.npix.net.np/graph',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 54,
#   'PCH_ID': '',
#   'PeeringDB_ID': 248,
#   'IXP_name': 'DE-CIX Munich',
#   'IXP_City': 'Munich',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://muc.de-cix.net',
#   'IXP_Url_Stats': 'https://www.de-cix.net/locations/germany/munich/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CO',
#   'IXPDB_ID': 69,
#   'PCH_ID': '',
#   'PeeringDB_ID': 252,
#   'IXP_name': 'NAP Colombia',
#   'IXP_City': 'Bogota',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-12-11T00:00:00Z',
#   'IXP_Website': 'http://nap.co',
#   'IXP_Url_Stats': 'http://nap.co/html/estadisticas.php',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FR',
#   'IXPDB_ID': 39,
#   'PCH_ID': '',
#   'PeeringDB_ID': 255,
#   'IXP_name': 'Equinix Paris',
#   'IXP_City': 'Paris',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.equinix-ix.fr/',
#   'IXP_Url_Stats': 'https://ix.equinix.com/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SE',
#   'IXPDB_ID': 145,
#   'PCH_ID': '',
#   'PeeringDB_ID': 257,
#   'IXP_name': 'Netnod Lulea',
#   'IXP_City': 'Lulea',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.netnod.se',
#   'IXP_Url_Stats': 'http://www.netnod.se/ix/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 36,
#   'PCH_ID': '',
#   'PeeringDB_ID': 264,
#   'IXP_name': 'Equinix Warsaw (PLIX)',
#   'IXP_City': 'Warsaw',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.plix.pl/',
#   'IXP_Url_Stats': 'http://www.plix.pl/en/network/statistic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RO',
#   'IXPDB_ID': 37,
#   'PCH_ID': '',
#   'PeeringDB_ID': 270,
#   'IXP_name': 'InterLAN',
#   'IXP_City': 'Bucharest, Arad, Cluj-Napoca, Constanta, Craiova, Iasi, Suceava, Timisoara',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.interlan.ro/en/',
#   'IXP_Url_Stats': 'https://ixpm.interlan.ro/statistics/ixp',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'EG',
#   'IXPDB_ID': 206,
#   'PCH_ID': '',
#   'PeeringDB_ID': 274,
#   'IXP_name': 'CAIX',
#   'IXP_City': 'Cairo',
#   'IXP_region_continent': 'Middle East',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.caix.net.eg/',
#   'IXP_Url_Stats': 'http://www.caix.net.eg/index.php/technical-info/traffic-statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'DE',
#   'IXPDB_ID': 341,
#   'PCH_ID': '',
#   'PeeringDB_ID': 291,
#   'IXP_name': 'ECIX-HAM',
#   'IXP_City': 'Hamburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.ecix.net/',
#   'IXP_Url_Stats': 'https://www.ecix.net/infrastructure/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NO',
#   'IXPDB_ID': 99,
#   'PCH_ID': '',
#   'PeeringDB_ID': 298,
#   'IXP_name': 'NIX2',
#   'IXP_City': 'Oslo',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.nix.no/',
#   'IXP_Url_Stats': 'https://www.nix.no/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RO',
#   'IXPDB_ID': 16,
#   'PCH_ID': '',
#   'PeeringDB_ID': 301,
#   'IXP_name': 'RoNIX',
#   'IXP_City': 'Bucharest',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://anisp.ro/',
#   'IXP_Url_Stats': 'https://ronix.ro/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'HR',
#   'IXPDB_ID': 28,
#   'PCH_ID': '',
#   'PeeringDB_ID': 303,
#   'IXP_name': 'CIX',
#   'IXP_City': 'Zagreb',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.cix.hr/',
#   'IXP_Url_Stats': 'http://www.cix.hr/en/about-cix/traffic-statistics/traffic-summary',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IT',
#   'IXPDB_ID': 38,
#   'PCH_ID': '',
#   'PeeringDB_ID': 311,
#   'IXP_name': 'VSIX',
#   'IXP_City': 'Padova',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.vsix.it/',
#   'IXP_Url_Stats': 'https://www.vsix.it/en/support/statistics.htm',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NL',
#   'IXPDB_ID': 146,
#   'PCH_ID': '',
#   'PeeringDB_ID': 313,
#   'IXP_name': 'R_iX',
#   'IXP_City': 'Rotterdam',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.r-ix.nl',
#   'IXP_Url_Stats': 'https://www.r-ix.nl/#Traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 214,
#   'PCH_ID': '',
#   'PeeringDB_ID': 314,
#   'IXP_name': 'IX.br (PTT.br) Londrina',
#   'IXP_City': 'Londrina/PR',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/lda',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SI',
#   'IXPDB_ID': 25,
#   'PCH_ID': '',
#   'PeeringDB_ID': 319,
#   'IXP_name': 'SIX SI',
#   'IXP_City': 'Ljubljana',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.arnes.si/infrastructure/six-slovenian-internet-exchange/',
#   'IXP_Url_Stats': 'https://www.arnes.si/infrastructure/six-slovenian-internet-exchange/six-traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GB',
#   'IXPDB_ID': 600,
#   'PCH_ID': '',
#   'PeeringDB_ID': 321,
#   'IXP_name': 'LINX LON2',
#   'IXP_City': 'London',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.linx.net/',
#   'IXP_Url_Stats': 'https://stats.linx.net/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BG',
#   'IXPDB_ID': 197,
#   'PCH_ID': '',
#   'PeeringDB_ID': 326,
#   'IXP_name': 'B-IX',
#   'IXP_City': 'Sofia',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.b-ix.net/',
#   'IXP_Url_Stats': 'http://www.b-ix.net/technical/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'UA',
#   'IXPDB_ID': 198,
#   'PCH_ID': '',
#   'PeeringDB_ID': 327,
#   'IXP_name': 'DTEL-IX',
#   'IXP_City': 'Kiev',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://dtel-ix.net/en/',
#   'IXP_Url_Stats': 'https://dtel-ix.net/en/st',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FI',
#   'IXPDB_ID': 46,
#   'PCH_ID': '',
#   'PeeringDB_ID': 328,
#   'IXP_name': 'TREX',
#   'IXP_City': 'Tampere',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.trex.fi/',
#   'IXP_Url_Stats': 'https://stats-trex.basen.com/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BG',
#   'IXPDB_ID': 40,
#   'PCH_ID': '',
#   'PeeringDB_ID': 331,
#   'IXP_name': 'BIX.BG',
#   'IXP_City': 'Sofia',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.bix.bg/',
#   'IXP_Url_Stats': 'http://www.bix.bg/en/technical_information/traffic_statistics.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GR',
#   'IXPDB_ID': 752,
#   'PCH_ID': '',
#   'PeeringDB_ID': 347,
#   'IXP_name': 'GR-IX::Athens',
#   'IXP_City': 'Athens',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.gr-ix.gr/',
#   'IXP_Url_Stats': 'http://www.gr-ix.gr/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 169,
#   'PCH_ID': '',
#   'PeeringDB_ID': 350,
#   'IXP_name': 'MSK-IX Ekaterinburg',
#   'IXP_City': 'Ekaterinburg',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/ekt',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CA',
#   'IXPDB_ID': 266,
#   'PCH_ID': '',
#   'PeeringDB_ID': 355,
#   'IXP_name': 'QIX',
#   'IXP_City': 'Montreal',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.qix.ca/?lang=en',
#   'IXP_Url_Stats': 'https://www.qix.ca/network?lang=en',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 523,
#   'PCH_ID': '',
#   'PeeringDB_ID': 358,
#   'IXP_name': 'DATAIX',
#   'IXP_City': 'Frankfurt, Stockholm, Helsinki, Amsterdam, St.Petersburg, Moscow, Ekaterinburg, Ufa, Novosibirsk, Omsk, Khabarovsk,Kiev, Kharkov, Odessa',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.dataix.ru',
#   'IXP_Url_Stats': 'http://graphs.dataix.ru/total.png',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FR',
#   'IXPDB_ID': 41,
#   'PCH_ID': '',
#   'PeeringDB_ID': 359,
#   'IXP_name': 'France-IX Paris',
#   'IXP_City': 'Paris',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.franceix.net',
#   'IXP_Url_Stats': 'https://tools.franceix.net/pops',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CW',
#   'IXPDB_ID': 61,
#   'PCH_ID': '',
#   'PeeringDB_ID': 366,
#   'IXP_name': 'AMS-IX Caribbean',
#   'IXP_City': 'Curacao',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2013-05-12T00:00:00Z',
#   'IXP_Website': 'http://www.ams-ix.cw/',
#   'IXP_Url_Stats': 'https://cw.ams-ix.net/technical--2/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RO',
#   'IXPDB_ID': 291,
#   'PCH_ID': '',
#   'PeeringDB_ID': 372,
#   'IXP_name': 'Balcan-IX',
#   'IXP_City': 'Bucharest',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.balcan-ix.net',
#   'IXP_Url_Stats': 'http://balcan-ix.net/new/en/traffic-statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 170,
#   'PCH_ID': '',
#   'PeeringDB_ID': 378,
#   'IXP_name': 'MSK-IX Vladivostok',
#   'IXP_City': 'Vladivostok',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/vlv',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 88,
#   'PCH_ID': '',
#   'PeeringDB_ID': 379,
#   'IXP_name': 'MSK-IX Samara',
#   'IXP_City': 'Samara',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/smr',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 178,
#   'PCH_ID': '',
#   'PeeringDB_ID': 380,
#   'IXP_name': 'MSK-IX Rostov-on-Don',
#   'IXP_City': 'Rostov-on-Don',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/rnd',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'LV',
#   'IXPDB_ID': 83,
#   'PCH_ID': '',
#   'PeeringDB_ID': 383,
#   'IXP_name': 'LIX-LV',
#   'IXP_City': 'Riga',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.lix.lv',
#   'IXP_Url_Stats': 'http://www.lix.lv/site/load',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IE',
#   'IXPDB_ID': 645,
#   'PCH_ID': '',
#   'PeeringDB_ID': 387,
#   'IXP_name': 'INEX LAN2',
#   'IXP_City': 'Dublin',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'https://www.inex.ie/',
#   'IXP_Url_Stats': 'https://www.inex.ie/ixp/statistics/ixp',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 275,
#   'PCH_ID': '',
#   'PeeringDB_ID': 398,
#   'IXP_name': 'MSK-IX Kazan',
#   'IXP_City': 'Kazan',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-07-29T00:00:00Z',
#   'IXP_Website': 'http://www.msk-ix.ru/en/ix/kzn',
#   'IXP_Url_Stats': 'http://www.msk-ix.ru/en/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 262,
#   'PCH_ID': '',
#   'PeeringDB_ID': 415,
#   'IXP_name': 'IX.br (PTT.br) Campinas',
#   'IXP_City': 'Campinas/SP',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2010-07-31T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/cas',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'UG',
#   'IXPDB_ID': 96,
#   'PCH_ID': '',
#   'PeeringDB_ID': 422,
#   'IXP_name': 'UIXP',
#   'IXP_City': 'Kampala',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2010-08-18T00:00:00Z',
#   'IXP_Website': 'https://uixp.co.ug/',
#   'IXP_Url_Stats': 'https://portal.uixp.co.ug/public-statistics/public',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SG',
#   'IXPDB_ID': 371,
#   'PCH_ID': '',
#   'PeeringDB_ID': 429,
#   'IXP_name': 'SGIX',
#   'IXP_City': 'Singapore',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-09-10T00:00:00Z',
#   'IXP_Website': 'https://www.sgix.sg',
#   'IXP_Url_Stats': 'https://www.sgix.sg/traffic-statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'AT',
#   'IXPDB_ID': 348,
#   'PCH_ID': '',
#   'PeeringDB_ID': 430,
#   'IXP_name': 'GraX',
#   'IXP_City': 'Graz',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-09-14T00:00:00Z',
#   'IXP_Website': 'http://www.grax.at/',
#   'IXP_Url_Stats': 'http://www.grax.at/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GB',
#   'IXPDB_ID': 281,
#   'PCH_ID': '',
#   'PeeringDB_ID': 435,
#   'IXP_name': 'IX Leeds',
#   'IXP_City': 'Leeds / Western Yorkshire',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2010-09-21T00:00:00Z',
#   'IXP_Website': 'http://ixleeds.net',
#   'IXP_Url_Stats': 'http://ixleeds.net/graphs.php',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 335,
#   'PCH_ID': '',
#   'PeeringDB_ID': 446,
#   'IXP_name': 'MICE',
#   'IXP_City': 'Minneapolis, MN',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2010-10-09T00:00:00Z',
#   'IXP_Website': 'http://www.micemn.net',
#   'IXP_Url_Stats': 'http://micelg.usinternet.com/export/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GU',
#   'IXPDB_ID': 472,
#   'PCH_ID': '',
#   'PeeringDB_ID': 463,
#   'IXP_name': 'GU-IX',
#   'IXP_City': 'Guam',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2010-12-09T00:00:00Z',
#   'IXP_Website': 'http://www.gu-ix.net',
#   'IXP_Url_Stats': 'http://www.gu-ix.net/stats/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 436,
#   'PCH_ID': '',
#   'PeeringDB_ID': 474,
#   'IXP_name': 'EPIX.Warszawa-KIX',
#   'IXP_City': 'Warsaw',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-01-15T00:00:00Z',
#   'IXP_Website': 'http://www.epix.net.pl/',
#   'IXP_Url_Stats': 'http://www.epix.net.pl/narzedzia/statystyki-epix/#epix-katowice-stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 346,
#   'PCH_ID': '',
#   'PeeringDB_ID': 481,
#   'IXP_name': 'Thinx',
#   'IXP_City': 'Warsaw',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-02-06T00:00:00Z',
#   'IXP_Website': 'http://www.atman.pl',
#   'IXP_Url_Stats': 'https://portal.atman.pl/stats/acx.jsf',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 401,
#   'PCH_ID': '',
#   'PeeringDB_ID': 482,
#   'IXP_name': 'TPIX',
#   'IXP_City': 'Warsaw',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-02-06T00:00:00Z',
#   'IXP_Website': 'http://www.tpix.pl/en',
#   'IXP_Url_Stats': 'http://www.tpix.pl/en/statystyki_en.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NG',
#   'IXPDB_ID': 60,
#   'PCH_ID': '',
#   'PeeringDB_ID': 488,
#   'IXP_name': 'IXPN Lagos',
#   'IXP_City': 'Lagos',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2011-03-03T00:00:00Z',
#   'IXP_Website': 'http://www.ixp.net.ng',
#   'IXP_Url_Stats': 'http://rt1.ixp.net.ng/mrtg/totalixpnlagos.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PL',
#   'IXPDB_ID': 548,
#   'PCH_ID': '',
#   'PeeringDB_ID': 491,
#   'IXP_name': 'EPIX.Katowice',
#   'IXP_City': 'Katowice/Silesia',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-03-25T00:00:00Z',
#   'IXP_Website': 'http://www.epix.net.pl/',
#   'IXP_Url_Stats': 'http://www.epix.net.pl/narzedzia/statystyki-epix/#epix-katowice-stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'FI',
#   'IXPDB_ID': 172,
#   'PCH_ID': '',
#   'PeeringDB_ID': 492,
#   'IXP_name': 'FICIX 3 (Oulu)',
#   'IXP_City': 'Oulu',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-03-19T00:00:00Z',
#   'IXP_Website': 'http://www.ficix.fi/',
#   'IXP_Url_Stats': 'http://stats.ficix.fi/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 418,
#   'PCH_ID': '',
#   'PeeringDB_ID': 499,
#   'IXP_name': 'MKE-IX',
#   'IXP_City': 'Milwaukee',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2011-06-02T00:00:00Z',
#   'IXP_Website': 'http://www.mkeix.net',
#   'IXP_Url_Stats': 'http://www.mkeix.net/stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 293,
#   'PCH_ID': '',
#   'PeeringDB_ID': 512,
#   'IXP_name': 'PIRIX',
#   'IXP_City': 'St.Petersburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-05-12T00:00:00Z',
#   'IXP_Website': 'http://www.pirix.ru',
#   'IXP_Url_Stats': 'http://pirix.ru/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'AU',
#   'IXPDB_ID': 393,
#   'PCH_ID': '',
#   'PeeringDB_ID': 513,
#   'IXP_name': 'IX Australia VIC',
#   'IXP_City': 'Melbourne/Victoria',
#   'IXP_region_continent': 'Australia',
#   'Date_Creation_IXP': '2011-05-12T00:00:00Z',
#   'IXP_Website': 'http://www.waia.asn.au',
#   'IXP_Url_Stats': 'https://metrics.ix.asn.au',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'LT',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 526,
#   'IXP_name': 'LIXP',
#   'IXP_City': 'Vilnius',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-08-05T00:00:00Z',
#   'IXP_Website': 'http://www.lixp.lt/en/',
#   'IXP_Url_Stats': 'http://www.lixp.lt/en/network/stat',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'MZ',
#   'IXPDB_ID': 338,
#   'PCH_ID': '',
#   'PeeringDB_ID': 528,
#   'IXP_name': 'MOZIX',
#   'IXP_City': 'Maputo',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2011-08-09T00:00:00Z',
#   'IXP_Website': 'http://www.mozix.org.mz',
#   'IXP_Url_Stats': 'http://www.mozix.org.mz/mrtg',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'LI',
#   'IXPDB_ID': 483,
#   'PCH_ID': '',
#   'PeeringDB_ID': 543,
#   'IXP_name': 'Rheintal IX',
#   'IXP_City': 'Eschen/LI, Feldkirch/AT, St. Gallen/CH',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2011-12-06T00:00:00Z',
#   'IXP_Website': 'http://www.rheintal-ix.net',
#   'IXP_Url_Stats': 'http://www.rheintal-ix.net/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 160,
#   'PCH_ID': '',
#   'PeeringDB_ID': 556,
#   'IXP_name': 'IX.br (PTT.br) Salvador',
#   'IXP_City': 'Salvador/BA',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2012-01-16T00:00:00Z',
#   'IXP_Website': 'http://ix.br',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/ba',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 376,
#   'PCH_ID': '',
#   'PeeringDB_ID': 558,
#   'IXP_name': 'IX.br (PTT.br) Caxias do Sul',
#   'IXP_City': 'Caxias do Sul/RS',
# ...
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GU',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2116,
#   'IXP_name': 'GOREX',
#   'IXP_City': 'Tumon',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-03-09T05:13:54Z',
#   'IXP_Website': 'https://gorex.uog.edu',
#   'IXP_Url_Stats': 'http://perfsonar.uog.edu',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'ES',
#   'IXPDB_ID': 783,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2130,
#   'IXP_name': 'Equinix Madrid',
#   'IXP_City': 'Madrid',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-03-22T13:45:50Z',
#   'IXP_Website': 'https://ix.equinix.com/home/madrid/',
#   'IXP_Url_Stats': 'https://ix.equinix.com/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PT',
#   'IXPDB_ID': 782,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2131,
#   'IXP_name': 'Equinix Lisbon',
#   'IXP_City': 'Lisbon',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-03-22T13:46:38Z',
#   'IXP_Website': 'https://ix.equinix.com/home/lisbon/',
#   'IXP_Url_Stats': 'https://ix.equinix.com/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': 761,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2149,
#   'IXP_name': 'PITER-IX',
#   'IXP_City': 'St.Petersburg',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-04-02T20:32:10Z',
#   'IXP_Website': 'http://piter-ix.ru',
#   'IXP_Url_Stats': 'http://lg.piter-ix.ru',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CL',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2176,
#   'IXP_name': 'PIT entel',
#   'IXP_City': 'Santiago',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2018-04-30T19:20:42Z',
#   'IXP_Website': 'http://www.pitentel.cl',
#   'IXP_Url_Stats': 'http://www.pitentel.cl',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 780,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2182,
#   'IXP_name': 'Equinix Denver',
#   'IXP_City': 'Denver',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-05-07T21:23:04Z',
#   'IXP_Website': 'https://www.equinix.com',
#   'IXP_Url_Stats': 'https://ix.equinix.com',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 781,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2183,
#   'IXP_name': 'Equinix Houston',
#   'IXP_City': 'Houston',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-05-07T21:23:57Z',
#   'IXP_Website': 'https://www.equinix.com',
#   'IXP_Url_Stats': 'https://ix.equinix.com',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 766,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2186,
#   'IXP_name': 'Baltimore IX',
#   'IXP_City': 'Baltimore',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-05-13T21:54:50Z',
#   'IXP_Website': 'https://baltimoreix.net',
#   'IXP_Url_Stats': 'https://baltimoreix.net/stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'AF',
#   'IXPDB_ID': 749,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2245,
#   'IXP_name': 'NIXA',
#   'IXP_City': 'Kabul',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-06-26T00:34:19Z',
#   'IXP_Website': 'http://www.nixa.af',
#   'IXP_Url_Stats': 'http://www.nixa.af',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'KZ',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2250,
#   'IXP_name': 'KAZ-GOV-IX',
#   'IXP_City': 'Astana',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-06-29T06:54:22Z',
#   'IXP_Website': 'http://sts.kz/',
#   'IXP_Url_Stats': 'http://lg-ix.sts.kz/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TT',
#   'IXPDB_ID': 799,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2272,
#   'IXP_name': 'TTIX2',
#   'IXP_City': 'Princes Town',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2018-07-18T20:58:43Z',
#   'IXP_Website': 'https://ix.tt',
#   'IXP_Url_Stats': 'https://ix.tt/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 756,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2274,
#   'IXP_name': 'EVIX',
#   'IXP_City': 'Fremont',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-07-19T16:24:58Z',
#   'IXP_Website': 'https://evix.org',
#   'IXP_Url_Stats': 'https://evix.org',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CO',
#   'IXPDB_ID': 776,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2289,
#   'IXP_name': 'Equinix Bogota',
#   'IXP_City': 'Bogota',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2018-08-02T17:59:16Z',
#   'IXP_Website': 'https://www.equinix.com',
#   'IXP_Url_Stats': 'https://ix.equinix.com',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BR',
#   'IXPDB_ID': 788,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2291,
#   'IXP_name': 'IX.br (PTT.br) Maceió',
#   'IXP_City': 'Maceió/AL',
#   'IXP_region_continent': 'South America',
#   'Date_Creation_IXP': '2018-08-06T12:42:57Z',
#   'IXP_Website': 'http://ix.br/',
#   'IXP_Url_Stats': 'http://ix.br/trafego/agregado/mcz',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IN',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2341,
#   'IXP_name': 'REDIX Chennai',
#   'IXP_City': 'Chennai',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-09-10T12:12:16Z',
#   'IXP_Website': 'https://redix.org',
#   'IXP_Url_Stats': 'https://manage.redix.org',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'PR',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2353,
#   'IXP_name': 'Puerto Rico Internet Exchange',
#   'IXP_City': 'San Juan',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-09-19T04:23:47Z',
#   'IXP_Website': 'https://www.puertorico-ix.com',
#   'IXP_Url_Stats': 'https://www.puertorico-ix.com/stats',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BT',
#   'IXPDB_ID': 757,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2355,
#   'IXP_name': 'btIX',
#   'IXP_City': 'Thimphu',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-09-22T17:01:27Z',
#   'IXP_Website': 'https://www.btix.bt',
#   'IXP_Url_Stats': 'https://www.btix.bt',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CH',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2365,
#   'IXP_name': 'CHIX-CH',
#   'IXP_City': 'Frauenfeld',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-09-27T21:15:52Z',
#   'IXP_Website': 'https://chix.ch',
#   'IXP_Url_Stats': 'https://chix.ch',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'GR',
#   'IXPDB_ID': 753,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2386,
#   'IXP_name': 'GR-IX::Thessaloniki',
#   'IXP_City': 'Thessaloniki',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-11-02T11:13:23Z',
#   'IXP_Website': 'http://www.gr-ix.gr/',
#   'IXP_Url_Stats': 'http://www.gr-ix.gr/traffic/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'SO',
#   'IXPDB_ID': 754,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2410,
#   'IXP_name': 'SoIXP',
#   'IXP_City': 'Mogadishu',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2018-11-23T12:26:29Z',
#   'IXP_Website': 'http://www.soixp.so',
#   'IXP_Url_Stats': 'https://portal.soixp.so/statistics/infrastructure',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NG',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2415,
#   'IXP_name': 'IXPN Port Harcourt',
#   'IXP_City': 'Port Harcourt',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2018-11-28T12:49:35Z',
#   'IXP_Website': 'http://www.ixp.net.ng',
#   'IXP_Url_Stats': 'https://traffics.ixp.net.ng/sensor.htm?id=3304&tabid=1',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CH',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2447,
#   'IXP_name': '4b42 Internet Exchange Point',
#   'IXP_City': 'Zurich',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2018-12-06T12:23:38Z',
#   'IXP_Website': 'https://www.4ixp.com',
#   'IXP_Url_Stats': 'https://www.4ixp.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CA',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2452,
#   'IXP_name': 'UNM-Exch Canada-West',
#   'IXP_City': 'Vancouver',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2018-12-10T15:25:53Z',
#   'IXP_Website': 'http://unmetered.exchange',
#   'IXP_Url_Stats': 'http://unmetered.exchange',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TH',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2454,
#   'IXP_name': 'CSL Thai-IX Malaysia',
#   'IXP_City': 'Bangkok',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2018-12-11T03:18:51Z',
#   'IXP_Website': 'https://www.cslthai-ix.net',
#   'IXP_Url_Stats': 'https://www.cslthai-ix.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TH',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2494,
#   'IXP_name': 'CSL Thai-IX Singapore',
#   'IXP_City': 'Bangkok',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-01-31T01:47:49Z',
#   'IXP_Website': 'https://www.cslthai-ix.net',
#   'IXP_Url_Stats': 'https://www.cslthai-ix.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TH',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2495,
#   'IXP_name': 'CSL Thai-IX Bangkok',
#   'IXP_City': 'Bangkok',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-01-31T01:57:08Z',
#   'IXP_Website': 'https://www.cslthai-ix.net/',
#   'IXP_Url_Stats': 'https://www.cslthai-ix.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'KZ',
#   'IXPDB_ID': 768,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2497,
#   'IXP_name': 'KazNIX',
#   'IXP_City': 'Semey',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-02-07T12:00:09Z',
#   'IXP_Website': 'https://kaznix.kz',
#   'IXP_Url_Stats': 'https://kaznix.kz',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'BD',
#   'IXPDB_ID': 109,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2516,
#   'IXP_name': 'BDIX',
#   'IXP_City': 'Dhaka',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-02-26T05:33:18Z',
#   'IXP_Website': 'http://www.bdix.net',
#   'IXP_Url_Stats': 'http://www.bdix.net/stat.htm',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'KR',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2522,
#   'IXP_name': 'Sejong Neutral-IX',
#   'IXP_City': 'Seoul',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-03-07T01:44:11Z',
#   'IXP_Website': 'https://www.sejongtelecom.net/en/pages/service/data_network_nix',
#   'IXP_Url_Stats': 'https://client.sjtel.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'TR',
#   'IXPDB_ID': 767,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2527,
#   'IXP_name': 'Turk-IX',
#   'IXP_City': 'Istanbul',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2019-03-12T15:27:36Z',
#   'IXP_Website': 'https://www.turk-ix.com',
#   'IXP_Url_Stats': 'https://www.turk-ix.com/monitoring.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CM',
#   'IXPDB_ID': 798,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2541,
#   'IXP_name': 'CAMIX Douala',
#   'IXP_City': 'Douala, CAMTEL BEPANDA',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2019-03-25T22:07:12Z',
#   'IXP_Website': 'http://www.camix.cm',
#   'IXP_Url_Stats': 'http://www.camix.cm/index.php/statistiques-de-trafic-douala',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2551,
#   'IXP_name': 'Digital Realty Chicago',
#   'IXP_City': 'Chicago',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2019-03-29T11:02:59Z',
#   'IXP_Website': 'https://ix.digitalrealty.com',
#   'IXP_Url_Stats': 'https://ix.digitalrealty.com',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'CM',
#   'IXPDB_ID': 528,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2554,
#   'IXP_name': 'CAMIX Yaounde',
#   'IXP_City': 'Yaounde',
#   'IXP_region_continent': 'Africa',
#   'Date_Creation_IXP': '2019-04-01T20:43:37Z',
#   'IXP_Website': 'http://www.camix.cm',
#   'IXP_Url_Stats': 'http://camix.cm/index.php/techniques/technologies/statistiques-de-trafic',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': 786,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2558,
#   'IXP_name': 'NYIIX Philadelphia',
#   'IXP_City': 'Philadelphia',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2019-04-08T13:44:34Z',
#   'IXP_Website': 'https://www.nyiix.net/locations/nyiix-philadelphia/',
#   'IXP_Url_Stats': 'https://www.nyiix.net/PHI-mrtg/sum.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'RU',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2568,
#   'IXP_name': 'TN-IX',
#   'IXP_City': 'Novokuznetsk',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-04-22T15:54:49Z',
#   'IXP_Website': 'http://tn-ix.net/',
#   'IXP_Url_Stats': 'http://tn-ix.net/statistics/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'US',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2585,
#   'IXP_name': 'STLIX',
#   'IXP_City': 'Saint Louis, MO',
#   'IXP_region_continent': 'North America',
#   'Date_Creation_IXP': '2019-05-09T01:40:13Z',
#   'IXP_Website': 'http://www.stlix.net',
#   'IXP_Url_Stats': 'http://www.stlix.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IN',
#   'IXPDB_ID': 688,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2587,
#   'IXP_name': 'DE-CIX Delhi',
#   'IXP_City': 'Delhi',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-05-14T14:20:32Z',
#   'IXP_Website': 'https://www.de-cix.in/locations/de-cix-delhi',
#   'IXP_Url_Stats': 'https://www.de-cix.in/statistics',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IN',
#   'IXPDB_ID': '',
#   'PCH_ID': '',
#   'PeeringDB_ID': 2588,
#   'IXP_name': 'DE-CIX Chennai',
#   'IXP_City': 'Chennai',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-05-14T14:22:47Z',
#   'IXP_Website': 'https://www.de-cix.in/locations/de-cix-chennai',
#   'IXP_Url_Stats': 'https://www.de-cix.in/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'IN',
#   'IXPDB_ID': 689,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2589,
#   'IXP_name': 'DE-CIX Kolkata',
#   'IXP_City': 'Kolkata',
#   'IXP_region_continent': 'Asia Pacific',
#   'Date_Creation_IXP': '2019-05-14T14:25:01Z',
#   'IXP_Website': '',
#   'IXP_Url_Stats': 'https://www.de-cix.in/',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'NL',
#   'IXPDB_ID': 774,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2601,
#   'IXP_name': 'NLocIX',
#   'IXP_City': 'Meppel',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2019-05-26T12:55:28Z',
#   'IXP_Website': 'http://www.nlocix.net',
#   'IXP_Url_Stats': 'http://www.nlocix.net',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''},
#  {'IXP_Country_ISO_Alpha2': 'UA',
#   'IXPDB_ID': 402,
#   'PCH_ID': '',
#   'PeeringDB_ID': 2611,
#   'IXP_name': 'KM-IX',
#   'IXP_City': 'Khmelnitskiy',
#   'IXP_region_continent': 'Europe',
#   'Date_Creation_IXP': '2019-06-13T21:23:38Z',
#   'IXP_Website': 'http://ix.km.ua/',
#   'IXP_Url_Stats': 'http://ix.km.ua/traffic.html',
#   'URL_stats_comments': '',
#   'Date_check_Stats': ''}]
